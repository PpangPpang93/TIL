# %%
# 기본세팅
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import time
import datetime
import random

# 크롤링용
from pandas.io.json import json_normalize
from bs4 import BeautifulSoup
import json
import requests
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

# 컬럼, 로우 조회 최대수 지정 
pd.options.display.max_info_columns =200
pd.options.display.max_columns = 200
pd.options.display.max_info_rows =100
pd.options.display.max_rows = 100

# 시각화할때 warning 무시
import warnings
warnings.filterwarnings(action='ignore')

# %% [markdown]
# # 정보
# - 일단 탑10밖에 안된다.
# - list 만들어서 그냥 탑텐정도 뽑아놓고 셀레니움을 해보자

# %%
# 지역 및 가게별 검색어 리스트를 따로 만들어보자
sgg = pd.read_csv('/Users/ppangppang/Desktop/ssac/data_crwaling/restaurant_test/SGG.csv')
sgg['county'] = sgg['county'].apply(lambda x:'부산' if (x == "부산광역시") else x)
sgg['county'] = sgg['county'].apply(lambda x:'서울' if (x == "서울특별시") else x)
sgg['county'] = sgg['county'].apply(lambda x:'경북' if (x == "경상북도") else x)
sgg['county'] = sgg['county'].apply(lambda x:'경남' if (x == "경상남도") else x)
sgg['county'] = sgg['county'].apply(lambda x:'전북' if (x == "전라북도") else x)
sgg['county'] = sgg['county'].apply(lambda x:'전남' if (x == "전라남도") else x)
sgg['county'] = sgg['county'].apply(lambda x:'전북' if (x == "전라북도") else x)
sgg['county'] = sgg['county'].apply(lambda x:'충북' if (x == "충청북도") else x)
sgg['county'] = sgg['county'].apply(lambda x:'충남' if (x == "충청북도") else x)
sgg['county'] = sgg['county'].apply(lambda x:'대구' if (x == "대구광역시") else x)
sgg['county'] = sgg['county'].apply(lambda x:'울산' if (x == "울산광역시") else x)
sgg['county'] = sgg['county'].apply(lambda x:'제주' if (x == "제주특별자치도") else x)
sgg['county'] = sgg['county'].apply(lambda x:'세종' if (x == "세종특별자치시") else x)
sgg['county'] = sgg['county'].apply(lambda x:'인천' if (x == "인천광역시") else x)
sgg['county'] = sgg['county'].apply(lambda x:'광주' if (x == "광주광역시") else x)

# %%
# list_df=sgg[(sgg['county']=='서울') | (sgg['county']=='인천')]
# list_df.drop(['si_gun'],axis=1,inplace=True)
# list_df=list_df.dropna()

# list_gu = list(list_df['gu'])
# list_dong = list(list_df['dong'])
# total_list=[0]*len(list_gu)
# for i in range(len(list_gu)):
#      total_list[i] = list_gu[i] + list_dong[i]

# %%
# sgg[sgg['county']=='부산']
list_gu1 = []
for i in list_gu:
    if i != '부산진구':
        list_gu1.append('부산'+i)
    else:
        list_gu1.append(i)

# %%
list_gu1
# Out:
# ['부산중구',
#  '부산중구',
#  '부산중구',
#  '부산중구',
#  '부산중구',
#  '부산중구',
#  '부산중구',
#  '부산중구',
#  '부산중구',
#  '부산중구',
#  '부산중구',
#  '부산서구',
#  '부산서구',
#  '부산서구',
#  '부산서구',
#  '부산서구',
#  '부산서구',
#  '부산서구',
#  '부산서구',
#  '부산서구',
#  '부산서구',
#  '부산동구',
#  '부산동구',
#  '부산동구',
#  '부산동구',
#  '부산영도구',
#  '부산영도구',
#  '부산영도구',
#  '부산영도구',
#  '부산영도구',
#  '부산영도구',
#  '부산영도구',
#  '부산영도구',
#  '부산진구',
#  '부산진구',
#  '부산진구',
#  '부산진구',
#  '부산진구',
#  '부산진구',
#  '부산진구',
#  '부산진구',
#  '부산진구',
#  '부산진구',
#  '부산진구',
#  '부산동래구',
#  '부산동래구',
#  '부산동래구',
#  '부산동래구',
#  '부산동래구',
#  '부산동래구',
#  '부산동래구',
#  '부산동래구',
#  '부산동래구',
#  '부산남구',
#  '부산남구',
#  '부산남구',
#  '부산남구',
#  '부산남구',
#  '부산남구',
#  '부산북구',
#  '부산북구',
#  '부산북구',
#  '부산북구',
#  '부산북구',
#  '부산해운대구',
#  '부산해운대구',
#  '부산해운대구',
#  '부산해운대구',
#  '부산해운대구',
#  '부산해운대구',
#  '부산해운대구',
#  '부산해운대구',
#  '부산사하구',
#  '부산사하구',
#  '부산사하구',
#  '부산사하구',
#  '부산사하구',
#  '부산사하구',
#  '부산사하구',
#  '부산사하구',
#  '부산금정구',
#  '부산금정구',
#  '부산금정구',
#  '부산금정구',
#  '부산금정구',
#  '부산금정구',
#  '부산금정구',
#  '부산금정구',
#  '부산금정구',
#  '부산금정구',
#  '부산금정구',
#  '부산금정구',
#  '부산금정구',
#  '부산강서구',
#  '부산강서구',
#  '부산강서구',
#  '부산강서구',
#  '부산강서구',
#  '부산강서구',
#  '부산강서구',
#  '부산강서구',
#  '부산강서구',
#  '부산강서구',
#  '부산강서구',
#  '부산강서구',
#  '부산강서구',
#  '부산강서구',
#  '부산강서구',
#  '부산강서구',
#  '부산강서구',
#  '부산강서구',
#  '부산강서구',
#  '부산강서구',
#  '부산강서구',
#  '부산연제구',
#  '부산연제구',
#  '부산수영구',
#  '부산수영구',
#  '부산수영구',
#  '부산수영구',
#  '부산수영구',
#  '부산사상구',
#  '부산사상구',
#  '부산사상구',
#  '부산사상구',
#  '부산사상구',
#  '부산사상구',
#  '부산사상구',
#  '부산사상구']

# %%
list_df=sgg[(sgg['county']=='부산')]
list_df.drop(['si_gun'],axis=1,inplace=True)
list_df=list_df.dropna()

list_gu = list(list_df['gu'])

list_gu1 = []
for i in list_gu:
    if i != '부산진구':
        list_gu1.append('부산'+i)
    else:
        list_gu1.append(i)
        
list_gu2=[]
for i in list_gu1:
    if i not in list_gu2:
        list_gu2.append(i)

# %%
list_gu2
# Out:
# ['부산중구',
#  '부산서구',
#  '부산동구',
#  '부산영도구',
#  '부산진구',
#  '부산동래구',
#  '부산남구',
#  '부산북구',
#  '부산해운대구',
#  '부산사하구',
#  '부산금정구',
#  '부산강서구',
#  '부산연제구',
#  '부산수영구',
#  '부산사상구']

# %%
# 음식 리스트 가져오기
food_cat = pd.read_excel('/Users/ppangppang/Desktop/ssac/data_crwaling/restaurant_test/food_cat.xlsx')
# food_cat.drop(columns='Unnamed: 0',axis=1, inplace=True)
food = (list(food_cat['list']))

# %%
# test
food1=food
list_gu1=[]
for i in list_gu:
    if i not in list_gu1:
        list_gu1.append(i)
# 강남
# list_gu1=['강남']
# list_gu1=['연수구']
# list_gu1=['종로구']
# list_gu1=['창곡동'] # 위례
# list_gu1=['영등포']
# list_gu1=['마포구']
# list_gu1=['동대문']
# list_gu1=['강서구']
# list_gu1=['건대']
# list_gu1=['홍대']
# list_gu1=['용산']
# list_gu1=['이태원']
# list_gu1=['광명']
# list_gu1=['구로']
# list_gu1=['계양']
# list_gu1=['남동구']
# list_gu1=['성북구']
# list_gu1=['강동구']
# list_gu1=['중랑구']
# list_gu1=['서대문구']
# list_gu1=['노원구']
# list_gu1=['동작구']
# list_gu1=['서초구']
# list_gu1=['관악구']
# list_gu1=['강북구']
# list_gu1=['금천구']
# list_gu1=['은평구']
# list_gu1=['양천구']
# list_gu1=['송파구']
# list_gu1=['광진구']
# list_gu1=['도봉구']
# list_gu1=['성동구']
# list_gu1=['서울중구']
# list_gu1=['인천중구']
# list_gu1=['인천동구']
# list_gu1=['미추홀구']
# list_gu1=['강화군']
# list_gu1=['옹진군']

target=[]
for loca in list_gu1:
    for foody in food1:
        target.append(loca + foody)

# %%
target
# Out:
# ['옹진군가라아게',
#  '옹진군가래떡',
#  '옹진군가리국밥',
#  '옹진군가리비',
#  '옹진군가릿국밥',
#  '옹진군가마솥',
#  '옹진군가마솥국밥',
#  '옹진군가마솥밥',
#  '옹진군가마솥설렁탕',
#  '옹진군가마솥순두부',
#  '옹진군가마솥통닭',
#  '옹진군가맥',
#  '옹진군가브리살',
#  '옹진군가스트로펍',
#  '옹진군가오리',
#  '옹진군가자미물회',
#  '옹진군가자미미역국',
#  '옹진군가정식',
#  '옹진군가지그라탕',
#  '옹진군가지덮밥',
#  '옹진군가지볶음',
#  '옹진군가지볶음밥',
#  '옹진군가지튀김',
#  '옹진군가츠나베',
#  '옹진군가츠동',
#  '옹진군가츠산도',
#  '옹진군각재기국',
#  '옹진군간자장',
#  '옹진군간장구이',
#  '옹진군간장덮밥',
#  '옹진군간장새우',
#  '옹진군간재미',
#  '옹진군간짜장',
#  '옹진군갈낙찜',
#  '옹진군갈낙탕',
#  '옹진군갈릭난',
#  '옹진군갈릭돈까스',
#  '옹진군갈릭버거',
#  '옹진군갈릭버터쉬림프',
#  '옹진군갈릭쉬림프',
#  '옹진군갈릭스테이크',
#  '옹진군갈릭페뇨파스타',
#  '옹진군갈매기살',
#  '옹진군갈비',
#  '옹진군갈비국밥',
#  '옹진군갈비국수',
#  '옹진군갈비덮밥',
#  '옹진군갈비만두',
#  '옹진군갈비쌀국수',
#  '옹진군갈비찜',
#  '옹진군갈비탕',
#  '옹진군갈빗살',
#  '옹진군갈추어탕',
#  '옹진군갈치',
#  '옹진군갈치구이',
#  '옹진군갈치국',
#  '옹진군갈치덮밥',
#  '옹진군갈치조림',
#  '옹진군갈치찜',
#  '옹진군갈치회',
#  '옹진군감바스',
#  '옹진군감바스알아히요',
#  '옹진군감베로니',
#  '옹진군감베리크레마',
#  '옹진군감성돔',
#  '옹진군감자고로케',
#  '옹진군감자국',
#  '옹진군감자국수',
#  '옹진군감자뇨끼',
#  '옹진군감자떡',
#  '옹진군감자빵',
#  '옹진군감자수제비',
#  '옹진군감자스프',
#  '옹진군감자옹심이',
#  '옹진군감자전',
#  '옹진군감자탕',
#  '옹진군감자튀김',
#  '옹진군갑오징어',
#  '옹진군강된장',
#  '옹진군강된장비빔밥',
#  '옹진군개스트로펍',
#  '옹진군객주리조림',
#  '옹진군갯장어',
#  '옹진군건강빵',
#  '옹진군건두부볶음',
#  '옹진군검은콩국수',
#  '옹진군게국지',
#  '옹진군게살비빔밥',
#  '옹진군게장',
#  '옹진군간장게장',
#  '옹진군게찜',
#  '옹진군경양식',
#  '옹진군계떡',
#  '옹진군계란김밥',
#  '옹진군계란말이',
#  '옹진군계란찜',
#  '옹진군계란초밥',
#  '옹진군계란토스트',
#  '옹진군고갈비',
#  '옹진군고구마',
#  '옹진군고기국수',
#  '옹진군고기군만두',
#  '옹진군고기만두',
#  '옹진군고기말이',
#  '옹진군고기뷔페',
#  '옹진군고기비빔국수',
#  '옹진군고기완자',
#  '옹진군고기전',
#  '옹진군고기짬뽕',
#  '옹진군고기튀김',
#  '옹진군고등어',
#  '옹진군고로케',
#  '옹진군고르곤졸라',
#  '옹진군고르곤졸라피자',
#  '옹진군고사리육개장',
#  '옹진군고추군만두',
#  '옹진군고추닭튀김',
#  '옹진군고추부각',
#  '옹진군고추장구이',
#  '옹진군고추장불고기',
#  '옹진군고추장불백',
#  '옹진군고추장삼겹살',
#  '옹진군고추장주물럭',
#  '옹진군고추장찌개',
#  '옹진군고추장찜닭',
#  '옹진군고추전',
#  '옹진군고추짜장',
#  '옹진군고추짬뽕',
#  '옹진군고추튀김',
#  '옹진군곤드레',
#  '옹진군곤이',
#  '옹진군골뱅이',
#  '옹진군곰국',
#  '옹진군곰국시',
#  '옹진군곰장어',
#  '옹진군곰장어양념구이',
#  '옹진군곰치국',
#  '옹진군곰탕',
#  '옹진군곱도리탕',
#  '옹진군곱창',
#  '옹진군곱창국수',
#  '옹진군곱창떡볶이',
#  '옹진군곱창모듬',
#  '옹진군곱창볶음',
#  '옹진군곱창순대전골',
#  '옹진군곱창순두부',
#  '옹진군곱창쌀국수',
#  '옹진군곱창전골',
#  '옹진군과메기',
#  '옹진군과일디저트',
#  '옹진군과일에이드',
#  '옹진군과일주스',
#  '옹진군과자점',
#  '옹진군관자구이',
#  '옹진군광동식',
#  '옹진군광양불고기',
#  '옹진군광어',
#  '옹진군광어물회',
#  '옹진군광어세꼬시',
#  '옹진군광어회',
#  '옹진군교자',
#  '옹진군교자만두',
#  '옹진군구운치킨',
#  '옹진군구절판',
#  '옹진군국물닭발',
#  '옹진군국물떡볶이',
#  '옹진군국밥',
#  '옹진군국수',
#  '옹진군국시',
#  '옹진군군만두',
#  '옹진군굴국밥',
#  '옹진군굴림만두',
#  '옹진군굴',
#  '옹진군궁중음식',
#  '옹진군규동',
#  '옹진군규카츠',
#  '옹진군그라탕',
#  '옹진군그리스식',
#  '옹진군그릭요거트',
#  '옹진군그린티',
#  '옹진군그릴드샌드위치',
#  '옹진군근고기',
#  '옹진군기네스',
#  '옹진군기절낙지',
#  '옹진군김말이',
#  '옹진군김밥',
#  '옹진군김치나베',
#  '옹진군김치낙지죽',
#  '옹진군김치덮밥',
#  '옹진군김치돈까스',
#  '옹진군김치돼지찌개',
#  '옹진군김치두루치기',
#  '옹진군김치만두',
#  '옹진군김치만두전골',
#  '옹진군김치말이국수',
#  '옹진군김치보쌈',
#  '옹진군김치볶음밥',
#  '옹진군김치수제비',
#  '옹진군김치순두부',
#  '옹진군김치왕만두',
#  '옹진군김치우동',
#  '옹진군김치전',
#  '옹진군김치전골',
#  '옹진군김치제육볶음',
#  '옹진군김치찌개',
#  '옹진군김치치즈나베',
#  '옹진군김치칼국수',
#  '옹진군김치콩나물국밥',
#  '옹진군까눌레',
#  '옹진군까르보나라',
#  '옹진군까페',
#  '옹진군깍두기볶음밥',
#  '옹진군깐풍기',
#  '옹진군깔조네',
#  '옹진군껍데기',
#  '옹진군꼬들살',
#  '옹진군꼬리곰탕',
#  '옹진군꼬리찜',
#  '옹진군꼬막',
#  '옹진군꼬치',
#  '옹진군꼼장어',
#  '옹진군꽁보리밥',
#  '옹진군꽁치찌개',
#  '옹진군꽃게',
#  '옹진군꽃등심',
#  '옹진군꽃살',
#  '옹진군꽃삼겹',
#  '옹진군꽃새우',
#  '옹진군꽃항정살',
#  '옹진군꽈리고추',
#  '옹진군꽈배기',
#  '옹진군꿀막걸리',
#  '옹진군꿀빵',
#  '옹진군꿀호떡',
#  '옹진군꿔바로우',
#  '옹진군꿩',
#  '옹진군나가사키짬뽕',
#  '옹진군나베',
#  '옹진군나비파이',
#  '옹진군나시고랭',
#  '옹진군나폴리피자',
#  '옹진군낙곱새',
#  '옹진군낙엽살',
#  '옹진군낙지',
#  '옹진군난자완스',
#  '옹진군날치알',
#  '옹진군남도음식',
#  '옹진군남방즈케',
#  '옹진군남아공음식',
#  '옹진군납작만두',
#  '옹진군내장',
#  '옹진군냄비우동',
#  '옹진군냉국수',
#  '옹진군냉동삼겹살',
#  '옹진군냉라면',
#  '옹진군냉면',
#  '옹진군냉모밀',
#  '옹진군냉소바',
#  '옹진군냉우동',
#  '옹진군냉족',
#  '옹진군냉짬뽕',
#  '옹진군냉채족발',
#  '옹진군냉칼국수',
#  '옹진군냉콩국수',
#  '옹진군네팔식',
#  '옹진군노가리',
#  '옹진군녹두빈대떡',
#  '옹진군녹두전',
#  '옹진군뇨끼',
#  '옹진군누들',
#  '옹진군누룽지탕',
#  '옹진군누룽지통닭',
#  '옹진군누텔라',
#  '옹진군눈꽃빙수',
#  '옹진군능이오리',
#  '옹진군니꾸우동',
#  '옹진군다금바리',
#  '옹진군다슬기',
#  '옹진군다이닝펍',
#  '옹진군다찌',
#  '옹진군다코야끼',
#  '옹진군단팥빵',
#  '옹진군단팥죽',
#  '옹진군단호박',
#  '옹진군달걀말이',
#  '옹진군닭가슴살',
#  '옹진군닭갈비',
#  '옹진군닭강정',
#  '옹진군닭개장',
#  '옹진군닭곰탕',
#  '옹진군닭구이',
#  '옹진군닭국수',
#  '옹진군닭껍질',
#  '옹진군닭꼬치',
#  '옹진군닭내장',
#  '옹진군닭다리',
#  '옹진군닭도리탕',
#  '옹진군닭똥집',
#  '옹진군닭목살',
#  '옹진군닭발',
#  '옹진군닭백숙',
#  '옹진군닭볶음탕',
#  '옹진군닭숯불구이',
#  '옹진군닭죽',
#  '옹진군닭칼국수',
#  '옹진군닭한마리',
#  '옹진군당근주스',
#  '옹진군당근케이크',
#  '옹진군대게',
#  '옹진군대구매운탕',
#  '옹진군대구뽈찜',
#  '옹진군대구왕뽈찜',
#  '옹진군대구전골',
#  '옹진군대구탕',
#  '옹진군대나무통밥',
#  '옹진군대만샌드위치',
#  '옹진군대방어',
#  '옹진군대창',
#  '옹진군대통밥',
#  '옹진군대패삼겹살',
#  '옹진군대하',
#  '옹진군대합',
#  '옹진군더덕',
#  '옹진군더블치즈버거',
#  '옹진군더치커피',
#  '옹진군덕자',
#  '옹진군데리야끼막창',
#  '옹진군덴뿌라',
#  '옹진군도가니',
#  '옹진군도넛',
#  '옹진군도다리쑥국',
#  '옹진군도라지정과',
#  '옹진군도래창',
#  '옹진군도로초밥',
#  '옹진군도루묵',
#  '옹진군도리뱅뱅',
#  '옹진군도리아',
#  '옹진군도미',
#  '옹진군도삭면',
#  '옹진군도치알탕',
#  '옹진군도토리',
#  '옹진군독일식레스토랑',
#  '옹진군돈까스',
#  '옹진군돈부리',
#  '옹진군돈치맛살',
#  '옹진군돈코츠',
#  '옹진군돈파스',
#  '옹진군돌게장',
#  '옹진군돌곱창',
#  '옹진군돌문어',
#  '옹진군돌솥밥',
#  '옹진군돌판',
#  '옹진군돔베고기',
#  '옹진군동남아음식',
#  '옹진군동동주',
#  '옹진군동치미막국수',
#  '옹진군동태탕',
#  '옹진군동파육',
#  '옹진군돼지갈비',
#  '옹진군돼지고기탕수육',
#  '옹진군돼지곱창전골',
#  '옹진군돼지국밥',
#  '옹진군돼지김치구이',
#  '옹진군돼지김치찜',
#  '옹진군돼지껍데기',
#  '옹진군돼지꼬리',
#  '옹진군돼지머리고기',
#  '옹진군돼지부속',
#  '옹진군돼지불고기',
#  '옹진군돼지불백',
#  '옹진군돼지양념갈비',
#  '옹진군돼지왕갈비',
#  '옹진군돼지주물럭',
#  '옹진군돼지짜글이',
#  '옹진군돼지특수부위',
#  '옹진군된장국',
#  '옹진군두루치기',
#  '옹진군두부',
#  '옹진군두부버섯전골',
#  '옹진군두부요리전문',
#  '옹진군뒷고기',
#  '옹진군드라이에이징',
#  '옹진군드립커피',
#  '옹진군들기름막국수',
#  '옹진군들깨',
#  '옹진군등갈비',
#  '옹진군등뼈찜',
#  '옹진군등심',
#  '옹진군등심덧살',
#  '옹진군디너코스',
#  '옹진군디저트',
#  '옹진군딤섬',
#  '옹진군따개비칼국수',
#  '옹진군따로국밥',
#  '옹진군딱새우',
#  '옹진군딴딴면',
#  '옹진군딸기막걸리',
#  '옹진군딸기',
#  '옹진군땡초',
#  '옹진군떠먹는피자',
#  '옹진군떡갈비',
#  '옹진군떡국',
#  '옹진군떡볶이',
#  '옹진군떡케이크',
#  '옹진군똠얌쌀국수',
#  '옹진군뚝배기감자탕',
#  '옹진군뚝배기닭볶음탕',
#  '옹진군뚝배기불고기',
#  '옹진군뚱카롱',
#  '옹진군라구파스타',
#  '옹진군라따뚜이',
#  '옹진군라멘',
#  '옹진군라면',
#  '옹진군라볶이',
#  '옹진군라오스음식',
#  '옹진군라자냐',
#  '옹진군라코타치즈샐러드',
#  '옹진군라클렛',
#  '옹진군랍스타',
#  '옹진군랩피자',
#  '옹진군러스크',
#  '옹진군러시아',
#  '옹진군런치코스',
#  '옹진군레드락',
#  '옹진군레모네이드',
#  '옹진군레몬마들렌',
#  '옹진군레몬에이드',
#  '옹진군레몬탕수육',
#  '옹진군레몬티',
#  '옹진군레스토랑',
#  '옹진군레터링케이크',
#  '옹진군로바다야키',
#  '옹진군로스',
#  '옹진군로스트비프',
#  '옹진군로스팅',
#  '옹진군로제떡볶이',
#  '옹진군로제빠네',
#  '옹진군로제찜닭',
#  '옹진군로제파스타',
#  '옹진군롤케이크',
#  '옹진군루꼴라',
#  '옹진군루프탑',
#  '옹진군룽고',
#  '옹진군류산슬',
#  '옹진군리조또',
#  '옹진군리코타치즈샐러드',
#  '옹진군립아이',
#  '옹진군링귀니',
#  '옹진군마구로',
#  '옹진군마늘간장',
#  '옹진군마늘곱창',
#  '옹진군마늘닭',
#  '옹진군마늘떡볶이',
#  '옹진군마늘바게트',
#  '옹진군마늘보쌈',
#  '옹진군마늘볶음밥',
#  '옹진군마늘빵',
#  '옹진군마늘족발',
#  '옹진군마늘치킨',
#  '옹진군마늘탕수육',
#  '옹진군마늘통닭',
#  '옹진군마들렌',
#  '옹진군마라',
#  '옹진군마라샹궈',
#  '옹진군마르게리타',
#  '옹진군마스카포네피자',
#  '옹진군마약김밥',
#  '옹진군마약옥수수',
#  '옹진군마제',
#  '옹진군마카롱',
#  '옹진군마파두부',
#  '옹진군막걸리',
#  '옹진군막국수',
#  '옹진군막창',
#  '옹진군막회',
#  '옹진군만두',
#  '옹진군만두전골',
#  '옹진군말차',
#  '옹진군맑은버섯탕',
#  '옹진군맛감자',
#  '옹진군망고',
#  '옹진군매생이',
#  '옹진군매운갈비찜',
#  '옹진군매운냉면',
#  '옹진군매운닭발',
#  '옹진군매운돈까스',
#  '옹진군매운등갈비',
#  '옹진군매운등뼈찜',
#  '옹진군매운버섯샤브샤브',
#  '옹진군매운부타동',
#  '옹진군매운뼈찜',
#  '옹진군매운오뎅',
#  '옹진군매운족발',
#  '옹진군매운쭈꾸미',
#  '옹진군매운탕',
#  '옹진군매콤불닭',
#  '옹진군매콤크림파스타',
#  '옹진군맥주',
#  '옹진군머릿고기',
#  '옹진군머쉬룸버거',
#  '옹진군머핀',
#  '옹진군먹태',
#  '옹진군멍게',
#  '옹진군멍게비빔밥',
#  '옹진군메기',
#  '옹진군메기매운탕',
#  '옹진군메로구이',
#  '옹진군메론빙수',
#  '옹진군메밀',
#  '옹진군메밀전병',
#  '옹진군멕시칸',
#  '옹진군멘보샤',
#  '옹진군멜란자네',
#  '옹진군멜론빙수',
#  '옹진군멜젓',
#  '옹진군멸치',
#  '옹진군명란',
#  '옹진군명란파스타',
#  '옹진군명이나물',
#  '옹진군명태',
#  '옹진군모나카',
#  '옹진군모던한식',
#  '옹진군모두부',
#  '옹진군모둠구이',
#  '옹진군모둠회',
#  '옹진군모듬사시미',
#  '옹진군모듬수육',
#  '옹진군모듬전',
#  '옹진군모듬조개',
#  '옹진군모듬철판구이',
#  '옹진군모듬초밥',
#  '옹진군모듬튀김',
#  '옹진군모듬해산물',
#  '옹진군모로코',
#  '옹진군모밀',
#  '옹진군모소리살',
#  '옹진군모주',
#  '옹진군모찌리도후',
#  '옹진군모츠나베',
#  '옹진군모카번',
#  '옹진군모히또',
#  '옹진군목등심',
#  '옹진군목살',
#  '옹진군목살필라프',
#  '옹진군목화솜탕수육',
#  '옹진군몸국',
#  '옹진군몽골음식',
#  '옹진군몽블랑',
#  '옹진군무가당',
#  '옹진군무국',
#  '옹진군무뼈닭발',
#  '옹진군무쇠솥밥',
#  '옹진군무지개케이크',
#  '옹진군무침',
#  '옹진군무한리필조개구이',
#  '옹진군무화과',
#  '옹진군묵밥',
#  '옹진군묵은지',
#  '옹진군문어',
#  '옹진군물갈비',
#  '옹진군물곰탕',
#  '옹진군물국수',
#  '옹진군물냉면',
#  '옹진군물닭갈비',
#  '옹진군물막국수',
#  '옹진군물만두',
#  '옹진군물짜장',
#  '옹진군물쫄면',
#  '옹진군물칡냉면',
#  '옹진군물회',
#  '옹진군미고랭',
#  '옹진군미국가정식',
#  '옹진군미국식바베큐',
#  '옹진군미나리',
#  '옹진군미니우동',
#  '옹진군미니족발',
#  '옹진군미숫가루',
#  '옹진군미역국',
#  '옹진군미트볼',
#  '옹진군민물매운탕',
#  '옹진군민물장어',
#  '옹진군민어',
#  '옹진군민트초코',
#  '옹진군밀면',
#  '옹진군밀복',
#  '옹진군밀크빙수',
#  '옹진군밀크티',
#  '옹진군밀키트',
#  '옹진군밀푀유',
#  '옹진군바게트',
#  '옹진군바닐라',
#  '옹진군바다장어',
#  '옹진군바베큐',
#  '옹진군바싹불고기',
#  '옹진군바오',
#  '옹진군바지락',
#  '옹진군박대구이',
#  '옹진군박속',
#  '옹진군반미',
#  '옹진군반상',
#  '옹진군반세오',
#  '옹진군반찬가게',
#  '옹진군발국수',
#  '옹진군발리음식',
#  '옹진군밤라떼',
#  '옹진군밤식빵',
#  '옹진군밥버거',
#  '옹진군방어',
#  '옹진군백골뱅이탕',
#  '옹진군백반',
#  '옹진군백숙',
#  '옹진군백순대',
#  '옹진군백짬뽕',
#  '옹진군백차',
#  '옹진군백합죽',
#  '옹진군밴댕이회',
#  '옹진군뱅쇼',
#  '옹진군버거',
#  '옹진군버블티',
#  '옹진군버섯두부전골',
#  '옹진군버섯매운탕',
#  '옹진군버섯샤브',
#  '옹진군버섯전골',
#  '옹진군버섯탕수',
#  '옹진군버터갈릭감자튀김',
#  '옹진군버터난',
#  '옹진군버터밀크',
#  '옹진군번데기',
#  '옹진군벌집껍데기',
#  '옹진군벚꽃빙수',
#  '옹진군베이글',
#  '옹진군베이징덕',
#  '옹진군베이커리',
#  '옹진군베이컨',
#  '옹진군베트남쌀국수',
#  '옹진군베트남연유커피',
#  '옹진군벤또',
#  '옹진군벨기에와플',
#  '옹진군병어',
#  '옹진군병천순대',
#  '옹진군보리굴비',
#  '옹진군보리밥',
#  '옹진군보리새우',
#  '옹진군보말죽',
#  '옹진군보신탕',
#  '옹진군보쌈',
#  '옹진군보이차',
#  '옹진군복국',
#  '옹진군복숭아아이스티',
#  '옹진군복집',
#  '옹진군볶음국수',
#  '옹진군볶음밥',
#  '옹진군볶음짜장',
#  '옹진군볶음짬뽕',
#  '옹진군봉골레',
#  '옹진군부각',
#  '옹진군부대볶음',
#  '옹진군부대전골',
#  '옹진군부대찌개',
#  '옹진군부산오뎅',
#  '옹진군부채살',
#  '옹진군부추전',
#  '옹진군부타동',
#  '옹진군부페',
#  '옹진군북경오리',
#  '옹진군북어국',
#  '옹진군북유럽',
#  '옹진군북한음식',
#  '옹진군분식',
#  '옹진군분짜',
#  '옹진군불갈비',
#  '옹진군불고기',
#  '옹진군불낙전골',
#  '옹진군불닭',
#  '옹진군불도장',
#  '옹진군불막창',
#  '옹진군불맛쭈꾸미',
#  '옹진군불백',
#  '옹진군불오징어',
#  '옹진군불족발',
#  '옹진군불짜장',
#  '옹진군불짬뽕',
#  '옹진군불쭈꾸미',
#  '옹진군불향낙지',
#  '옹진군붓카케우동',
#  '옹진군붕장어',
#  '옹진군브라우니',
#  '옹진군브라질',
#  '옹진군브런치',
#  '옹진군브리또',
#  '옹진군블랙티',
#  '옹진군블루베리',
#  '옹진군비건',
#  '옹진군비빔국수',
#  '옹진군비빔냉면',
#  '옹진군비빔막국수',
#  '옹진군비빔만두',
#  '옹진군비빔메밀',
#  '옹진군비빔면',
#  '옹진군비빔밥',
#  '옹진군비빔손칼국수',
#  '옹진군비빔쫄면',
#  '옹진군비빔칼국수',
#  '옹진군비스마르크',
#  '옹진군비스트로',
#  '옹진군비엔나커피',
#  '옹진군비지찌개',
#  '옹진군비프',
#  '옹진군빈대떡',
#  '옹진군빙수',
#  '옹진군빙어튀김',
#  '옹진군빠가탕',
#  '옹진군빠네',
#  '옹진군빠에야',
#  '옹진군빨간오뎅',
#  '옹진군빨계떡',
#  '옹진군빵집',
#  '옹진군뻥튀기',
#  '옹진군뼈감자탕',
#  '옹진군뼈닭발',
#  '옹진군뼈없는닭발',
#  '옹진군뼈찜',
#  '옹진군뼈해장국',
#  '옹진군뽈살',
#  '옹진군뽈찜',
#  '옹진군사골곰탕',
#  '옹진군사라다빵',
#  '옹진군사시미',
#  '옹진군사이공라떼',
#  '옹진군사찰음식',
#  '옹진군사천',
#  '옹진군사철탕',
#  '옹진군사케',
#  '옹진군산꼼장어',
#  '옹진군산나물',
#  '옹진군산낙지',
#  '옹진군산닭구이',
#  '옹진군산미구엘',
#  '옹진군산삼배양근삼계탕',
#  '옹진군산야초',
#  '옹진군산오징어',
#  '옹진군산채백반',
#  '옹진군산채비빔밥',
#  '옹진군산채정식',
#  '옹진군살얼음맥주',
#  '옹진군살치살',
#  '옹진군삼각갈비',
#  '옹진군삼겹살',
#  '옹진군삼계탕',
#  '옹진군삼색전',
#  '옹진군삼선고추짬뽕',
#  '옹진군삼선짬뽕',
#  '옹진군삼숙이탕',
#  '옹진군삼치',
#  '옹진군삼합',
#  '옹진군상추튀김',
#  '옹진군상황버섯',
#  '옹진군새알팥죽',
#  '옹진군새우',
#  '옹진군새우튀김',
#  '옹진군새우필라프',
#  '옹진군새조개샤브샤브',
#  '옹진군샌드위치',
#  '옹진군샐러드',
#  '옹진군샘플러',
#  '옹진군생간',
#  '옹진군생갈비',
#  '옹진군생고기',
#  '옹진군생과일주스',
#  '옹진군생국수',
#  '옹진군생굴',
#  '옹진군생대구탕',
#  '옹진군생도넛',
#  '옹진군생돈까스',
#  '옹진군생맥주',
#  '옹진군생선구이',
#  '옹진군생선까스',
#  '옹진군생연어',
#  '옹진군생오겹살',
#  '옹진군생오리',
#  '옹진군생크림케이크',
#  '옹진군생태찌개',
#  '옹진군샤브샤브',
#  '옹진군샤오롱바오',
#  '옹진군샤퀴테리',
#  '옹진군샴페인',
#  '옹진군서리태콩국수',
#  '옹진군석갈비',
#  '옹진군석쇠구이',
#  '옹진군섞어찌개',
#  '옹진군선술집',
#  '옹진군선지국',
#  '옹진군설기떡',
#  '옹진군설농탕',
#  '옹진군설렁탕',
#  '옹진군섭죽',
#  '옹진군섭해장국',
#  '옹진군성게',
#  '옹진군세꼬시',
#  '옹진군세발낙지',
#  '옹진군세숫대야냉면',
#  '옹진군세이로무시',
#  '옹진군센베',
#  '옹진군소갈매기',
#  '옹진군소갈비',
#  '옹진군소고기무국',
#  '옹진군소고기전골',
#  '옹진군소고기짬뽕',
#  '옹진군소고기편백찜',
#  '옹진군소고기해장국',
#  '옹진군소곱창',
#  '옹진군소금구이',
#  '옹진군소금아이스크림',
#  '옹진군소금커피',
#  '옹진군소꼬리찜',
#  '옹진군소라숙회',
#  '옹진군소룡포',
#  '옹진군소머리국밥',
#  '옹진군소머리수육',
#  '옹진군소바',
#  '옹진군소보로',
#  '옹진군소불고기',
#  '옹진군소불백',
#  '옹진군소뼈해장국',
#  '옹진군소세지',
#  '옹진군소양념갈비',
#  '옹진군손두부',
#  '옹진군손만두',
#  '옹진군손수제비',
#  '옹진군손짜장',
#  '옹진군손칼국수',
#  '옹진군솔트커피',
#  '옹진군송어',
#  '옹진군송이버섯',
#  '옹진군솥뚜껑삼겹살',
#  '옹진군솥밥',
#  '옹진군쇼가야끼',
#  '옹진군쇼콜라',
#  '옹진군수라상',
#  '옹진군수박쥬스',
#  '옹진군수산물',
#  '옹진군수원왕갈비',
#  '옹진군수육',
#  '옹진군수육국밥',
#  '옹진군수입맥주',
#  '옹진군수정과',
#  '옹진군수제꼬치',
#  '옹진군수제도시락',
#  '옹진군수제돈까스',
#  '옹진군수제두부',
#  '옹진군수제등심돈까스',
#  '옹진군수제맥주',
#  '옹진군수제버거',
#  '옹진군수제비',
#  '옹진군수제아이스크림',
#  '옹진군수제양갱',
#  '옹진군수제와플',
#  '옹진군수제청',
#  '옹진군수제초콜릿',
#  '옹진군수제케이크',
#  '옹진군수제티라미수',
#  '옹진군수제햄버거',
#  '옹진군수타면',
#  '옹진군수타짜장',
#  '옹진군수프',
#  '옹진군수플레',
#  '옹진군숙성돼지고기',
#  '옹진군숙성등심',
#  '옹진군숙성목살',
#  '옹진군숙성삼겹살',
#  '옹진군숙성생삼겹살',
#  '옹진군숙성오겹살',
#  '옹진군숙성통삼겹살',
#  '옹진군숙성한우',
#  '옹진군숙성한우등심',
#  '옹진군숙성회',
#  '옹진군순대',
#  '옹진군순대볶음',
#  '옹진군순대전골',
#  '옹진군순두부',
#  '옹진군순메밀',
#  '옹진군순무김치',
#  '옹진군순살강정',
#  '옹진군술떡',
#  '옹진군술찜',
#  '옹진군숯불',
#  '옹진군숯불꼼장어',
#  '옹진군쉐이크',
#  '옹진군쉬림프버거',
#  '옹진군슈니첼',
#  '옹진군슈마이',
#  '옹진군슈크림',
#  '옹진군슈톨렌',
#  '옹진군슈하스코',
#  '옹진군스끼야끼',
#  '옹진군스몰비어',
#  '옹진군스무디',
#  '옹진군스시',
#  '옹진군스시뷔페',
#  '옹진군스위스식',
#  '옹진군스지수육',
#  '옹진군스지오뎅탕',
#  '옹진군스콘',
#  '옹진군스키야끼',
#  '옹진군스테이크',
#  '옹진군스테이크덮밥',
#  '옹진군스테이크피자',
#  '옹진군스테키동',
#  '옹진군스텔라',
#  '옹진군스튜',
#  '옹진군스파게티',
#  '옹진군스팸',
#  '옹진군스페인식',
#  '옹진군스프',
#  '옹진군스프링롤',
#  '옹진군슬로푸드',
#  '옹진군시골밥상',
#  '옹진군시금치',
#  '옹진군시래기',
#  '옹진군시저샐러드',
#  '옹진군시카고피자',
#  '옹진군시푸드',
#  '옹진군식빵',
#  '옹진군식육식당',
#  '옹진군식혜',
#  '옹진군신선로',
#  '옹진군신쭈꾸미',
#  '옹진군실내포장마차',
#  '옹진군실비집',
#  '옹진군심야식당',
#  '옹진군싱가폴',
#  '옹진군싱글몰트',
#  '옹진군쌀국수',
#  '옹진군쌀떡볶이',
#  '옹진군쌀빵',
#  '옹진군쌀케이크',
#  '옹진군쌀통닭',
#  '옹진군쌈밥',
#  '옹진군쌍화차',
#  '옹진군쏘가리매운탕',
#  '옹진군쏘세지',
#  '옹진군쑥라떼',
#  '옹진군쑥인절미',
#  '옹진군쑥차',
#  '옹진군씨앗호떡',
#  '옹진군씨푸드',
#  '옹진군아강발',
#  '옹진군아게다시도후',
#  '옹진군아구찜',
#  '옹진군아구탕',
#  '옹진군아나고',
#  '옹진군아란치니',
#  '옹진군아롱사태',
#  '옹진군아메리칸치즈버거',
#  '옹진군아몬드크림라떼',
#  '옹진군아바이순대',
#  '옹진군아보카도',
#  '옹진군아부라소바',
#  '옹진군아시안푸드',
#  '옹진군아이리쉬커피',
#  '옹진군아이리쉬펍',
#  '옹진군아이스모찌',
#  '옹진군아이스크림',
#  '옹진군아이스티',
#  '옹진군아인슈페너',
#  '옹진군아포카토',
#  '옹진군안동국시',
#  '옹진군안동찜닭',
#  '옹진군안심돈까스',
#  '옹진군안심스테이크',
#  '옹진군안심탕수육',
#  '옹진군안심파스타',
#  '옹진군안창살',
#  '옹진군안흥찐빵',
#  '옹진군알곤이찜',
#  '옹진군알곱창',
#  '옹진군알리오올리오',
#  '옹진군알밥',
#  '옹진군알요리',
#  '옹진군알탕',
#  '옹진군앙금빵',
#  '옹진군앙버터',
#  '옹진군애프터눈티',
#  '옹진군애플망고빙수',
#  '옹진군애플파이',
#  '옹진군애호박찌개',
#  '옹진군야끼니꾸',
#  '옹진군야끼도리',
#  '옹진군야끼만두',
#  '옹진군야끼소바',
#  '옹진군야끼소바빵',
#  '옹진군야끼우동',
#  '옹진군야채곱창',
#  '옹진군야채빵',
#  '옹진군야채튀김',
#  '옹진군야채호떡',
#  '옹진군야키니쿠',
#  '옹진군야키도리',
#  '옹진군야키소바',
#  '옹진군야키토리',
#  ...]

# %%
# 음식이름으로 검색
search_list = target

restaurant_df = pd.DataFrame()
date=str(datetime.date.today()).replace('-','')[2:]

for f_name in search_list:
    url = f'https://www.diningcode.com/list.php?query={f_name}'
    
    seed = np.random.randint(100)
    np.random.seed(seed)    
    a = np.random.randint(5)
    time.sleep(a)
    try:
        response = requests.get(url) 
    except:
        print('page error')
        break
        
    data = BeautifulSoup(response.text, 'html.parser')

    # 순위제거(상황봐서 순위 넣으려면 반복문만 주석처리)
    store = [name.text for name in data.select('span.btxt')]
    for i in range(len(store)):
        store[i] = store[i][3:]

    # 주소정보
    summary = [s_mary.text for s_mary in data.select('span.stxt')]
    sub_loca = [sub.text for sub in data.select('i.loca')]
    full_loca = [full_l.text for full_l in data.select('span.ctxt')][1::2]

    # full_loca 중복처리
    try:
        for i in range(len(full_loca)):
            if full_loca[i][0:len(sub_loca[i])] == sub_loca[i]:
                full_loca[i] = full_loca[i][len(sub_loca[i]):]
            else:
                pass
    except: pass
    
    # 카테고리 지정
    category = [f_name] * len(full_loca)
    food_cat = [f_name[3:]] * len(full_loca)
    
    # 점수
    score = [point.text for point in data.select('span.point')]

    cat_df = pd.DataFrame(columns=['category','food_cat','store','score','summary','sub_loca','full_loca'], data=list(zip(category,food_cat,store,score,summary,sub_loca,full_loca)))
    temp = cat_df
    restaurant_df = pd.concat([restaurant_df,temp])
    restaurant_df.index=range(1,len(restaurant_df)+1)
    print(f'{f_name} 크롤링 완료')

print('\n *****크롤링완료*****')

# test
restaurant_df.to_csv(f'/Users/ppangppang/Desktop/맛집리스트확인/{date}_restaurant_list.csv',index=False)

# 데이터저장
restaurant_df.to_csv(f'/Users/ppangppang/Documents/dev/TIL/test_restaurant_data/{date}_restaurant_list.csv',index=False)
# 백업
restaurant_df.to_csv(f'/Users/ppangppang/Desktop/ssac/data_crwaling/restaurant_test/databackup/{date}_restaurant_list.csv',index=False)
# Out:
# 옹진군가라아게 크롤링 완료
# 옹진군가래떡 크롤링 완료
# 옹진군가리국밥 크롤링 완료
# 옹진군가리비 크롤링 완료
# 옹진군가릿국밥 크롤링 완료
# 옹진군가마솥 크롤링 완료
# 옹진군가마솥국밥 크롤링 완료
# 옹진군가마솥밥 크롤링 완료
# 옹진군가마솥설렁탕 크롤링 완료
# 옹진군가마솥순두부 크롤링 완료
# 옹진군가마솥통닭 크롤링 완료
# 옹진군가맥 크롤링 완료
# 옹진군가브리살 크롤링 완료
# 옹진군가스트로펍 크롤링 완료
# 옹진군가오리 크롤링 완료
# 옹진군가자미물회 크롤링 완료
# 옹진군가자미미역국 크롤링 완료
# 옹진군가정식 크롤링 완료
# 옹진군가지그라탕 크롤링 완료
# 옹진군가지덮밥 크롤링 완료
# 옹진군가지볶음 크롤링 완료
# 옹진군가지볶음밥 크롤링 완료
# 옹진군가지튀김 크롤링 완료
# 옹진군가츠나베 크롤링 완료
# 옹진군가츠동 크롤링 완료
# 옹진군가츠산도 크롤링 완료
# 옹진군각재기국 크롤링 완료
# 옹진군간자장 크롤링 완료
# 옹진군간장구이 크롤링 완료
# 옹진군간장덮밥 크롤링 완료
# 옹진군간장새우 크롤링 완료
# 옹진군간재미 크롤링 완료
# 옹진군간짜장 크롤링 완료
# 옹진군갈낙찜 크롤링 완료
# 옹진군갈낙탕 크롤링 완료
# 옹진군갈릭난 크롤링 완료
# 옹진군갈릭돈까스 크롤링 완료
# 옹진군갈릭버거 크롤링 완료
# 옹진군갈릭버터쉬림프 크롤링 완료
# 옹진군갈릭쉬림프 크롤링 완료
# 옹진군갈릭스테이크 크롤링 완료
# 옹진군갈릭페뇨파스타 크롤링 완료
# 옹진군갈매기살 크롤링 완료
# 옹진군갈비 크롤링 완료
# 옹진군갈비국밥 크롤링 완료
# 옹진군갈비국수 크롤링 완료
# 옹진군갈비덮밥 크롤링 완료
# 옹진군갈비만두 크롤링 완료
# 옹진군갈비쌀국수 크롤링 완료
# 옹진군갈비찜 크롤링 완료
# 옹진군갈비탕 크롤링 완료
# 옹진군갈빗살 크롤링 완료
# 옹진군갈추어탕 크롤링 완료
# 옹진군갈치 크롤링 완료
# 옹진군갈치구이 크롤링 완료
# 옹진군갈치국 크롤링 완료
# 옹진군갈치덮밥 크롤링 완료
# 옹진군갈치조림 크롤링 완료
# 옹진군갈치찜 크롤링 완료
# 옹진군갈치회 크롤링 완료
# 옹진군감바스 크롤링 완료
# 옹진군감바스알아히요 크롤링 완료
# 옹진군감베로니 크롤링 완료
# 옹진군감베리크레마 크롤링 완료
# 옹진군감성돔 크롤링 완료
# 옹진군감자고로케 크롤링 완료
# 옹진군감자국 크롤링 완료
# 옹진군감자국수 크롤링 완료
# 옹진군감자뇨끼 크롤링 완료
# 옹진군감자떡 크롤링 완료
# 옹진군감자빵 크롤링 완료
# 옹진군감자수제비 크롤링 완료
# 옹진군감자스프 크롤링 완료
# 옹진군감자옹심이 크롤링 완료
# 옹진군감자전 크롤링 완료
# 옹진군감자탕 크롤링 완료
# 옹진군감자튀김 크롤링 완료
# 옹진군갑오징어 크롤링 완료
# 옹진군강된장 크롤링 완료
# 옹진군강된장비빔밥 크롤링 완료
# 옹진군개스트로펍 크롤링 완료
# 옹진군객주리조림 크롤링 완료
# 옹진군갯장어 크롤링 완료
# 옹진군건강빵 크롤링 완료
# 옹진군건두부볶음 크롤링 완료
# 옹진군검은콩국수 크롤링 완료
# 옹진군게국지 크롤링 완료
# 옹진군게살비빔밥 크롤링 완료
# 옹진군게장 크롤링 완료
# 옹진군간장게장 크롤링 완료
# 옹진군게찜 크롤링 완료
# 옹진군경양식 크롤링 완료
# 옹진군계떡 크롤링 완료
# 옹진군계란김밥 크롤링 완료
# 옹진군계란말이 크롤링 완료
# 옹진군계란찜 크롤링 완료
# 옹진군계란초밥 크롤링 완료
# 옹진군계란토스트 크롤링 완료
# 옹진군고갈비 크롤링 완료
# 옹진군고구마 크롤링 완료
# 옹진군고기국수 크롤링 완료
# 옹진군고기군만두 크롤링 완료
# 옹진군고기만두 크롤링 완료
# 옹진군고기말이 크롤링 완료
# 옹진군고기뷔페 크롤링 완료
# 옹진군고기비빔국수 크롤링 완료
# 옹진군고기완자 크롤링 완료
# 옹진군고기전 크롤링 완료
# 옹진군고기짬뽕 크롤링 완료
# 옹진군고기튀김 크롤링 완료
# 옹진군고등어 크롤링 완료
# 옹진군고로케 크롤링 완료
# 옹진군고르곤졸라 크롤링 완료
# 옹진군고르곤졸라피자 크롤링 완료
# 옹진군고사리육개장 크롤링 완료
# 옹진군고추군만두 크롤링 완료
# 옹진군고추닭튀김 크롤링 완료
# 옹진군고추부각 크롤링 완료
# 옹진군고추장구이 크롤링 완료
# 옹진군고추장불고기 크롤링 완료
# 옹진군고추장불백 크롤링 완료
# 옹진군고추장삼겹살 크롤링 완료
# 옹진군고추장주물럭 크롤링 완료
# 옹진군고추장찌개 크롤링 완료
# 옹진군고추장찜닭 크롤링 완료
# 옹진군고추전 크롤링 완료
# 옹진군고추짜장 크롤링 완료
# 옹진군고추짬뽕 크롤링 완료
# 옹진군고추튀김 크롤링 완료
# 옹진군곤드레 크롤링 완료
# 옹진군곤이 크롤링 완료
# 옹진군골뱅이 크롤링 완료
# 옹진군곰국 크롤링 완료
# 옹진군곰국시 크롤링 완료
# 옹진군곰장어 크롤링 완료
# 옹진군곰장어양념구이 크롤링 완료
# 옹진군곰치국 크롤링 완료
# 옹진군곰탕 크롤링 완료
# 옹진군곱도리탕 크롤링 완료
# 옹진군곱창 크롤링 완료
# 옹진군곱창국수 크롤링 완료
# 옹진군곱창떡볶이 크롤링 완료
# 옹진군곱창모듬 크롤링 완료
# 옹진군곱창볶음 크롤링 완료
# 옹진군곱창순대전골 크롤링 완료
# 옹진군곱창순두부 크롤링 완료
# 옹진군곱창쌀국수 크롤링 완료
# 옹진군곱창전골 크롤링 완료
# 옹진군과메기 크롤링 완료
# 옹진군과일디저트 크롤링 완료
# 옹진군과일에이드 크롤링 완료
# 옹진군과일주스 크롤링 완료
# 옹진군과자점 크롤링 완료
# 옹진군관자구이 크롤링 완료
# 옹진군광동식 크롤링 완료
# 옹진군광양불고기 크롤링 완료
# 옹진군광어 크롤링 완료
# 옹진군광어물회 크롤링 완료
# 옹진군광어세꼬시 크롤링 완료
# 옹진군광어회 크롤링 완료
# 옹진군교자 크롤링 완료
# 옹진군교자만두 크롤링 완료
# 옹진군구운치킨 크롤링 완료
# 옹진군구절판 크롤링 완료
# 옹진군국물닭발 크롤링 완료
# 옹진군국물떡볶이 크롤링 완료
# 옹진군국밥 크롤링 완료
# 옹진군국수 크롤링 완료
# 옹진군국시 크롤링 완료
# 옹진군군만두 크롤링 완료
# 옹진군굴국밥 크롤링 완료
# 옹진군굴림만두 크롤링 완료
# 옹진군굴 크롤링 완료
# 옹진군궁중음식 크롤링 완료
# 옹진군규동 크롤링 완료
# 옹진군규카츠 크롤링 완료
# 옹진군그라탕 크롤링 완료
# 옹진군그리스식 크롤링 완료
# 옹진군그릭요거트 크롤링 완료
# 옹진군그린티 크롤링 완료
# 옹진군그릴드샌드위치 크롤링 완료
# 옹진군근고기 크롤링 완료
# 옹진군기네스 크롤링 완료
# 옹진군기절낙지 크롤링 완료
# 옹진군김말이 크롤링 완료
# 옹진군김밥 크롤링 완료
# 옹진군김치나베 크롤링 완료
# 옹진군김치낙지죽 크롤링 완료
# 옹진군김치덮밥 크롤링 완료
# 옹진군김치돈까스 크롤링 완료
# 옹진군김치돼지찌개 크롤링 완료
# 옹진군김치두루치기 크롤링 완료
# 옹진군김치만두 크롤링 완료
# 옹진군김치만두전골 크롤링 완료
# 옹진군김치말이국수 크롤링 완료
# 옹진군김치보쌈 크롤링 완료
# 옹진군김치볶음밥 크롤링 완료
# 옹진군김치수제비 크롤링 완료
# 옹진군김치순두부 크롤링 완료
# 옹진군김치왕만두 크롤링 완료
# 옹진군김치우동 크롤링 완료
# 옹진군김치전 크롤링 완료
# 옹진군김치전골 크롤링 완료
# 옹진군김치제육볶음 크롤링 완료
# 옹진군김치찌개 크롤링 완료
# 옹진군김치치즈나베 크롤링 완료
# 옹진군김치칼국수 크롤링 완료
# 옹진군김치콩나물국밥 크롤링 완료
# 옹진군까눌레 크롤링 완료
# 옹진군까르보나라 크롤링 완료
# 옹진군까페 크롤링 완료
# 옹진군깍두기볶음밥 크롤링 완료
# 옹진군깐풍기 크롤링 완료
# 옹진군깔조네 크롤링 완료
# 옹진군껍데기 크롤링 완료
# 옹진군꼬들살 크롤링 완료
# 옹진군꼬리곰탕 크롤링 완료
# 옹진군꼬리찜 크롤링 완료
# 옹진군꼬막 크롤링 완료
# 옹진군꼬치 크롤링 완료
# 옹진군꼼장어 크롤링 완료
# 옹진군꽁보리밥 크롤링 완료
# 옹진군꽁치찌개 크롤링 완료
# 옹진군꽃게 크롤링 완료
# 옹진군꽃등심 크롤링 완료
# 옹진군꽃살 크롤링 완료
# 옹진군꽃삼겹 크롤링 완료
# 옹진군꽃새우 크롤링 완료
# 옹진군꽃항정살 크롤링 완료
# 옹진군꽈리고추 크롤링 완료
# 옹진군꽈배기 크롤링 완료
# 옹진군꿀막걸리 크롤링 완료
# 옹진군꿀빵 크롤링 완료
# 옹진군꿀호떡 크롤링 완료
# 옹진군꿔바로우 크롤링 완료
# 옹진군꿩 크롤링 완료
# 옹진군나가사키짬뽕 크롤링 완료
# 옹진군나베 크롤링 완료
# 옹진군나비파이 크롤링 완료
# 옹진군나시고랭 크롤링 완료
# 옹진군나폴리피자 크롤링 완료
# 옹진군낙곱새 크롤링 완료
# 옹진군낙엽살 크롤링 완료
# 옹진군낙지 크롤링 완료
# 옹진군난자완스 크롤링 완료
# 옹진군날치알 크롤링 완료
# 옹진군남도음식 크롤링 완료
# 옹진군남방즈케 크롤링 완료
# 옹진군남아공음식 크롤링 완료
# 옹진군납작만두 크롤링 완료
# 옹진군내장 크롤링 완료
# 옹진군냄비우동 크롤링 완료
# 옹진군냉국수 크롤링 완료
# 옹진군냉동삼겹살 크롤링 완료
# 옹진군냉라면 크롤링 완료
# 옹진군냉면 크롤링 완료
# 옹진군냉모밀 크롤링 완료
# 옹진군냉소바 크롤링 완료
# 옹진군냉우동 크롤링 완료
# 옹진군냉족 크롤링 완료
# 옹진군냉짬뽕 크롤링 완료
# 옹진군냉채족발 크롤링 완료
# 옹진군냉칼국수 크롤링 완료
# 옹진군냉콩국수 크롤링 완료
# 옹진군네팔식 크롤링 완료
# 옹진군노가리 크롤링 완료
# 옹진군녹두빈대떡 크롤링 완료
# 옹진군녹두전 크롤링 완료
# 옹진군뇨끼 크롤링 완료
# 옹진군누들 크롤링 완료
# 옹진군누룽지탕 크롤링 완료
# 옹진군누룽지통닭 크롤링 완료
# 옹진군누텔라 크롤링 완료
# 옹진군눈꽃빙수 크롤링 완료
# 옹진군능이오리 크롤링 완료
# 옹진군니꾸우동 크롤링 완료
# 옹진군다금바리 크롤링 완료
# 옹진군다슬기 크롤링 완료
# 옹진군다이닝펍 크롤링 완료
# 옹진군다찌 크롤링 완료
# 옹진군다코야끼 크롤링 완료
# 옹진군단팥빵 크롤링 완료
# 옹진군단팥죽 크롤링 완료
# 옹진군단호박 크롤링 완료
# 옹진군달걀말이 크롤링 완료
# 옹진군닭가슴살 크롤링 완료
# 옹진군닭갈비 크롤링 완료
# 옹진군닭강정 크롤링 완료
# 옹진군닭개장 크롤링 완료
# 옹진군닭곰탕 크롤링 완료
# 옹진군닭구이 크롤링 완료
# 옹진군닭국수 크롤링 완료
# 옹진군닭껍질 크롤링 완료
# 옹진군닭꼬치 크롤링 완료
# 옹진군닭내장 크롤링 완료
# 옹진군닭다리 크롤링 완료
# 옹진군닭도리탕 크롤링 완료
# 옹진군닭똥집 크롤링 완료
# 옹진군닭목살 크롤링 완료
# 옹진군닭발 크롤링 완료
# 옹진군닭백숙 크롤링 완료
# 옹진군닭볶음탕 크롤링 완료
# 옹진군닭숯불구이 크롤링 완료
# 옹진군닭죽 크롤링 완료
# 옹진군닭칼국수 크롤링 완료
# 옹진군닭한마리 크롤링 완료
# 옹진군당근주스 크롤링 완료
# 옹진군당근케이크 크롤링 완료
# 옹진군대게 크롤링 완료
# 옹진군대구매운탕 크롤링 완료
# 옹진군대구뽈찜 크롤링 완료
# 옹진군대구왕뽈찜 크롤링 완료
# 옹진군대구전골 크롤링 완료
# 옹진군대구탕 크롤링 완료
# 옹진군대나무통밥 크롤링 완료
# 옹진군대만샌드위치 크롤링 완료
# 옹진군대방어 크롤링 완료
# 옹진군대창 크롤링 완료
# 옹진군대통밥 크롤링 완료
# 옹진군대패삼겹살 크롤링 완료
# 옹진군대하 크롤링 완료
# 옹진군대합 크롤링 완료
# 옹진군더덕 크롤링 완료
# 옹진군더블치즈버거 크롤링 완료
# 옹진군더치커피 크롤링 완료
# 옹진군덕자 크롤링 완료
# 옹진군데리야끼막창 크롤링 완료
# 옹진군덴뿌라 크롤링 완료
# 옹진군도가니 크롤링 완료
# 옹진군도넛 크롤링 완료
# 옹진군도다리쑥국 크롤링 완료
# 옹진군도라지정과 크롤링 완료
# 옹진군도래창 크롤링 완료
# 옹진군도로초밥 크롤링 완료
# 옹진군도루묵 크롤링 완료
# 옹진군도리뱅뱅 크롤링 완료
# 옹진군도리아 크롤링 완료
# 옹진군도미 크롤링 완료
# 옹진군도삭면 크롤링 완료
# 옹진군도치알탕 크롤링 완료
# 옹진군도토리 크롤링 완료
# 옹진군독일식레스토랑 크롤링 완료
# 옹진군돈까스 크롤링 완료
# 옹진군돈부리 크롤링 완료
# 옹진군돈치맛살 크롤링 완료
# 옹진군돈코츠 크롤링 완료
# 옹진군돈파스 크롤링 완료
# 옹진군돌게장 크롤링 완료
# 옹진군돌곱창 크롤링 완료
# 옹진군돌문어 크롤링 완료
# 옹진군돌솥밥 크롤링 완료
# 옹진군돌판 크롤링 완료
# 옹진군돔베고기 크롤링 완료
# 옹진군동남아음식 크롤링 완료
# 옹진군동동주 크롤링 완료
# 옹진군동치미막국수 크롤링 완료
# 옹진군동태탕 크롤링 완료
# 옹진군동파육 크롤링 완료
# 옹진군돼지갈비 크롤링 완료
# 옹진군돼지고기탕수육 크롤링 완료
# 옹진군돼지곱창전골 크롤링 완료
# 옹진군돼지국밥 크롤링 완료
# 옹진군돼지김치구이 크롤링 완료
# 옹진군돼지김치찜 크롤링 완료
# 옹진군돼지껍데기 크롤링 완료
# 옹진군돼지꼬리 크롤링 완료
# 옹진군돼지머리고기 크롤링 완료
# 옹진군돼지부속 크롤링 완료
# 옹진군돼지불고기 크롤링 완료
# 옹진군돼지불백 크롤링 완료
# 옹진군돼지양념갈비 크롤링 완료
# 옹진군돼지왕갈비 크롤링 완료
# 옹진군돼지주물럭 크롤링 완료
# 옹진군돼지짜글이 크롤링 완료
# 옹진군돼지특수부위 크롤링 완료
# 옹진군된장국 크롤링 완료
# 옹진군두루치기 크롤링 완료
# 옹진군두부 크롤링 완료
# 옹진군두부버섯전골 크롤링 완료
# 옹진군두부요리전문 크롤링 완료
# 옹진군뒷고기 크롤링 완료
# 옹진군드라이에이징 크롤링 완료
# 옹진군드립커피 크롤링 완료
# 옹진군들기름막국수 크롤링 완료
# 옹진군들깨 크롤링 완료
# 옹진군등갈비 크롤링 완료
# 옹진군등뼈찜 크롤링 완료
# 옹진군등심 크롤링 완료
# 옹진군등심덧살 크롤링 완료
# 옹진군디너코스 크롤링 완료
# 옹진군디저트 크롤링 완료
# 옹진군딤섬 크롤링 완료
# 옹진군따개비칼국수 크롤링 완료
# 옹진군따로국밥 크롤링 완료
# 옹진군딱새우 크롤링 완료
# 옹진군딴딴면 크롤링 완료
# 옹진군딸기막걸리 크롤링 완료
# 옹진군딸기 크롤링 완료
# 옹진군땡초 크롤링 완료
# 옹진군떠먹는피자 크롤링 완료
# 옹진군떡갈비 크롤링 완료
# 옹진군떡국 크롤링 완료
# 옹진군떡볶이 크롤링 완료
# 옹진군떡케이크 크롤링 완료
# 옹진군똠얌쌀국수 크롤링 완료
# 옹진군뚝배기감자탕 크롤링 완료
# 옹진군뚝배기닭볶음탕 크롤링 완료
# 옹진군뚝배기불고기 크롤링 완료
# 옹진군뚱카롱 크롤링 완료
# 옹진군라구파스타 크롤링 완료
# 옹진군라따뚜이 크롤링 완료
# 옹진군라멘 크롤링 완료
# 옹진군라면 크롤링 완료
# 옹진군라볶이 크롤링 완료
# 옹진군라오스음식 크롤링 완료
# 옹진군라자냐 크롤링 완료
# 옹진군라코타치즈샐러드 크롤링 완료
# 옹진군라클렛 크롤링 완료
# 옹진군랍스타 크롤링 완료
# 옹진군랩피자 크롤링 완료
# 옹진군러스크 크롤링 완료
# 옹진군러시아 크롤링 완료
# 옹진군런치코스 크롤링 완료
# 옹진군레드락 크롤링 완료
# 옹진군레모네이드 크롤링 완료
# 옹진군레몬마들렌 크롤링 완료
# 옹진군레몬에이드 크롤링 완료
# 옹진군레몬탕수육 크롤링 완료
# 옹진군레몬티 크롤링 완료
# 옹진군레스토랑 크롤링 완료
# 옹진군레터링케이크 크롤링 완료
# 옹진군로바다야키 크롤링 완료
# 옹진군로스 크롤링 완료
# 옹진군로스트비프 크롤링 완료
# 옹진군로스팅 크롤링 완료
# 옹진군로제떡볶이 크롤링 완료
# 옹진군로제빠네 크롤링 완료
# 옹진군로제찜닭 크롤링 완료
# 옹진군로제파스타 크롤링 완료
# 옹진군롤케이크 크롤링 완료
# 옹진군루꼴라 크롤링 완료
# 옹진군루프탑 크롤링 완료
# 옹진군룽고 크롤링 완료
# 옹진군류산슬 크롤링 완료
# 옹진군리조또 크롤링 완료
# 옹진군리코타치즈샐러드 크롤링 완료
# 옹진군립아이 크롤링 완료
# 옹진군링귀니 크롤링 완료
# 옹진군마구로 크롤링 완료
# 옹진군마늘간장 크롤링 완료
# 옹진군마늘곱창 크롤링 완료
# 옹진군마늘닭 크롤링 완료
# 옹진군마늘떡볶이 크롤링 완료
# 옹진군마늘바게트 크롤링 완료
# 옹진군마늘보쌈 크롤링 완료
# 옹진군마늘볶음밥 크롤링 완료
# 옹진군마늘빵 크롤링 완료
# 옹진군마늘족발 크롤링 완료
# 옹진군마늘치킨 크롤링 완료
# 옹진군마늘탕수육 크롤링 완료
# 옹진군마늘통닭 크롤링 완료
# 옹진군마들렌 크롤링 완료
# 옹진군마라 크롤링 완료
# 옹진군마라샹궈 크롤링 완료
# 옹진군마르게리타 크롤링 완료
# 옹진군마스카포네피자 크롤링 완료
# 옹진군마약김밥 크롤링 완료
# 옹진군마약옥수수 크롤링 완료
# 옹진군마제 크롤링 완료
# 옹진군마카롱 크롤링 완료
# 옹진군마파두부 크롤링 완료
# 옹진군막걸리 크롤링 완료
# 옹진군막국수 크롤링 완료
# 옹진군막창 크롤링 완료
# 옹진군막회 크롤링 완료
# 옹진군만두 크롤링 완료
# 옹진군만두전골 크롤링 완료
# 옹진군말차 크롤링 완료
# 옹진군맑은버섯탕 크롤링 완료
# 옹진군맛감자 크롤링 완료
# 옹진군망고 크롤링 완료
# 옹진군매생이 크롤링 완료
# 옹진군매운갈비찜 크롤링 완료
# 옹진군매운냉면 크롤링 완료
# 옹진군매운닭발 크롤링 완료
# 옹진군매운돈까스 크롤링 완료
# 옹진군매운등갈비 크롤링 완료
# 옹진군매운등뼈찜 크롤링 완료
# 옹진군매운버섯샤브샤브 크롤링 완료
# 옹진군매운부타동 크롤링 완료
# 옹진군매운뼈찜 크롤링 완료
# 옹진군매운오뎅 크롤링 완료
# 옹진군매운족발 크롤링 완료
# 옹진군매운쭈꾸미 크롤링 완료
# 옹진군매운탕 크롤링 완료
# 옹진군매콤불닭 크롤링 완료
# 옹진군매콤크림파스타 크롤링 완료
# 옹진군맥주 크롤링 완료
# 옹진군머릿고기 크롤링 완료
# 옹진군머쉬룸버거 크롤링 완료
# 옹진군머핀 크롤링 완료
# 옹진군먹태 크롤링 완료
# 옹진군멍게 크롤링 완료
# 옹진군멍게비빔밥 크롤링 완료
# 옹진군메기 크롤링 완료
# 옹진군메기매운탕 크롤링 완료
# 옹진군메로구이 크롤링 완료
# 옹진군메론빙수 크롤링 완료
# 옹진군메밀 크롤링 완료
# 옹진군메밀전병 크롤링 완료
# 옹진군멕시칸 크롤링 완료
# 옹진군멘보샤 크롤링 완료
# 옹진군멜란자네 크롤링 완료
# 옹진군멜론빙수 크롤링 완료
# 옹진군멜젓 크롤링 완료
# 옹진군멸치 크롤링 완료
# 옹진군명란 크롤링 완료
# 옹진군명란파스타 크롤링 완료
# 옹진군명이나물 크롤링 완료
# 옹진군명태 크롤링 완료
# 옹진군모나카 크롤링 완료
# 옹진군모던한식 크롤링 완료
# 옹진군모두부 크롤링 완료
# 옹진군모둠구이 크롤링 완료
# 옹진군모둠회 크롤링 완료
# 옹진군모듬사시미 크롤링 완료
# 옹진군모듬수육 크롤링 완료
# 옹진군모듬전 크롤링 완료
# 옹진군모듬조개 크롤링 완료
# 옹진군모듬철판구이 크롤링 완료
# 옹진군모듬초밥 크롤링 완료
# 옹진군모듬튀김 크롤링 완료
# 옹진군모듬해산물 크롤링 완료
# 옹진군모로코 크롤링 완료
# 옹진군모밀 크롤링 완료
# 옹진군모소리살 크롤링 완료
# 옹진군모주 크롤링 완료
# 옹진군모찌리도후 크롤링 완료
# 옹진군모츠나베 크롤링 완료
# 옹진군모카번 크롤링 완료
# 옹진군모히또 크롤링 완료
# 옹진군목등심 크롤링 완료
# 옹진군목살 크롤링 완료
# 옹진군목살필라프 크롤링 완료
# 옹진군목화솜탕수육 크롤링 완료
# 옹진군몸국 크롤링 완료
# 옹진군몽골음식 크롤링 완료
# 옹진군몽블랑 크롤링 완료
# 옹진군무가당 크롤링 완료
# 옹진군무국 크롤링 완료
# 옹진군무뼈닭발 크롤링 완료
# 옹진군무쇠솥밥 크롤링 완료
# 옹진군무지개케이크 크롤링 완료
# 옹진군무침 크롤링 완료
# 옹진군무한리필조개구이 크롤링 완료
# 옹진군무화과 크롤링 완료
# 옹진군묵밥 크롤링 완료
# 옹진군묵은지 크롤링 완료
# 옹진군문어 크롤링 완료
# 옹진군물갈비 크롤링 완료
# 옹진군물곰탕 크롤링 완료
# 옹진군물국수 크롤링 완료
# 옹진군물냉면 크롤링 완료
# 옹진군물닭갈비 크롤링 완료
# 옹진군물막국수 크롤링 완료
# 옹진군물만두 크롤링 완료
# 옹진군물짜장 크롤링 완료
# 옹진군물쫄면 크롤링 완료
# 옹진군물칡냉면 크롤링 완료
# 옹진군물회 크롤링 완료
# 옹진군미고랭 크롤링 완료
# 옹진군미국가정식 크롤링 완료
# 옹진군미국식바베큐 크롤링 완료
# 옹진군미나리 크롤링 완료
# 옹진군미니우동 크롤링 완료
# 옹진군미니족발 크롤링 완료
# 옹진군미숫가루 크롤링 완료
# 옹진군미역국 크롤링 완료
# 옹진군미트볼 크롤링 완료
# 옹진군민물매운탕 크롤링 완료
# 옹진군민물장어 크롤링 완료
# 옹진군민어 크롤링 완료
# 옹진군민트초코 크롤링 완료
# 옹진군밀면 크롤링 완료
# 옹진군밀복 크롤링 완료
# 옹진군밀크빙수 크롤링 완료
# 옹진군밀크티 크롤링 완료
# 옹진군밀키트 크롤링 완료
# 옹진군밀푀유 크롤링 완료
# 옹진군바게트 크롤링 완료
# 옹진군바닐라 크롤링 완료
# 옹진군바다장어 크롤링 완료
# 옹진군바베큐 크롤링 완료
# 옹진군바싹불고기 크롤링 완료
# 옹진군바오 크롤링 완료
# 옹진군바지락 크롤링 완료
# 옹진군박대구이 크롤링 완료
# 옹진군박속 크롤링 완료
# 옹진군반미 크롤링 완료
# 옹진군반상 크롤링 완료
# 옹진군반세오 크롤링 완료
# 옹진군반찬가게 크롤링 완료
# 옹진군발국수 크롤링 완료
# 옹진군발리음식 크롤링 완료
# 옹진군밤라떼 크롤링 완료
# 옹진군밤식빵 크롤링 완료
# 옹진군밥버거 크롤링 완료
# 옹진군방어 크롤링 완료
# 옹진군백골뱅이탕 크롤링 완료
# 옹진군백반 크롤링 완료
# 옹진군백숙 크롤링 완료
# 옹진군백순대 크롤링 완료
# 옹진군백짬뽕 크롤링 완료
# 옹진군백차 크롤링 완료
# 옹진군백합죽 크롤링 완료
# 옹진군밴댕이회 크롤링 완료
# 옹진군뱅쇼 크롤링 완료
# 옹진군버거 크롤링 완료
# 옹진군버블티 크롤링 완료
# 옹진군버섯두부전골 크롤링 완료
# 옹진군버섯매운탕 크롤링 완료
# 옹진군버섯샤브 크롤링 완료
# 옹진군버섯전골 크롤링 완료
# 옹진군버섯탕수 크롤링 완료
# 옹진군버터갈릭감자튀김 크롤링 완료
# 옹진군버터난 크롤링 완료
# 옹진군버터밀크 크롤링 완료
# 옹진군번데기 크롤링 완료
# 옹진군벌집껍데기 크롤링 완료
# 옹진군벚꽃빙수 크롤링 완료
# 옹진군베이글 크롤링 완료
# 옹진군베이징덕 크롤링 완료
# 옹진군베이커리 크롤링 완료
# 옹진군베이컨 크롤링 완료
# 옹진군베트남쌀국수 크롤링 완료
# 옹진군베트남연유커피 크롤링 완료
# 옹진군벤또 크롤링 완료
# 옹진군벨기에와플 크롤링 완료
# 옹진군병어 크롤링 완료
# 옹진군병천순대 크롤링 완료
# 옹진군보리굴비 크롤링 완료
# 옹진군보리밥 크롤링 완료
# 옹진군보리새우 크롤링 완료
# 옹진군보말죽 크롤링 완료
# 옹진군보신탕 크롤링 완료
# 옹진군보쌈 크롤링 완료
# 옹진군보이차 크롤링 완료
# 옹진군복국 크롤링 완료
# 옹진군복숭아아이스티 크롤링 완료
# 옹진군복집 크롤링 완료
# 옹진군볶음국수 크롤링 완료
# 옹진군볶음밥 크롤링 완료
# 옹진군볶음짜장 크롤링 완료
# 옹진군볶음짬뽕 크롤링 완료
# 옹진군봉골레 크롤링 완료
# 옹진군부각 크롤링 완료
# 옹진군부대볶음 크롤링 완료
# 옹진군부대전골 크롤링 완료
# 옹진군부대찌개 크롤링 완료
# 옹진군부산오뎅 크롤링 완료
# 옹진군부채살 크롤링 완료
# 옹진군부추전 크롤링 완료
# 옹진군부타동 크롤링 완료
# 옹진군부페 크롤링 완료
# 옹진군북경오리 크롤링 완료
# 옹진군북어국 크롤링 완료
# 옹진군북유럽 크롤링 완료
# 옹진군북한음식 크롤링 완료
# 옹진군분식 크롤링 완료
# 옹진군분짜 크롤링 완료
# 옹진군불갈비 크롤링 완료
# 옹진군불고기 크롤링 완료
# 옹진군불낙전골 크롤링 완료
# 옹진군불닭 크롤링 완료
# 옹진군불도장 크롤링 완료
# 옹진군불막창 크롤링 완료
# 옹진군불맛쭈꾸미 크롤링 완료
# 옹진군불백 크롤링 완료
# 옹진군불오징어 크롤링 완료
# 옹진군불족발 크롤링 완료
# 옹진군불짜장 크롤링 완료
# 옹진군불짬뽕 크롤링 완료
# 옹진군불쭈꾸미 크롤링 완료
# 옹진군불향낙지 크롤링 완료
# 옹진군붓카케우동 크롤링 완료
# 옹진군붕장어 크롤링 완료
# 옹진군브라우니 크롤링 완료
# 옹진군브라질 크롤링 완료
# 옹진군브런치 크롤링 완료
# 옹진군브리또 크롤링 완료
# 옹진군블랙티 크롤링 완료
# 옹진군블루베리 크롤링 완료
# 옹진군비건 크롤링 완료
# 옹진군비빔국수 크롤링 완료
# 옹진군비빔냉면 크롤링 완료
# 옹진군비빔막국수 크롤링 완료
# 옹진군비빔만두 크롤링 완료
# 옹진군비빔메밀 크롤링 완료
# 옹진군비빔면 크롤링 완료
# 옹진군비빔밥 크롤링 완료
# 옹진군비빔손칼국수 크롤링 완료
# 옹진군비빔쫄면 크롤링 완료
# 옹진군비빔칼국수 크롤링 완료
# 옹진군비스마르크 크롤링 완료
# 옹진군비스트로 크롤링 완료
# 옹진군비엔나커피 크롤링 완료
# 옹진군비지찌개 크롤링 완료
# 옹진군비프 크롤링 완료
# 옹진군빈대떡 크롤링 완료
# 옹진군빙수 크롤링 완료
# 옹진군빙어튀김 크롤링 완료
# 옹진군빠가탕 크롤링 완료
# 옹진군빠네 크롤링 완료
# 옹진군빠에야 크롤링 완료
# 옹진군빨간오뎅 크롤링 완료
# 옹진군빨계떡 크롤링 완료
# 옹진군빵집 크롤링 완료
# 옹진군뻥튀기 크롤링 완료
# 옹진군뼈감자탕 크롤링 완료
# 옹진군뼈닭발 크롤링 완료
# 옹진군뼈없는닭발 크롤링 완료
# 옹진군뼈찜 크롤링 완료
# 옹진군뼈해장국 크롤링 완료
# 옹진군뽈살 크롤링 완료
# 옹진군뽈찜 크롤링 완료
# 옹진군사골곰탕 크롤링 완료
# 옹진군사라다빵 크롤링 완료
# 옹진군사시미 크롤링 완료
# 옹진군사이공라떼 크롤링 완료
# 옹진군사찰음식 크롤링 완료
# 옹진군사천 크롤링 완료
# 옹진군사철탕 크롤링 완료
# 옹진군사케 크롤링 완료
# 옹진군산꼼장어 크롤링 완료
# 옹진군산나물 크롤링 완료
# 옹진군산낙지 크롤링 완료
# 옹진군산닭구이 크롤링 완료
# 옹진군산미구엘 크롤링 완료
# 옹진군산삼배양근삼계탕 크롤링 완료
# 옹진군산야초 크롤링 완료
# 옹진군산오징어 크롤링 완료
# 옹진군산채백반 크롤링 완료
# 옹진군산채비빔밥 크롤링 완료
# 옹진군산채정식 크롤링 완료
# 옹진군살얼음맥주 크롤링 완료
# 옹진군살치살 크롤링 완료
# 옹진군삼각갈비 크롤링 완료
# 옹진군삼겹살 크롤링 완료
# 옹진군삼계탕 크롤링 완료
# 옹진군삼색전 크롤링 완료
# 옹진군삼선고추짬뽕 크롤링 완료
# 옹진군삼선짬뽕 크롤링 완료
# 옹진군삼숙이탕 크롤링 완료
# 옹진군삼치 크롤링 완료
# 옹진군삼합 크롤링 완료
# 옹진군상추튀김 크롤링 완료
# 옹진군상황버섯 크롤링 완료
# 옹진군새알팥죽 크롤링 완료
# 옹진군새우 크롤링 완료
# 옹진군새우튀김 크롤링 완료
# 옹진군새우필라프 크롤링 완료
# 옹진군새조개샤브샤브 크롤링 완료
# 옹진군샌드위치 크롤링 완료
# 옹진군샐러드 크롤링 완료
# 옹진군샘플러 크롤링 완료
# 옹진군생간 크롤링 완료
# 옹진군생갈비 크롤링 완료
# 옹진군생고기 크롤링 완료
# 옹진군생과일주스 크롤링 완료
# 옹진군생국수 크롤링 완료
# 옹진군생굴 크롤링 완료
# 옹진군생대구탕 크롤링 완료
# 옹진군생도넛 크롤링 완료
# 옹진군생돈까스 크롤링 완료
# 옹진군생맥주 크롤링 완료
# 옹진군생선구이 크롤링 완료
# 옹진군생선까스 크롤링 완료
# 옹진군생연어 크롤링 완료
# 옹진군생오겹살 크롤링 완료
# 옹진군생오리 크롤링 완료
# 옹진군생크림케이크 크롤링 완료
# 옹진군생태찌개 크롤링 완료
# 옹진군샤브샤브 크롤링 완료
# 옹진군샤오롱바오 크롤링 완료
# 옹진군샤퀴테리 크롤링 완료
# 옹진군샴페인 크롤링 완료
# 옹진군서리태콩국수 크롤링 완료
# 옹진군석갈비 크롤링 완료
# 옹진군석쇠구이 크롤링 완료
# 옹진군섞어찌개 크롤링 완료
# 옹진군선술집 크롤링 완료
# 옹진군선지국 크롤링 완료
# 옹진군설기떡 크롤링 완료
# 옹진군설농탕 크롤링 완료
# 옹진군설렁탕 크롤링 완료
# 옹진군섭죽 크롤링 완료
# 옹진군섭해장국 크롤링 완료
# 옹진군성게 크롤링 완료
# 옹진군세꼬시 크롤링 완료
# 옹진군세발낙지 크롤링 완료
# 옹진군세숫대야냉면 크롤링 완료
# 옹진군세이로무시 크롤링 완료
# 옹진군센베 크롤링 완료
# 옹진군소갈매기 크롤링 완료
# 옹진군소갈비 크롤링 완료
# 옹진군소고기무국 크롤링 완료
# 옹진군소고기전골 크롤링 완료
# 옹진군소고기짬뽕 크롤링 완료
# 옹진군소고기편백찜 크롤링 완료
# 옹진군소고기해장국 크롤링 완료
# 옹진군소곱창 크롤링 완료
# 옹진군소금구이 크롤링 완료
# 옹진군소금아이스크림 크롤링 완료
# 옹진군소금커피 크롤링 완료
# 옹진군소꼬리찜 크롤링 완료
# 옹진군소라숙회 크롤링 완료
# 옹진군소룡포 크롤링 완료
# 옹진군소머리국밥 크롤링 완료
# 옹진군소머리수육 크롤링 완료
# 옹진군소바 크롤링 완료
# 옹진군소보로 크롤링 완료
# 옹진군소불고기 크롤링 완료
# 옹진군소불백 크롤링 완료
# 옹진군소뼈해장국 크롤링 완료
# 옹진군소세지 크롤링 완료
# 옹진군소양념갈비 크롤링 완료
# 옹진군손두부 크롤링 완료
# 옹진군손만두 크롤링 완료
# 옹진군손수제비 크롤링 완료
# 옹진군손짜장 크롤링 완료
# 옹진군손칼국수 크롤링 완료
# 옹진군솔트커피 크롤링 완료
# 옹진군송어 크롤링 완료
# 옹진군송이버섯 크롤링 완료
# 옹진군솥뚜껑삼겹살 크롤링 완료
# 옹진군솥밥 크롤링 완료
# 옹진군쇼가야끼 크롤링 완료
# 옹진군쇼콜라 크롤링 완료
# 옹진군수라상 크롤링 완료
# 옹진군수박쥬스 크롤링 완료
# 옹진군수산물 크롤링 완료
# 옹진군수원왕갈비 크롤링 완료
# 옹진군수육 크롤링 완료
# 옹진군수육국밥 크롤링 완료
# 옹진군수입맥주 크롤링 완료
# 옹진군수정과 크롤링 완료
# 옹진군수제꼬치 크롤링 완료
# 옹진군수제도시락 크롤링 완료
# 옹진군수제돈까스 크롤링 완료
# 옹진군수제두부 크롤링 완료
# 옹진군수제등심돈까스 크롤링 완료
# 옹진군수제맥주 크롤링 완료
# 옹진군수제버거 크롤링 완료
# 옹진군수제비 크롤링 완료
# 옹진군수제아이스크림 크롤링 완료
# 옹진군수제양갱 크롤링 완료
# 옹진군수제와플 크롤링 완료
# 옹진군수제청 크롤링 완료
# 옹진군수제초콜릿 크롤링 완료
# 옹진군수제케이크 크롤링 완료
# 옹진군수제티라미수 크롤링 완료
# 옹진군수제햄버거 크롤링 완료
# 옹진군수타면 크롤링 완료
# 옹진군수타짜장 크롤링 완료
# 옹진군수프 크롤링 완료
# 옹진군수플레 크롤링 완료
# 옹진군숙성돼지고기 크롤링 완료
# 옹진군숙성등심 크롤링 완료
# 옹진군숙성목살 크롤링 완료
# 옹진군숙성삼겹살 크롤링 완료
# 옹진군숙성생삼겹살 크롤링 완료
# 옹진군숙성오겹살 크롤링 완료
# 옹진군숙성통삼겹살 크롤링 완료
# 옹진군숙성한우 크롤링 완료
# 옹진군숙성한우등심 크롤링 완료
# 옹진군숙성회 크롤링 완료
# 옹진군순대 크롤링 완료
# 옹진군순대볶음 크롤링 완료
# 옹진군순대전골 크롤링 완료
# 옹진군순두부 크롤링 완료
# 옹진군순메밀 크롤링 완료
# 옹진군순무김치 크롤링 완료
# 옹진군순살강정 크롤링 완료
# 옹진군술떡 크롤링 완료
# 옹진군술찜 크롤링 완료
# 옹진군숯불 크롤링 완료
# 옹진군숯불꼼장어 크롤링 완료
# 옹진군쉐이크 크롤링 완료
# 옹진군쉬림프버거 크롤링 완료
# 옹진군슈니첼 크롤링 완료
# 옹진군슈마이 크롤링 완료
# 옹진군슈크림 크롤링 완료
# 옹진군슈톨렌 크롤링 완료
# 옹진군슈하스코 크롤링 완료
# 옹진군스끼야끼 크롤링 완료
# 옹진군스몰비어 크롤링 완료
# 옹진군스무디 크롤링 완료
# 옹진군스시 크롤링 완료
# 옹진군스시뷔페 크롤링 완료
# 옹진군스위스식 크롤링 완료
# 옹진군스지수육 크롤링 완료
# 옹진군스지오뎅탕 크롤링 완료
# 옹진군스콘 크롤링 완료
# 옹진군스키야끼 크롤링 완료
# 옹진군스테이크 크롤링 완료
# 옹진군스테이크덮밥 크롤링 완료
# 옹진군스테이크피자 크롤링 완료
# 옹진군스테키동 크롤링 완료
# 옹진군스텔라 크롤링 완료
# 옹진군스튜 크롤링 완료
# 옹진군스파게티 크롤링 완료
# 옹진군스팸 크롤링 완료
# 옹진군스페인식 크롤링 완료
# 옹진군스프 크롤링 완료
# 옹진군스프링롤 크롤링 완료
# 옹진군슬로푸드 크롤링 완료
# 옹진군시골밥상 크롤링 완료
# 옹진군시금치 크롤링 완료
# 옹진군시래기 크롤링 완료
# 옹진군시저샐러드 크롤링 완료
# 옹진군시카고피자 크롤링 완료
# 옹진군시푸드 크롤링 완료
# 옹진군식빵 크롤링 완료
# 옹진군식육식당 크롤링 완료
# 옹진군식혜 크롤링 완료
# 옹진군신선로 크롤링 완료
# 옹진군신쭈꾸미 크롤링 완료
# 옹진군실내포장마차 크롤링 완료
# 옹진군실비집 크롤링 완료
# 옹진군심야식당 크롤링 완료
# 옹진군싱가폴 크롤링 완료
# 옹진군싱글몰트 크롤링 완료
# 옹진군쌀국수 크롤링 완료
# 옹진군쌀떡볶이 크롤링 완료
# 옹진군쌀빵 크롤링 완료
# 옹진군쌀케이크 크롤링 완료
# 옹진군쌀통닭 크롤링 완료
# 옹진군쌈밥 크롤링 완료
# 옹진군쌍화차 크롤링 완료
# 옹진군쏘가리매운탕 크롤링 완료
# 옹진군쏘세지 크롤링 완료
# 옹진군쑥라떼 크롤링 완료
# 옹진군쑥인절미 크롤링 완료
# 옹진군쑥차 크롤링 완료
# 옹진군씨앗호떡 크롤링 완료
# 옹진군씨푸드 크롤링 완료
# 옹진군아강발 크롤링 완료
# 옹진군아게다시도후 크롤링 완료
# 옹진군아구찜 크롤링 완료
# 옹진군아구탕 크롤링 완료
# 옹진군아나고 크롤링 완료
# 옹진군아란치니 크롤링 완료
# 옹진군아롱사태 크롤링 완료
# 옹진군아메리칸치즈버거 크롤링 완료
# 옹진군아몬드크림라떼 크롤링 완료
# 옹진군아바이순대 크롤링 완료
# 옹진군아보카도 크롤링 완료
# 옹진군아부라소바 크롤링 완료
# 옹진군아시안푸드 크롤링 완료
# 옹진군아이리쉬커피 크롤링 완료
# 옹진군아이리쉬펍 크롤링 완료
# 옹진군아이스모찌 크롤링 완료
# 옹진군아이스크림 크롤링 완료
# 옹진군아이스티 크롤링 완료
# 옹진군아인슈페너 크롤링 완료
# 옹진군아포카토 크롤링 완료
# 옹진군안동국시 크롤링 완료
# 옹진군안동찜닭 크롤링 완료
# 옹진군안심돈까스 크롤링 완료
# 옹진군안심스테이크 크롤링 완료
# 옹진군안심탕수육 크롤링 완료
# 옹진군안심파스타 크롤링 완료
# 옹진군안창살 크롤링 완료
# 옹진군안흥찐빵 크롤링 완료
# 옹진군알곤이찜 크롤링 완료
# 옹진군알곱창 크롤링 완료
# 옹진군알리오올리오 크롤링 완료
# 옹진군알밥 크롤링 완료
# 옹진군알요리 크롤링 완료
# 옹진군알탕 크롤링 완료
# 옹진군앙금빵 크롤링 완료
# 옹진군앙버터 크롤링 완료
# 옹진군애프터눈티 크롤링 완료
# 옹진군애플망고빙수 크롤링 완료
# 옹진군애플파이 크롤링 완료
# 옹진군애호박찌개 크롤링 완료
# 옹진군야끼니꾸 크롤링 완료
# 옹진군야끼도리 크롤링 완료
# 옹진군야끼만두 크롤링 완료
# 옹진군야끼소바 크롤링 완료
# 옹진군야끼소바빵 크롤링 완료
# 옹진군야끼우동 크롤링 완료
# 옹진군야채곱창 크롤링 완료
# 옹진군야채빵 크롤링 완료
# 옹진군야채튀김 크롤링 완료
# 옹진군야채호떡 크롤링 완료
# 옹진군야키니쿠 크롤링 완료
# 옹진군야키도리 크롤링 완료
# 옹진군야키소바 크롤링 완료
# 옹진군야키토리 크롤링 완료
# 옹진군약과 크롤링 완료
# 옹진군약초밥 크롤링 완료
# 옹진군양갈비 크롤링 완료
# 옹진군양고기 크롤링 완료
# 옹진군양곱창 크롤링 완료
# 옹진군양꼬치 크롤링 완료
# 옹진군양념갈비 크롤링 완료
# 옹진군양념게장 크롤링 완료
# 옹진군양념곱창구이 크롤링 완료
# 옹진군양념구이 크롤링 완료
# 옹진군양념막창 크롤링 완료
# 옹진군양념막창구이 크롤링 완료
# 옹진군양념삼겹살 크롤링 완료
# 옹진군양념오뎅 크롤링 완료
# 옹진군양념족발 크롤링 완료
# 옹진군양념치킨 크롤링 완료
# 옹진군양다리 크롤링 완료
# 옹진군양대창 크롤링 완료
# 옹진군양밥 크롤링 완료
# 옹진군양선지해장국 크롤링 완료
# 옹진군양식 크롤링 완료
# 옹진군양장피 크롤링 완료
# 옹진군양지곰탕 크롤링 완료
# 옹진군양지쌀국수 크롤링 완료
# 옹진군양푼갈비 크롤링 완료
# 옹진군어니언링 크롤링 완료
# 옹진군어란파스타 크롤링 완료
# 옹진군어리굴젓 크롤링 완료
# 옹진군어만두 크롤링 완료
# 옹진군어묵 크롤링 완료
# 옹진군어묵고로케 크롤링 완료
# 옹진군어묵탕 크롤링 완료
# 옹진군어복쟁반 크롤링 완료
# 옹진군어죽 크롤링 완료
# 옹진군어탕국수 크롤링 완료
# 옹진군어향가지 크롤링 완료
# 옹진군어향동고 크롤링 완료
# 옹진군언양불고기 크롤링 완료
# 옹진군얼그레이 크롤링 완료
# 옹진군얼큰곰탕 크롤링 완료
# 옹진군얼큰라면 크롤링 완료
# 옹진군얼큰설렁탕 크롤링 완료
# 옹진군얼큰수제비 크롤링 완료
# 옹진군얼큰순두부 크롤링 완료
# 옹진군얼큰칼국수 크롤링 완료
# 옹진군얼큰탕 크롤링 완료
# 옹진군엄나무백숙 크롤링 완료
# 옹진군에그마요 크롤링 완료
# 옹진군에그베네딕트 크롤링 완료
# 옹진군에그타르트 크롤링 완료
# 옹진군에그토스트 크롤링 완료
# 옹진군에끌레르 크롤링 완료
# 옹진군에비동 크롤링 완료
# 옹진군에비텐동 크롤링 완료
# 옹진군에클레어 크롤링 완료
# 옹진군엔초비파스타 크롤링 완료
# 옹진군연어 크롤링 완료
# 옹진군연어덮밥 크롤링 완료
# 옹진군연어롤 크롤링 완료
# 옹진군연어무한리필 크롤링 완료
# 옹진군연어사시미 크롤링 완료
# 옹진군연어샌드위치 크롤링 완료
# 옹진군연어샐러드 크롤링 완료
# 옹진군연어전문 크롤링 완료
# 옹진군연어초밥 크롤링 완료
# 옹진군연어회 크롤링 완료
# 옹진군연잎밥 크롤링 완료
# 옹진군연탄불고기 크롤링 완료
# 옹진군연탄불백 크롤링 완료
# 옹진군연포탕 크롤링 완료
# 옹진군열무 크롤링 완료
# 옹진군염소 크롤링 완료
# 옹진군염통꼬치 크롤링 완료
# 옹진군영국요리 크롤링 완료
# 옹진군영양굴밥 크롤링 완료
# 옹진군영양돌솥 크롤링 완료
# 옹진군영양삼계탕 크롤링 완료
# 옹진군영양탕 크롤링 완료
# 옹진군옛날도시락 크롤링 완료
# 옹진군옛날떡볶이 크롤링 완료
# 옹진군옛날순대 크롤링 완료
# 옹진군옛날왕돈까스 크롤링 완료
# 옹진군옛날우동 크롤링 완료
# 옹진군옛날짜장 크롤링 완료
# 옹진군옛날통닭 크롤링 완료
# 옹진군오가닉 크롤링 완료
# 옹진군오겹살 크롤링 완료
# 옹진군오골계 크롤링 완료
# 옹진군오꼬노미야끼 크롤링 완료
# 옹진군오뎅 크롤링 완료
# 옹진군오돌뼈 크롤링 완료
# 옹진군오드레기 크롤링 완료
# 옹진군오디 크롤링 완료
# 옹진군오리 크롤링 완료
# 옹진군오리로스 크롤링 완료
# 옹진군오리백숙 크롤링 완료
# 옹진군오리샤브샤브 크롤링 완료
# 옹진군오리주물럭 크롤링 완료
# 옹진군오리진흙구이 크롤링 완료
# 옹진군오리탕 크롤링 완료
# 옹진군오리한마리 크롤링 완료
# 옹진군오리훈제 크롤링 완료
# 옹진군오마카세 크롤링 완료
# 옹진군오메기떡 크롤링 완료
# 옹진군오므라이스 크롤링 완료
# 옹진군오믈렛 크롤링 완료
# 옹진군오븐스파게티 크롤링 완료
# 옹진군오삼불고기 크롤링 완료
# 옹진군오소리 크롤링 완료
# 옹진군오야꼬동 크롤링 완료
# 옹진군오이무침 크롤링 완료
# 옹진군오징어두루치기 크롤링 완료
# 옹진군오징어먹물빠에야 크롤링 완료
# 옹진군오징어무침 크롤링 완료
# 옹진군오징어물회 크롤링 완료
# 옹진군오징어볶음 크롤링 완료
# 옹진군오징어순대 크롤링 완료
# 옹진군오징어입 크롤링 완료
# 옹진군오징어짬뽕 크롤링 완료
# 옹진군오징어초무침 크롤링 완료
# 옹진군오징어튀김 크롤링 완료
# 옹진군오징어회 크롤링 완료
# 옹진군오코노미야끼 크롤링 완료
# 옹진군오향장육 크롤링 완료
# 옹진군오향족발 크롤링 완료
# 옹진군옥돔 크롤링 완료
# 옹진군옥수수빵 크롤링 완료
# 옹진군온면 크롤링 완료
# 옹진군온소바 크롤링 완료
# 옹진군올갱이 크롤링 완료
# 옹진군올챙이국수 크롤링 완료
# 옹진군옹심이 크롤링 완료
# 옹진군옻닭 크롤링 완료
# 옹진군와규 크롤링 완료
# 옹진군와인바 크롤링 완료
# 옹진군와인삼겹살 크롤링 완료
# 옹진군와플 크롤링 완료
# 옹진군완당 크롤링 완료
# 옹진군완탕면 크롤링 완료
# 옹진군왕갈비 크롤링 완료
# 옹진군왕돈까스 크롤링 완료
# 옹진군왕만두 크롤링 완료
# 옹진군왕새우튀김 크롤링 완료
# 옹진군왕새우팟타이 크롤링 완료
# 옹진군왕소금구이 크롤링 완료
# 옹진군왕순대 크롤링 완료
# 옹진군왕족발 크롤링 완료
# 옹진군왕짬뽕 크롤링 완료
# 옹진군요거트 크롤링 완료
# 옹진군우거지 크롤링 완료
# 옹진군우거지해장국 크롤링 완료
# 옹진군우니파스타 크롤링 완료
# 옹진군우동 크롤링 완료
# 옹진군우럭 크롤링 완료
# 옹진군우럭매운탕 크롤링 완료
# 옹진군우렁된장 크롤링 완료
# 옹진군우렁쌈밥 크롤링 완료
# 옹진군우렁제육쌈밥 크롤링 완료
# 옹진군우렁추어탕 크롤링 완료
# 옹진군우삼겹 크롤링 완료
# 옹진군우삼겹부대찌개 크롤링 완료
# 옹진군우엉밥 크롤링 완료
# 옹진군우유빙수 크롤링 완료
# 옹진군우육면 크롤링 완료
# 옹진군우족 크롤링 완료
# 옹진군우즈베키스탄 크롤링 완료
# 옹진군월남쌈 크롤링 완료
# 옹진군월병 크롤링 완료
# 옹진군웨지포테이토 크롤링 완료
# 옹진군웰빙뷔페 크롤링 완료
# 옹진군위스키 크롤링 완료
# 옹진군유니짜장 크롤링 완료
# 옹진군유린기 크롤링 완료
# 옹진군유부초밥 크롤링 완료
# 옹진군유케동 크롤링 완료
# 옹진군육개장 크롤링 완료
# 옹진군육사시미 크롤링 완료
# 옹진군육전 크롤링 완료
# 옹진군육칼 크롤링 완료
# 옹진군육칼국수 크롤링 완료
# 옹진군육회 크롤링 완료
# 옹진군은갈치조림 크롤링 완료
# 옹진군은복국 크롤링 완료
# 옹진군이동갈비 크롤링 완료
# 옹진군이베리코 크롤링 완료
# 옹진군이북식 크롤링 완료
# 옹진군이시가리 크롤링 완료
# 옹진군이자카야 크롤링 완료
# 옹진군이집트 크롤링 완료
# 옹진군이탈리안 크롤링 완료
# 옹진군이태리 크롤링 완료
# 옹진군인도네시아 크롤링 완료
# 옹진군인도요리 크롤링 완료
# 옹진군인도카레 크롤링 완료
# 옹진군인삼주 크롤링 완료
# 옹진군인절미 크롤링 완료
# 옹진군일본라면 크롤링 완료
# 옹진군일본식 크롤링 완료
# 옹진군일식당 크롤링 완료
# 옹진군일식집 크롤링 완료
# 옹진군임연수 크롤링 완료
# 옹진군잉글리쉬머핀 크롤링 완료
# 옹진군자루우동 크롤링 완료
# 옹진군자연산회 크롤링 완료
# 옹진군잔치국수 크롤링 완료
# 옹진군잠발라야 크롤링 완료
# 옹진군잠봉뵈르 크롤링 완료
# 옹진군잡어 크롤링 완료
# 옹진군잡채 크롤링 완료
# 옹진군잣두부구이 크롤링 완료
# 옹진군장미주 크롤링 완료
# 옹진군장어 크롤링 완료
# 옹진군장작구이 크롤링 완료
# 옹진군장조림 크롤링 완료
# 옹진군장치찜 크롤링 완료
# 옹진군장칼국수 크롤링 완료
# 옹진군장터국밥 크롤링 완료
# 옹진군재첩 크롤링 완료
# 옹진군쟁반국수 크롤링 완료
# 옹진군쟁반짜장 크롤링 완료
# 옹진군전골 크롤링 완료
# 옹진군전기구이 크롤링 완료
# 옹진군전라도음식 크롤링 완료
# 옹진군전복 크롤링 완료
# 옹진군전어 크롤링 완료
# 옹진군전주가맥 크롤링 완료
# 옹진군전주콩나물국밥 크롤링 완료
# 옹진군전통주 크롤링 완료
# 옹진군전통차 크롤링 완료
# 옹진군접짝뼈국 크롤링 완료
# 옹진군젓갈볶음밥 크롤링 완료
# 옹진군젓국갈비 크롤링 완료
# 옹진군정육식당 크롤링 완료
# 옹진군제과점 크롤링 완료
# 옹진군제비추리 크롤링 완료
# 옹진군제육 크롤링 완료
# 옹진군제주근고기 크롤링 완료
# 옹진군제주돼지 크롤링 완료
# 옹진군제주오겹살 크롤링 완료
# 옹진군젤라또 크롤링 완료
# 옹진군젤리 크롤링 완료
# 옹진군조개 크롤링 완료
# 옹진군족발 크롤링 완료
# 옹진군존슨탕 크롤링 완료
# 옹진군주꾸미 크롤링 완료
# 옹진군주말브런치 크롤링 완료
# 옹진군주먹고기 크롤링 완료
# 옹진군주먹밥 크롤링 완료
# 옹진군주물럭 크롤링 완료
# 옹진군죽전문 크롤링 완료
# 옹진군죽집 크롤링 완료
# 옹진군중국레스토랑 크롤링 완료
# 옹진군중식 크롤링 완료
# 옹진군중화비빔밥 크롤링 완료
# 옹진군중화요리 크롤링 완료
# 옹진군쥐치조림 크롤링 완료
# 옹진군즉석떡볶이 크롤링 완료
# 옹진군즉석튀김 크롤링 완료
# 옹진군지도리우동 크롤링 완료
# 옹진군지리탕 크롤링 완료
# 옹진군지삼선 크롤링 완료
# 옹진군지중해식 크롤링 완료
# 옹진군지짐만두 크롤링 완료
# 옹진군지평막걸리 크롤링 완료
# 옹진군직화구이 크롤링 완료
# 옹진군진주비빔밥 크롤링 완료
# 옹진군진흙구이 크롤링 완료
# 옹진군짜계치 크롤링 완료
# 옹진군짜글이 크롤링 완료
# 옹진군짜장떡볶이 크롤링 완료
# 옹진군짜파구리 크롤링 완료
# 옹진군짝태 크롤링 완료
# 옹진군짬뽕 크롤링 완료
# 옹진군짬짜면 크롤링 완료
# 옹진군짱뚱어 크롤링 완료
# 옹진군쪽갈비 크롤링 완료
# 옹진군쫀드기 크롤링 완료
# 옹진군쫄면 크롤링 완료
# 옹진군쫄뱅이 크롤링 완료
# 옹진군쭈곱새 크롤링 완료
# 옹진군쭈꾸미 크롤링 완료
# 옹진군쭈삼 크롤링 완료
# 옹진군찐빵 크롤링 완료
# 옹진군찜닭 크롤링 완료
# 옹진군차돌구이 크롤링 완료
# 옹진군차돌된장 크롤링 완료
# 옹진군차돌떡볶이 크롤링 완료
# 옹진군차돌막장찌개 크롤링 완료
# 옹진군차돌박이 크롤링 완료
# 옹진군차돌삼합 크롤링 완료
# 옹진군차돌쌀국수 크롤링 완료
# 옹진군차돌양지쌀국수 크롤링 완료
# 옹진군차돌우삼겹 크롤링 완료
# 옹진군차돌육개장 크롤링 완료
# 옹진군차돌짬뽕 크롤링 완료
# 옹진군차슈덮밥 크롤링 완료
# 옹진군착즙주스 크롤링 완료
# 옹진군찰밥 크롤링 완료
# 옹진군참가자미미역국 크롤링 완료
# 옹진군참게 크롤링 완료
# 옹진군참다랑어뱃살 크롤링 완료
# 옹진군참복 크롤링 완료
# 옹진군참새구이 크롤링 완료
# 옹진군참소라 크롤링 완료
# 옹진군참숯바베큐 크롤링 완료
# 옹진군참치 크롤링 완료
# 옹진군참치김치찌개 크롤링 완료
# 옹진군참치마요컵밥 크롤링 완료
# 옹진군참치무한리필 크롤링 완료
# 옹진군참치찌개 크롤링 완료
# 옹진군참치타다끼 크롤링 완료
# 옹진군참치회 크롤링 완료
# 옹진군찹스테이크 크롤링 완료
# 옹진군찹쌀꽈배기 크롤링 완료
# 옹진군찹쌀도너츠 크롤링 완료
# 옹진군찹쌀떡 크롤링 완료
# 옹진군찹쌀수제비 크롤링 완료
# 옹진군찹쌀순대 크롤링 완료
# 옹진군찹쌀탕수육 크롤링 완료
# 옹진군찹쌀호떡 크롤링 완료
# 옹진군채끝등심 크롤링 완료
# 옹진군채끝스테이크 크롤링 완료
# 옹진군채식 크롤링 완료
# 옹진군천엽 크롤링 완료
# 옹진군철판구이 크롤링 완료
# 옹진군철판닭갈비 크롤링 완료
# 옹진군철판볶음 크롤링 완료
# 옹진군철판요리 크롤링 완료
# 옹진군철판쭈꾸미 크롤링 완료
# 옹진군청국장 크롤링 완료
# 옹진군체코 크롤링 완료
# 옹진군초계국수 크롤링 완료
# 옹진군초당순두부 크롤링 완료
# 옹진군초무침 크롤링 완료
# 옹진군초밥 크롤링 완료
# 옹진군초밥부페 크롤링 완료
# 옹진군초콜렛 크롤링 완료
# 옹진군초콜릿 크롤링 완료
# 옹진군촌닭 크롤링 완료
# 옹진군촌두부 크롤링 완료
# 옹진군추러스 크롤링 완료
# 옹진군추어탕 크롤링 완료
# 옹진군추어튀김 크롤링 완료
# 옹진군춘천막국수 크롤링 완료
# 옹진군츄러스 크롤링 완료
# 옹진군치떡 크롤링 완료
# 옹진군치맛살 크롤링 완료
# 옹진군치맥 크롤링 완료
# 옹진군치미창가 크롤링 완료
# 옹진군치밥 크롤링 완료
# 옹진군치슐랭 크롤링 완료
# 옹진군치아바타 크롤링 완료
# 옹진군치즈 크롤링 완료
# 옹진군치즈계란말이 크롤링 완료
# 옹진군치즈돈까스 크롤링 완료
# 옹진군치즈라볶이 크롤링 완료
# 옹진군치즈롤 크롤링 완료
# 옹진군치즈무스 크롤링 완료
# 옹진군치즈바게트 크롤링 완료
# 옹진군치즈버거 크롤링 완료
# 옹진군치즈볼 크롤링 완료
# 옹진군치즈스틱 크롤링 완료
# 옹진군치즈오믈렛 크롤링 완료
# 옹진군치즈찜닭 크롤링 완료
# 옹진군치즈카츠 크롤링 완료
# 옹진군치즈케이크 크롤링 완료
# 옹진군치즈타르트 크롤링 완료
# 옹진군치즈토스트 크롤링 완료
# 옹진군치즈퐁듀 크롤링 완료
# 옹진군치즈프라이 크롤링 완료
# 옹진군치즈피자 크롤링 완료
# 옹진군치즈후라이 크롤링 완료
# 옹진군치킨 크롤링 완료
# 옹진군치킨마요 크롤링 완료
# 옹진군치킨스테이크 크롤링 완료
# 옹진군칠리 크롤링 완료
# 옹진군칠리새우볶음밥 크롤링 완료
# 옹진군칠리크랩 크롤링 완료
# 옹진군칠리프라이즈 크롤링 완료
# 옹진군칡냉면 크롤링 완료
# 옹진군칭따오 크롤링 완료
# 옹진군카라멜 크롤링 완료
# 옹진군카레 크롤링 완료
# 옹진군카레우동 크롤링 완료
# 옹진군카르파치오 크롤링 완료
# 옹진군카스테라 크롤링 완료
# 옹진군카야토스트 크롤링 완료
# 옹진군카이센동 크롤링 완료
# 옹진군카츠동 크롤링 완료
# 옹진군카케우동 크롤링 완료
# 옹진군카프레제 크롤링 완료
# 옹진군카프리쵸사 크롤링 완료
# 옹진군칵테일 크롤링 완료
# 옹진군칼국수 크롤링 완료
# 옹진군칼만두 크롤링 완료
# 옹진군칼삼겹살 크롤링 완료
# 옹진군칼제비 크롤링 완료
# 옹진군캐주얼다이닝 크롤링 완료
# 옹진군캘리포니아롤 크롤링 완료
# 옹진군캠핑식당 크롤링 완료
# 옹진군커리 크롤링 완료
# 옹진군커피 크롤링 완료
# 옹진군컵밥 크롤링 완료
# 옹진군컵케이크 크롤링 완료
# 옹진군케이크 크롤링 완료
# 옹진군코다리 크롤링 완료
# 옹진군코스요리 크롤링 완료
# 옹진군코울슬로 크롤링 완료
# 옹진군코코넛쉬림프샐러드 크롤링 완료
# 옹진군콘브레드 크롤링 완료
# 옹진군콘치즈 크롤링 완료
# 옹진군콥샐러드 크롤링 완료
# 옹진군콩국물 크롤링 완료
# 옹진군콩국수 크롤링 완료
# 옹진군콩나물국 크롤링 완료
# 옹진군콩나물국밥 크롤링 완료
# 옹진군콩나물밥 크롤링 완료
# 옹진군콩나물해장국 크롤링 완료
# 옹진군콩불 크롤링 완료
# 옹진군콩비지 크롤링 완료
# 옹진군콩요리 크롤링 완료
# 옹진군쿠바샌드위치 크롤링 완료
# 옹진군쿠키 크롤링 완료
# 옹진군퀘사디아 크롤링 완료
# 옹진군큐브라떼 크롤링 완료
# 옹진군큐브스테이크덮밥 크롤링 완료
# 옹진군크라상 크롤링 완료
# 옹진군크래프트맥주 크롤링 완료
# 옹진군크레이프 크롤링 완료
# 옹진군크레페 크롤링 완료
# 옹진군크로아상 크롤링 완료
# 옹진군크로크무슈 크롤링 완료
# 옹진군크로플 크롤링 완료
# 옹진군크림단팥빵 크롤링 완료
# 옹진군크림맥주 크롤링 완료
# 옹진군크림브륄레 크롤링 완료
# 옹진군크림빵 크롤링 완료
# 옹진군크림새우 크롤링 완료
# 옹진군크림생맥주 크롤링 완료
# 옹진군크림와플 크롤링 완료
# 옹진군크림우동 크롤링 완료
# 옹진군크림짬뽕 크롤링 완료
# 옹진군크림치즈 크롤링 완료
# 옹진군크림카레 크롤링 완료
# 옹진군크림탕수육 크롤링 완료
# 옹진군크림파스타 크롤링 완료
# 옹진군클라우드 크롤링 완료
# 옹진군클램차우더 크롤링 완료
# 옹진군키위 크롤링 완료
# 옹진군키조개 크롤링 완료
# 옹진군키즈까페 크롤링 완료
# 옹진군킹크랩 크롤링 완료
# 옹진군타다키 크롤링 완료
# 옹진군타로버블티 크롤링 완료
# 옹진군타르트 크롤링 완료
# 옹진군타마고산도 크롤링 완료
# 옹진군타이음식 크롤링 완료
# 옹진군타코 크롤링 완료
# 옹진군타코야끼 크롤링 완료
# 옹진군타코와사비 크롤링 완료
# 옹진군타파스 크롤링 완료
# 옹진군탄두리치킨 크롤링 완료
# 옹진군탄탄멘 크롤링 완료
# 옹진군탕수육 크롤링 완료
# 옹진군탕평채 크롤링 완료
# 옹진군태국식 크롤링 완료
# 옹진군태국요리 크롤링 완료
# 옹진군터키 크롤링 완료
# 옹진군털레기 크롤링 완료
# 옹진군테린느 크롤링 완료
# 옹진군텐동 크롤링 완료
# 옹진군토마토 크롤링 완료
# 옹진군토마토계란탕 크롤링 완료
# 옹진군토마토스튜 크롤링 완료
# 옹진군토마토짬뽕 크롤링 완료
# 옹진군토마토파스타 크롤링 완료
# 옹진군토스트 크롤링 완료
# 옹진군토시살 크롤링 완료
# 옹진군토종닭 크롤링 완료
# 옹진군토피넛라떼 크롤링 완료
# 옹진군톳김밥 크롤링 완료
# 옹진군통갈치구이 크롤링 완료
# 옹진군통갈치조림 크롤링 완료
# 옹진군통골뱅이 크롤링 완료
# 옹진군통닭 크롤링 완료
# 옹진군통돼지김치찌개 크롤링 완료
# 옹진군통목살 크롤링 완료
# 옹진군통문어 크롤링 완료
# 옹진군통불닭발 크롤링 완료
# 옹진군통삼겹 크롤링 완료
# 옹진군통오겹살 크롤링 완료
# 옹진군통오징어 크롤링 완료
# 옹진군통오징어튀김 크롤링 완료
# 옹진군통장어탕 크롤링 완료
# 옹진군통치즈스틱 크롤링 완료
# 옹진군투움바 크롤링 완료
# 옹진군튀김덮밥 크롤링 완료
# 옹진군튀김만두 크롤링 완료
# 옹진군튀김소보로 크롤링 완료
# 옹진군튀김족발 크롤링 완료
# 옹진군트러플 크롤링 완료
# 옹진군특갈비탕 크롤링 완료
# 옹진군특등심 크롤링 완료
# 옹진군특수부위 크롤링 완료
# 옹진군티라미수 크롤링 완료
# 옹진군티룸 크롤링 완료
# 옹진군티본스테이크 크롤링 완료
# 옹진군티하우스 크롤링 완료
# 옹진군파김치 크롤링 완료
# 옹진군파니니 크롤링 완료
# 옹진군파닭 크롤링 완료
# 옹진군파르페 크롤링 완료
# 옹진군파블로바 크롤링 완료
# 옹진군파스타 크롤링 완료
# 옹진군파운드케익 크롤링 완료
# 옹진군파이 크롤링 완료
# 옹진군파인다이닝 크롤링 완료
# 옹진군파인애플볶음밥 크롤링 완료
# 옹진군파전 크롤링 완료
# 옹진군파티세리 크롤링 완료
# 옹진군파히타 크롤링 완료
# 옹진군판메밀 크롤링 완료
# 옹진군팔보완자 크롤링 완료
# 옹진군팔보채 크롤링 완료
# 옹진군팟타이 크롤링 완료
# 옹진군팡도르 크롤링 완료
# 옹진군팥도너츠 크롤링 완료
# 옹진군팥빙수 크롤링 완료
# 옹진군팥빵 크롤링 완료
# 옹진군팥옹심이 크롤링 완료
# 옹진군팥죽 크롤링 완료
# 옹진군팥집 크롤링 완료
# 옹진군팥칼국수 크롤링 완료
# 옹진군패밀리레스토랑 크롤링 완료
# 옹진군팬케이크 크롤링 완료
# 옹진군펍 크롤링 완료
# 옹진군페퍼로니 크롤링 완료
# 옹진군편백찜 크롤링 완료
# 옹진군편육 크롤링 완료
# 옹진군평양냉면 크롤링 완료
# 옹진군포장마차 크롤링 완료
# 옹진군포천이동갈비 크롤링 완료
# 옹진군포테이토피자 크롤링 완료
# 옹진군폭립 크롤링 완료
# 옹진군폭탄피자 크롤링 완료
# 옹진군퐁듀 크롤링 완료
# 옹진군퐁크러쉬 크롤링 완료
# 옹진군푸딩 크롤링 완료
# 옹진군푸아그라 크롤링 완료
# 옹진군풍천장어 크롤링 완료
# 옹진군퓨전 크롤링 완료
# 옹진군프라이즈 크롤링 완료
# 옹진군프랑스 크롤링 완료
# 옹진군프랑스가정식 크롤링 완료
# 옹진군프랑스레스토랑 크롤링 완료
# 옹진군프렌치레스토랑 크롤링 완료
# 옹진군프렌치토스트 크롤링 완료
# 옹진군프렌치프라이 크롤링 완료
# 옹진군플래터 크롤링 완료
# 옹진군플레인베이글 크롤링 완료
# 옹진군플레인와플 크롤링 완료
# 옹진군피낭시에 크롤링 완료
# 옹진군피맥 크롤링 완료
# 옹진군피문어 크롤링 완료
# 옹진군피순대 크롤링 완료
# 옹진군피쉬앤칩스 크롤링 완료
# 옹진군피자 크롤링 완료
# 옹진군피자뷔페 크롤링 완료
# 옹진군피칸파이 크롤링 완료
# 옹진군필라프 크롤링 완료
# 옹진군필리치즈 크롤링 완료
# 옹진군필스너 크롤링 완료
# 옹진군하모 크롤링 완료
# 옹진군하모유비끼 크롤링 완료
# 옹진군하야시라이스 크롤링 완료
# 옹진군하얀짜장 크롤링 완료
# 옹진군하와이안 크롤링 완료
# 옹진군하이볼 크롤링 완료
# 옹진군학꽁치 크롤링 완료
# 옹진군학센 크롤링 완료
# 옹진군한과 크롤링 완료
# 옹진군한돈 크롤링 완료
# 옹진군한방구이 크롤링 완료
# 옹진군한방능이오리백숙 크롤링 완료
# 옹진군한방닭구이 크롤링 완료
# 옹진군한방보쌈 크롤링 완료
# 옹진군한방삼계탕 크롤링 완료
# 옹진군한방오리백숙 크롤링 완료
# 옹진군한방족발 크롤링 완료
# 옹진군한방통닭 크롤링 완료
# 옹진군한상차림 크롤링 완료
# 옹진군한식 크롤링 완료
# 옹진군한옥카페 크롤링 완료
# 옹진군한우 크롤링 완료
# 옹진군한우갈비 크롤링 완료
# 옹진군한우곱창 크롤링 완료
# 옹진군한우구이 크롤링 완료
# 옹진군한우국밥 크롤링 완료
# 옹진군한우국시 크롤링 완료
# 옹진군한우내장탕 크롤링 완료
# 옹진군한우등심 크롤링 완료
# 옹진군한우모듬 크롤링 완료
# 옹진군한우물회 크롤링 완료
# 옹진군한우불고기 크롤링 완료
# 옹진군한우생등심 크롤링 완료
# 옹진군한우샤브샤브 크롤링 완료
# 옹진군한우소곱창 크롤링 완료
# 옹진군한우소머리곰탕 크롤링 완료
# 옹진군한우양곰탕 크롤링 완료
# 옹진군소고기오마카세 크롤링 완료
# 옹진군한우육개장 크롤링 완료
# 옹진군한우육회 크롤링 완료
# 옹진군한우전골 크롤링 완료
# 옹진군한우차돌 크롤링 완료
# 옹진군한우초밥 크롤링 완료
# 옹진군한우특등심 크롤링 완료
# 옹진군한정식 크롤링 완료
# 옹진군한치 크롤링 완료
# 옹진군함바그 크롤링 완료
# 옹진군함박스테이크 크롤링 완료
# 옹진군함흥냉면 크롤링 완료
# 옹진군핫도그 크롤링 완료
# 옹진군항아리수제비 크롤링 완료
# 옹진군항정살 크롤링 완료
# 옹진군해내탕 크롤링 완료
# 옹진군해녀의집 크롤링 완료
# 옹진군해물 크롤링 완료
# 옹진군해물누룽지탕 크롤링 완료
# 옹진군해물뚝배기 크롤링 완료
# 옹진군해물라면 크롤링 완료
# 옹진군해물부추전 크롤링 완료
# 옹진군해물알찜 크롤링 완료
# 옹진군해물요리 크롤링 완료
# 옹진군해물전 크롤링 완료
# 옹진군해물조개찜 크롤링 완료
# 옹진군해물죽 크롤링 완료
# 옹진군해물짬뽕 크롤링 완료
# 옹진군해물찜 크롤링 완료
# 옹진군해물철판 크롤링 완료
# 옹진군해물칼국수 크롤링 완료
# 옹진군해물탕 크롤링 완료
# 옹진군해물파전 크롤링 완료
# 옹진군해물포차 크롤링 완료
# 옹진군해산물 크롤링 완료
# 옹진군해산물빠에야 크롤링 완료
# 옹진군해삼 크롤링 완료
# 옹진군해신탕 크롤링 완료
# 옹진군해온반 크롤링 완료
# 옹진군해장국 크롤링 완료
# 옹진군해전물회 크롤링 완료
# 옹진군해천탕 크롤링 완료
# 옹진군해초쌈 크롤링 완료
# 옹진군햄버거 크롤링 완료
# 옹진군햄샌드위치 크롤링 완료
# 옹진군햄치즈 크롤링 완료
# 옹진군햄치즈순두부 크롤링 완료
# 옹진군햄치즈토스트 크롤링 완료
# 옹진군햄치즈파니니 크롤링 완료
# 옹진군향어회 크롤링 완료
# 옹진군향토음식 크롤링 완료
# 옹진군허니브레드 크롤링 완료
# 옹진군허파전골 크롤링 완료
# 옹진군헛제사밥 크롤링 완료
# 옹진군헤이즐넛아메리카노 크롤링 완료
# 옹진군현미밥 크롤링 완료
# 옹진군호두과자 크롤링 완료
# 옹진군호떡 크롤링 완료
# 옹진군호르몬동 크롤링 완료
# 옹진군호박 크롤링 완료
# 옹진군호지차 크롤링 완료
# 옹진군호텔뷔페 크롤링 완료
# 옹진군호프 크롤링 완료
# 옹진군혼마구로 크롤링 완료
# 옹진군홍게칼국수 크롤링 완료
# 옹진군홍어 크롤링 완료
# 옹진군홍어탕 크롤링 완료
# 옹진군홍짬뽕 크롤링 완료
# 옹진군홍차 크롤링 완료
# 옹진군홍콩식 크롤링 완료
# 옹진군홍탁 크롤링 완료
# 옹진군홍합 크롤링 완료
# 옹진군홍합짬뽕 크롤링 완료
# 옹진군홍합탕 크롤링 완료
# 옹진군화과자 크롤링 완료
# 옹진군화덕피자 크롤링 완료
# 옹진군화로구이 크롤링 완료
# 옹진군화이타 크롤링 완료
# 옹진군화채 크롤링 완료
# 옹진군고등어회 크롤링 완료
# 옹진군활어 크롤링 완료
# 옹진군황제살 크롤링 완료
# 옹진군황태 크롤링 완료
# 옹진군회 크롤링 완료
# 옹진군회전초밥 크롤링 완료
# 옹진군회정식 크롤링 완료
# 옹진군횟집 크롤링 완료
# 옹진군횡성한우 크롤링 완료
# 옹진군후라이드닭강정 크롤링 완료
# 옹진군후라이드치킨 크롤링 완료
# 옹진군후라이드파닭 크롤링 완료
# 옹진군후르츠산도 크롤링 완료
# 옹진군후토마키 크롤링 완료
# 옹진군훈제오리 크롤링 완료
# 옹진군훠궈 크롤링 완료
# 옹진군휘낭시에 크롤링 완료
# 옹진군흑당버블티 크롤링 완료
# 옹진군흑돼지 크롤링 완료
# 옹진군흑된장밥 크롤링 완료
# 옹진군흑마늘치킨 크롤링 완료
# 옹진군흑염소 크롤링 완료
# 옹진군흑우 크롤링 완료
# 옹진군흑임자 크롤링 완료
# 옹진군히레카츠 크롤링 완료
# 옹진군히쯔마부시 크롤링 완료
#
#  *****크롤링완료*****

# %%
restaurant_df
# Out:
#        category food_cat       store score             summary   sub_loca  \
# 1       옹진군가라아게     가라아게    카츠 바이 콘반   83점   돈까스, 히레카츠, 치킨가라아게        압구정
# 2       옹진군가라아게     가라아게         만푸쿠   78점      일식당, 사케동, 가라아게        가천대
# 3       옹진군가라아게     가라아게        롤인익선   76점     초밥, 연어롤, 치킨가라아게        익선동
# 4       옹진군가라아게     가라아게      수타우동 겐   72점     우동, 덴뿌라, 치킨가라아게         야탑
# 5       옹진군가라아게     가라아게       하카타나카   71점       일본가정식백반, 가라아게         홍대
# ...         ...      ...         ...   ...                 ...        ...
# 16947  옹진군히쯔마부시    히쯔마부시       효자동초밥   70점      초밥, 미니우동, 장어덮밥         서촌
# 16948  옹진군히쯔마부시    히쯔마부시          해목   70점  일식당, 히츠마부시, 민물장어덮밥         서울
# 16949  옹진군히쯔마부시    히쯔마부시     이자카야 카덴   69점      우동, 이자카야, 장어덮밥        연희동
# 16950  옹진군히쯔마부시    히쯔마부시  동경산책 송리단길점   69점           스시롤, 장어덮밥       송리단길
# 16951  옹진군히쯔마부시    히쯔마부시       김영섭초밥   67점      초밥, 모듬초밥, 장어덮밥  디지털미디어시티역
#
#                                  full_loca
# 1                     서울특별시 강남구 신사동 647-22
# 2      경기 성남시 수정구 태평동 5113-9 경원프라자 2층 203호
# 3                         서울특별시 종로구 익선동 93
# 4                      경기도 성남시 분당구 야탑동 503
# 5                     서울특별시 마포구 서교동 346-36
# ...                                    ...
# 16947                     서울특별시 종로구 통의동 59
# 16948                  서울특별시 강남구 논현동 95-21
# 16949             서울 서대문구 연희동 81-1 거화빌딩 2층
# 16950                   서울특별시 송파구 송파동 42-6
# 16951                  서울특별시 마포구 상암동 42-20
#
# [16951 rows x 7 columns]

# %%
df = pd.read_csv(f'/Users/ppangppang/Desktop/맛집리스트확인/{date}_restaurant_list.csv')
df.drop_duplicates(['store'],inplace=True)
df.index = range(len(df))
df
# Out:
#       category food_cat     store score            summary   sub_loca  \
# 0      옹진군가라아게     가라아게  카츠 바이 콘반   83점  돈까스, 히레카츠, 치킨가라아게        압구정
# 1      옹진군가라아게     가라아게       만푸쿠   78점     일식당, 사케동, 가라아게        가천대
# 2      옹진군가라아게     가라아게      롤인익선   76점    초밥, 연어롤, 치킨가라아게        익선동
# 3      옹진군가라아게     가라아게    수타우동 겐   72점    우동, 덴뿌라, 치킨가라아게         야탑
# 4      옹진군가라아게     가라아게     하카타나카   71점      일본가정식백반, 가라아게         홍대
# ...        ...      ...       ...   ...                ...        ...
# 8489     옹진군흑우       흑우        왔쏘   41점   소고기무한리필, 소고기, 흑우         구리
# 8490     옹진군흑우       흑우       육시락   39점        육회, 갈비살, 흑우        검암동
# 8491     옹진군흑우       흑우        흑우   39점            흑우, 소고기         서구
# 8492   옹진군히레카츠     히레카츠      토도로끼   69점    일식당, 히레까스, 히레카츠         잠실
# 8493  옹진군히쯔마부시    히쯔마부시     김영섭초밥   67점     초밥, 모듬초밥, 장어덮밥  디지털미디어시티역
#
#                                 full_loca
# 0                    서울특별시 강남구 신사동 647-22
# 1     경기 성남시 수정구 태평동 5113-9 경원프라자 2층 203호
# 2                        서울특별시 종로구 익선동 93
# 3                     경기도 성남시 분당구 야탑동 503
# 4                    서울특별시 마포구 서교동 346-36
# ...                                   ...
# 8489                   경기도 구리시 수택동 404-13
# 8490                   인천광역시 서구 검암동 508-1
# 8491                   인천광역시 서구 청라동 186-6
# 8492                   서울특별시 송파구 신천동 7-14
# 8493                  서울특별시 마포구 상암동 42-20
#
# [8494 rows x 7 columns]

# %%
# 상위점수 구분(30점 이상만)
# a = list(df['score'])
# for i in range(len(a)):
#     a[i] = int(a[i][:-1])
# df['re_score'] = a
# df = df[df['re_score']>=30]
# df.index=range(len(df))
# df.drop(['re_score'],axis=1,inplace=True)
# df=df.sort_values('score',ascending=False)

# %%
df.to_excel('/Users/ppangppang/Desktop/맛집리스트확인/select/---.xlsx',index=False)

# %%
# df.to_csv('/Users/ppangppang/Documents/dev/TIL/test_restaurant_data/211010_restaurant_list3.csv',index=False)

# %% [markdown]
# ## 현재까지 작업한 파일 concat

# %%
import glob
import pandas as pd

# get data file names
filenames = glob.glob('/Users/ppangppang/Desktop/ssac/data_crwaling/restaurant_test/databackup/*.csv')

dfs = []
for filename in filenames:
    dfs.append(pd.read_csv(filename))

# Concatenate all data into one DataFrame
df = pd.concat(dfs, ignore_index=True)
df.drop_duplicates(['store'],inplace=True)
df.index = range(len(df))

# %%
df
# Out:
#       category food_cat           store score            summary sub_loca  \
# 0         부평냉면        면            해민면옥   61점      평양냉면, 녹두전, 냉면       부평
# 1         부평냉면        면           부평막국수   56점       수육, 물막국수, 냉면    부평시장역
# 2         부평냉면        면           별미칡냉면   54점            냉면, 물냉면       부평
# 3         부평냉면        면      화미소금구이 부평점   41점        삼겹살, 목살, 냉면       부평
# 4         부평냉면        면             디델리   35점      떡볶이, 라볶이, 물냉면       부평
# ...        ...      ...             ...   ...                ...      ...
# 48631  계양찹쌀꽈배기     쌀꽈배기        노랑고래 효성점   NaN    도너츠, 꽈배기, 찹쌀꽈배기      효성동
# 48632  계양치즈핫도그     즈핫도그  소문난 마늘숙성 수제돈가스   NaN  돈까스, 수제돈까스, 치즈핫도그      효성동
# 48633    계양닭다리       다리       BHC치킨 임학점   NaN       치킨, 치즈볼, 닭다리      임학역
# 48634   계양커피콩빵      피콩빵            투씨커피   NaN       카페, 커피, 커피콩빵      계산동
# 48635     계양홍어        어          명품홍어무침   NaN           홍어무침, 홍어     계양구청
#
#                             full_loca
# 0                인천광역시 부평구 부평동 212-24
# 1               인천광역시 부평구 부평1동 529-96
# 2                   인천시 부평구 갈산동 377-8
# 3                 인천광역시 부평구 부평동 70-83
# 4                인천광역시 부평구 부평동 211-75
# ...                               ...
# 48631             인천광역시 계양구 효성동 242-7
# 48632           인천광역시 계양구 병방동 373 28호
# 48633             인천광역시 계양구 임학동 65-11
# 48634             인천광역시 계양구 작전동 905-1
# 48635  인천 계양구 용종동 209-4 계양프라자 1층 103호
#
# [48636 rows x 7 columns]

# %%
df.isna().sum()
# Out:
# category         0
# food_cat      1534
# store            0
# score        12268
# summary          2
# sub_loca         0
# full_loca        0
# dtype: int64

# %%
# 어차피 0점은 없음. 점수가 있거나 없거나임
df['score']=df['score'].fillna('0점')
df
# Out:
#       category food_cat           store score            summary sub_loca  \
# 0         부평냉면        면            해민면옥   61점      평양냉면, 녹두전, 냉면       부평
# 1         부평냉면        면           부평막국수   56점       수육, 물막국수, 냉면    부평시장역
# 2         부평냉면        면           별미칡냉면   54점            냉면, 물냉면       부평
# 3         부평냉면        면      화미소금구이 부평점   41점        삼겹살, 목살, 냉면       부평
# 4         부평냉면        면             디델리   35점      떡볶이, 라볶이, 물냉면       부평
# ...        ...      ...             ...   ...                ...      ...
# 48631  계양찹쌀꽈배기     쌀꽈배기        노랑고래 효성점    0점    도너츠, 꽈배기, 찹쌀꽈배기      효성동
# 48632  계양치즈핫도그     즈핫도그  소문난 마늘숙성 수제돈가스    0점  돈까스, 수제돈까스, 치즈핫도그      효성동
# 48633    계양닭다리       다리       BHC치킨 임학점    0점       치킨, 치즈볼, 닭다리      임학역
# 48634   계양커피콩빵      피콩빵            투씨커피    0점       카페, 커피, 커피콩빵      계산동
# 48635     계양홍어        어          명품홍어무침    0점           홍어무침, 홍어     계양구청
#
#                             full_loca
# 0                인천광역시 부평구 부평동 212-24
# 1               인천광역시 부평구 부평1동 529-96
# 2                   인천시 부평구 갈산동 377-8
# 3                 인천광역시 부평구 부평동 70-83
# 4                인천광역시 부평구 부평동 211-75
# ...                               ...
# 48631             인천광역시 계양구 효성동 242-7
# 48632           인천광역시 계양구 병방동 373 28호
# 48633             인천광역시 계양구 임학동 65-11
# 48634             인천광역시 계양구 작전동 905-1
# 48635  인천 계양구 용종동 209-4 계양프라자 1층 103호
#
# [48636 rows x 7 columns]

# %%
df[df['summary'].isna()]
# Out:
#       category food_cat        store score summary sub_loca  \
# 39192   종로구운니동      NaN    COFFEE la   21점     NaN      안국역
# 39836   강서구공항동      NaN   호호카츠 김포공항점   26점     NaN     김포공항
#
#                          full_loca
# 39192        서울시 종로구 운니동 15 노블호텔1층
# 39836  서울특별시 강서구 공항동 1373 국내선청사 4층

# %%
# df['summary'][39836:39837] = '돈까스'
# df['summary'][39192:39293] = '커피'

# %%
df.isna().sum()
# Out:
# category        0
# food_cat     1534
# store           0
# score           0
# summary         0
# sub_loca        0
# full_loca       0
# dtype: int64

# %%
# food_cat은 부가정보로 남겨둔거니까 패스
df = df[['category','store','summary','sub_loca','full_loca']]
df.index = range(len(df))
df
# Out:
#       category           store            summary sub_loca  \
# 0         부평냉면            해민면옥      평양냉면, 녹두전, 냉면       부평
# 1         부평냉면           부평막국수       수육, 물막국수, 냉면    부평시장역
# 2         부평냉면           별미칡냉면            냉면, 물냉면       부평
# 3         부평냉면      화미소금구이 부평점        삼겹살, 목살, 냉면       부평
# 4         부평냉면             디델리      떡볶이, 라볶이, 물냉면       부평
# ...        ...             ...                ...      ...
# 48631  계양찹쌀꽈배기        노랑고래 효성점    도너츠, 꽈배기, 찹쌀꽈배기      효성동
# 48632  계양치즈핫도그  소문난 마늘숙성 수제돈가스  돈까스, 수제돈까스, 치즈핫도그      효성동
# 48633    계양닭다리       BHC치킨 임학점       치킨, 치즈볼, 닭다리      임학역
# 48634   계양커피콩빵            투씨커피       카페, 커피, 커피콩빵      계산동
# 48635     계양홍어          명품홍어무침           홍어무침, 홍어     계양구청
#
#                             full_loca
# 0                인천광역시 부평구 부평동 212-24
# 1               인천광역시 부평구 부평1동 529-96
# 2                   인천시 부평구 갈산동 377-8
# 3                 인천광역시 부평구 부평동 70-83
# 4                인천광역시 부평구 부평동 211-75
# ...                               ...
# 48631             인천광역시 계양구 효성동 242-7
# 48632           인천광역시 계양구 병방동 373 28호
# 48633             인천광역시 계양구 임학동 65-11
# 48634             인천광역시 계양구 작전동 905-1
# 48635  인천 계양구 용종동 209-4 계양프라자 1층 103호
#
# [48636 rows x 5 columns]

# %%
# 일단 서울, 인천만보자
location = pd.read_csv('/Users/ppangppang/Desktop/ssac/data_crwaling/restaurant_test/adm_code.csv')
location = location[(location['시도코드'] == 23) | (location['시도코드'] == 11)]
location.index = range(len(location))
location
# Out:
#      시도코드   시도명칭  시군구코드 시군구명칭    읍면동코드 읍면동명칭            전체코드
# 0      11  서울특별시  11010   종로구  1101053   사직동  11110101101053
# 1      11  서울특별시  11010   종로구  1101054   삼청동  11110101101054
# 2      11  서울특별시  11010   종로구  1101055   부암동  11110101101055
# 3      11  서울특별시  11010   종로구  1101056   평창동  11110101101056
# 4      11  서울특별시  11010   종로구  1101057   무악동  11110101101057
# ..    ...    ...    ...   ...      ...   ...             ...
# 574    23  인천광역시  23320   옹진군  2332033   백령면  23233202332033
# 575    23  인천광역시  23320   옹진군  2332034   대청면  23233202332034
# 576    23  인천광역시  23320   옹진군  2332035   덕적면  23233202332035
# 577    23  인천광역시  23320   옹진군  2332036   자월면  23233202332036
# 578    23  인천광역시  23320   옹진군  2332037   영흥면  23233202332037
#
# [579 rows x 7 columns]

# %%
df2 = df[df['full_loca'].str.contains('임학동')]

# %%
# df['si'] = np.where(df['full_loca'].str.contains('서울'), 11, 23)

# %%
df['si'] = np.where(df['full_loca'].str.contains('서울'), '서울', '인천')
# Out:
#       category           store            summary sub_loca  \
# 0         부평냉면            해민면옥      평양냉면, 녹두전, 냉면       부평
# 1         부평냉면           부평막국수       수육, 물막국수, 냉면    부평시장역
# 2         부평냉면           별미칡냉면            냉면, 물냉면       부평
# 3         부평냉면      화미소금구이 부평점        삼겹살, 목살, 냉면       부평
# 4         부평냉면             디델리      떡볶이, 라볶이, 물냉면       부평
# ...        ...             ...                ...      ...
# 48631  계양찹쌀꽈배기        노랑고래 효성점    도너츠, 꽈배기, 찹쌀꽈배기      효성동
# 48632  계양치즈핫도그  소문난 마늘숙성 수제돈가스  돈까스, 수제돈까스, 치즈핫도그      효성동
# 48633    계양닭다리       BHC치킨 임학점       치킨, 치즈볼, 닭다리      임학역
# 48634   계양커피콩빵            투씨커피       카페, 커피, 커피콩빵      계산동
# 48635     계양홍어          명품홍어무침           홍어무침, 홍어     계양구청
#
#                             full_loca  si
# 0                인천광역시 부평구 부평동 212-24  23
# 1               인천광역시 부평구 부평1동 529-96  23
# 2                   인천시 부평구 갈산동 377-8  23
# 3                 인천광역시 부평구 부평동 70-83  23
# 4                인천광역시 부평구 부평동 211-75  23
# ...                               ...  ..
# 48631             인천광역시 계양구 효성동 242-7  23
# 48632           인천광역시 계양구 병방동 373 28호  23
# 48633             인천광역시 계양구 임학동 65-11  23
# 48634             인천광역시 계양구 작전동 905-1  23
# 48635  인천 계양구 용종동 209-4 계양프라자 1층 103호  23
#
# [48636 rows x 6 columns]

# %%
location[location['읍면동명칭'] == '연희동']
# Out:
#      시도코드   시도명칭  시군구코드 시군구명칭    읍면동코드 읍면동명칭            전체코드
# 205    11  서울특별시  11130  서대문구  1113076   연희동  11111301113076
# 517    23  인천광역시  23080    서구  2308053   연희동  23230802308053

# %%
#예제 데이터 만들기
ex = {'경도' : [127.061026,127.047883,127.899220,128.980455,127.104071,127.102490,127.088387,126.809957,127.010861,126.836078
                ,127.014217,126.886859,127.031702,126.880898,127.028726,126.897710,126.910288,127.043189,127.071184,127.076812
                ,127.045022,126.982419,126.840285,127.115873,126.885320,127.078464,127.057100,127.020945,129.068324,129.059574
                ,126.927655,127.034302,129.106330,126.980242,126.945099,129.034599,127.054649,127.019556,127.053198,127.031005
                ,127.058560,127.078519,127.056141,129.034605,126.888485,129.070117,127.057746,126.929288,127.054163,129.060972],
     '위도' : [37.493922,37.505675,37.471711,35.159774,37.500249,37.515149,37.549245,37.562013,37.552153,37.538927,37.492388
              ,37.480390,37.588485,37.504067,37.608392,37.503693,37.579029,37.580073,37.552103,37.545461,37.580196,37.562274
              ,37.535419,37.527477,37.526139,37.648247,37.512939,37.517574,35.202902,35.144776,37.499229,35.150069,35.141176
              ,37.479403,37.512569,35.123196,37.546718,37.553668,37.488742,37.493653,37.498462,37.556602,37.544180,35.111532
              ,37.508058,35.085777,37.546103,37.483899,37.489299,35.143421],
     '구분' : ['음식','음식','음식','음식','생활서비스','음식','음식','음식','음식','음식','음식','음식','음식','음식','음식'
             ,'음식','음식','소매','음식','음식','음식','음식','소매','음식','소매','음식','음식','음식','음식','음식','음식'
             ,'음식','음식','음식','음식','소매','음식','음식','의료','음식','음식','음식','소매','음식','음식','음식','음식'
             ,'음식','음식','음식']}

ex=pd.DataFrame(ex)

# %%
lat = ex.loc[0,'위도']
long = ex.loc[0,'경도']

# %%
#지도 새로 띄우기
m = folium.Map([lat,long],zoom_start=12)

for i in ex.index:
    sub_lat =  ex.loc[i,'위도']
    sub_long = ex.loc[i,'경도']
    
    title = ex.loc[i,'구분']
  
    #구분이 소매면 빨간색으로 표시, default는 녹색
    color = 'green'
    if ex.loc[i,'구분'] == '소매':
        color = "red"
        
    #지도에 동그라미로 데이터 찍기    
    folium.CircleMarker([sub_lat,sub_long],color=color,radius = 5, tooltip=title).add_to(m)

m

# %%
driver = webdriver.Chrome('/Users/ppangppang/Desktop/ssac/02.Python_/Python_Basic_Class/chromedriver')

url = 'https://www.google.com/maps/'
driver.get(url)
time.sleep(5)

# %% [markdown]
# 1. 인기 메뉴 카테고리 설정(프렌차이즈가 많으니, 적어도 50분야 정도 설정)
# 2. 구단위 뒤도 경도 뽑아보기(좀 어려우면 좀 묶어서)
# 3. 카테고리별 맛집 평균점수에따라 지도에 표시해보기
# 여기서 나올만한 인사이트? - 카테고리별 지역별 맛집 분포 / 배달과 관련해서 뭐 엮을만한게 있을까? / 시간되면 생활지수들 질병관리청에서 가져와서 상관관계 확인?
#
# 위도경도 링크1 : https://sajuplus.tistory.com/778
# 위도경도 링크2 : https://kor.timegenie.com/latitude_longitude/country/kr
# 위도경도 api : https://www.vworld.kr/dev/v4dv_2ddataguide2_s002.do?svcIde=ademd
#
# 다른 데이터셋 확인 : kosis , 질병관리청
