# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# 이미지 파일명 설정
img_nm = './data/lena.jpg'

# %%
# 이미지를 파이썬으로 불러들임
lena = plt.imread(img_nm)

# %%
# 이미지 plotting
plt.imshow(lena);

# %%
#lena
# 값 하나하나가 픽셀이다

# %%
lena.shape # tensor 데이터
# 뒤쪽에 4가 RGB 채널에 해당하는 부분
# Out:
# (512, 512, 4)

# %%
R = lena.copy()
G = lena.copy()
B = lena.copy()
R[:, :, (1,2)] = 0 # G,B 채널값을 0으로해서 R 채널만 뽑아내기
G[:, :, (0,2)] = 0
B[:, :, (0,1)] = 0

# %%
plt.imshow(R);

# %%
plt.figure(figsize=(20,10))
plt.subplot(131)
plt.imshow(R)
plt.subplot(132)
plt.imshow(G)
plt.subplot(133)
plt.imshow(B)

# %%
plt.imshow(lena[:,:,2])

# %%
from PIL import Image

# %%
# 이미지 저장
img = Image.fromarray(lena[:,:,2])
img.save('./data/lena_color_split.jpg') # 흑백으로 나옴

# %%
# 이미지 크롭(100~400 부분만 가져오기)
plt.imshow(lena[100:400, 100:400])

# %%
# 반전
small_lena = lena[100:400, 100:400]
plt.imshow(small_lena[::-1])

# %%
mo_lena = lena[:,:,0]
plt.imshow(mo_lena)

# %%
# 명암반전
plt.imshow(255 - mo_lena)
