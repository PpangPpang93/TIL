# %%
# 기본세팅
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import time
import datetime
import random

# 크롤링용
from pandas.io.json import json_normalize
from bs4 import BeautifulSoup
import json
import requests
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

# 컬럼, 로우 조회 최대수 지정 
pd.options.display.max_info_columns =200
pd.options.display.max_columns = 200
pd.options.display.max_info_rows =100
pd.options.display.max_rows = 100

# 시각화할때 warning 무시
import warnings
warnings.filterwarnings(action='ignore')

# %% [markdown]
# # 정보
# - 일단 탑10밖에 안된다.
# - list 만들어서 그냥 탑텐정도 뽑아놓고 셀레니움을 해보자

# %%
# 지역 및 가게별 검색어 리스트를 따로 만들어보자
sgg = pd.read_csv('/Users/ppangppang/Desktop/ssac/data_crwaling/restaurant_test/SGG.csv')
sgg['county'] = sgg['county'].apply(lambda x:'부산' if (x == "부산광역시") else x)
sgg['county'] = sgg['county'].apply(lambda x:'서울' if (x == "서울특별시") else x)
sgg['county'] = sgg['county'].apply(lambda x:'경북' if (x == "경상북도") else x)
sgg['county'] = sgg['county'].apply(lambda x:'경남' if (x == "경상남도") else x)
sgg['county'] = sgg['county'].apply(lambda x:'전북' if (x == "전라북도") else x)
sgg['county'] = sgg['county'].apply(lambda x:'전남' if (x == "전라남도") else x)
sgg['county'] = sgg['county'].apply(lambda x:'전북' if (x == "전라북도") else x)
sgg['county'] = sgg['county'].apply(lambda x:'충북' if (x == "충청북도") else x)
sgg['county'] = sgg['county'].apply(lambda x:'충남' if (x == "충청북도") else x)
sgg['county'] = sgg['county'].apply(lambda x:'대구' if (x == "대구광역시") else x)
sgg['county'] = sgg['county'].apply(lambda x:'울산' if (x == "울산광역시") else x)
sgg['county'] = sgg['county'].apply(lambda x:'제주' if (x == "제주특별자치도") else x)
sgg['county'] = sgg['county'].apply(lambda x:'세종' if (x == "세종특별자치시") else x)
sgg['county'] = sgg['county'].apply(lambda x:'인천' if (x == "인천광역시") else x)
sgg['county'] = sgg['county'].apply(lambda x:'광주' if (x == "광주광역시") else x)

# %%
list_df=sgg[(sgg['county']=='부산')]
list_df.drop(['si_gun'],axis=1,inplace=True)
list_df=list_df.dropna()

list_gu = list(list_df['gu'])

list_gu1 = []
for i in list_gu:
    if i != '부산진구':
        list_gu1.append('부산'+i)
    else:
        list_gu1.append(i)
        
list_gu2=[]
for i in list_gu1:
    if i not in list_gu2:
        list_gu2.append(i)

# %%
list_gu2
# Out:
# ['부산중구',
#  '부산서구',
#  '부산동구',
#  '부산영도구',
#  '부산진구',
#  '부산동래구',
#  '부산남구',
#  '부산북구',
#  '부산해운대구',
#  '부산사하구',
#  '부산금정구',
#  '부산강서구',
#  '부산연제구',
#  '부산수영구',
#  '부산사상구']

# %%
# 음식 리스트 가져오기
food_cat = pd.read_excel('/Users/ppangppang/Desktop/ssac/data_crwaling/restaurant_test/food_cat.xlsx')
# food_cat.drop(columns='Unnamed: 0',axis=1, inplace=True)
food = (list(food_cat['list']))

# %%
# test
food1=food
target=[]
for loca in list_gu2[12:13]:
    for foody in food1:
        target.append(loca + foody)

# %%
target
# Out:
# ['부산연제구가라아게',
#  '부산연제구가리국밥',
#  '부산연제구가리비',
#  '부산연제구가릿국밥',
#  '부산연제구가마솥',
#  '부산연제구가맥',
#  '부산연제구가브리살',
#  '부산연제구가오리',
#  '부산연제구가자미물회',
#  '부산연제구가자미미역국',
#  '부산연제구가정식',
#  '부산연제구가지요리',
#  '부산연제구가츠나베',
#  '부산연제구가츠동',
#  '부산연제구가츠산도',
#  '부산연제구각재기국',
#  '부산연제구간장구이',
#  '부산연제구간장덮밥',
#  '부산연제구간장새우',
#  '부산연제구간재미',
#  '부산연제구간짜장',
#  '부산연제구갈낙찜',
#  '부산연제구갈낙탕',
#  '부산연제구갈릭난',
#  '부산연제구갈릭돈까스',
#  '부산연제구갈릭버거',
#  '부산연제구갈릭버터쉬림프',
#  '부산연제구갈릭쉬림프',
#  '부산연제구갈릭스테이크',
#  '부산연제구갈릭페뇨파스타',
#  '부산연제구갈매기살',
#  '부산연제구갈비',
#  '부산연제구갈추어탕',
#  '부산연제구갈치',
#  '부산연제구감바스',
#  '부산연제구감바스알아히요',
#  '부산연제구감베로니',
#  '부산연제구감베리크레마',
#  '부산연제구감성돔',
#  '부산연제구감자고로케',
#  '부산연제구감자국',
#  '부산연제구감자국수',
#  '부산연제구감자뇨끼',
#  '부산연제구감자떡',
#  '부산연제구감자빵',
#  '부산연제구감자수제비',
#  '부산연제구감자스프',
#  '부산연제구감자옹심이',
#  '부산연제구감자전',
#  '부산연제구감자탕',
#  '부산연제구감자튀김',
#  '부산연제구갑오징어',
#  '부산연제구강된장',
#  '부산연제구강된장비빔밥',
#  '부산연제구개스트로펍',
#  '부산연제구객주리조림',
#  '부산연제구갯장어',
#  '부산연제구건강빵',
#  '부산연제구건두부볶음',
#  '부산연제구검은콩국수',
#  '부산연제구게국지',
#  '부산연제구게살비빔밥',
#  '부산연제구게장',
#  '부산연제구간장게장',
#  '부산연제구게찜',
#  '부산연제구경양식',
#  '부산연제구계란김밥',
#  '부산연제구계란말이',
#  '부산연제구계란찜',
#  '부산연제구계란토스트',
#  '부산연제구고갈비',
#  '부산연제구고구마',
#  '부산연제구고기국수',
#  '부산연제구고기군만두',
#  '부산연제구고기만두',
#  '부산연제구고기말이',
#  '부산연제구고기뷔페',
#  '부산연제구고기짬뽕',
#  '부산연제구고기튀김',
#  '부산연제구고등어',
#  '부산연제구고로케',
#  '부산연제구고르곤졸라',
#  '부산연제구고사리육개장',
#  '부산연제구고추군만두',
#  '부산연제구고추닭튀김',
#  '부산연제구고추부각',
#  '부산연제구고추장',
#  '부산연제구고추전',
#  '부산연제구고추짜장',
#  '부산연제구고추짬뽕',
#  '부산연제구고추튀김',
#  '부산연제구곤드레',
#  '부산연제구곤이',
#  '부산연제구골뱅이',
#  '부산연제구곰국',
#  '부산연제구곰국시',
#  '부산연제구곰장어',
#  '부산연제구곰치국',
#  '부산연제구곰탕',
#  '부산연제구곱도리탕',
#  '부산연제구곱창',
#  '부산연제구곱창국수',
#  '부산연제구곱창떡볶이',
#  '부산연제구곱창모듬',
#  '부산연제구곱창볶음',
#  '부산연제구곱창순대전골',
#  '부산연제구곱창순두부',
#  '부산연제구곱창쌀국수',
#  '부산연제구곱창전골',
#  '부산연제구과메기',
#  '부산연제구과일디저트',
#  '부산연제구과일주스',
#  '부산연제구관자구이',
#  '부산연제구광동식',
#  '부산연제구광양불고기',
#  '부산연제구광어',
#  '부산연제구교자',
#  '부산연제구구운치킨',
#  '부산연제구국물닭발',
#  '부산연제구국물떡볶이',
#  '부산연제구국밥',
#  '부산연제구국수',
#  '부산연제구국시',
#  '부산연제구군만두',
#  '부산연제구굴림만두',
#  '부산연제구굴',
#  '부산연제구궁중음식',
#  '부산연제구규동',
#  '부산연제구규카츠',
#  '부산연제구그라탕',
#  '부산연제구그리스식',
#  '부산연제구그릭요거트',
#  '부산연제구그린티',
#  '부산연제구그릴드샌드위치',
#  '부산연제구근고기',
#  '부산연제구기네스',
#  '부산연제구기절낙지',
#  '부산연제구김말이',
#  '부산연제구김밥',
#  '부산연제구김치나베',
#  '부산연제구김치낙지죽',
#  '부산연제구김치덮밥',
#  '부산연제구김치돈까스',
#  '부산연제구김치돼지찌개',
#  '부산연제구김치두루치기',
#  '부산연제구김치만두',
#  '부산연제구김치말이국수',
#  '부산연제구김치보쌈',
#  '부산연제구김치볶음밥',
#  '부산연제구김치수제비',
#  '부산연제구김치순두부',
#  '부산연제구김치왕만두',
#  '부산연제구김치우동',
#  '부산연제구김치전',
#  '부산연제구김치전골',
#  '부산연제구김치제육볶음',
#  '부산연제구김치찌개',
#  '부산연제구김치치즈나베',
#  '부산연제구김치칼국수',
#  '부산연제구김치콩나물국밥',
#  '부산연제구까눌레',
#  '부산연제구까르보나라',
#  '부산연제구까페',
#  '부산연제구깍두기볶음밥',
#  '부산연제구깐풍기',
#  '부산연제구깔조네',
#  '부산연제구껍데기',
#  '부산연제구꼬들살',
#  '부산연제구꼬리곰탕',
#  '부산연제구꼬리찜',
#  '부산연제구꼬막',
#  '부산연제구꼬치',
#  '부산연제구꼼장어',
#  '부산연제구꽁보리밥',
#  '부산연제구꽁치찌개',
#  '부산연제구꽃게',
#  '부산연제구꽃등심',
#  '부산연제구꽃살',
#  '부산연제구꽃삼겹',
#  '부산연제구꽃새우',
#  '부산연제구꽃항정살',
#  '부산연제구꽈리고추',
#  '부산연제구꽈배기',
#  '부산연제구꿀막걸리',
#  '부산연제구꿀빵',
#  '부산연제구꿀호떡',
#  '부산연제구꿔바로우',
#  '부산연제구꿩',
#  '부산연제구나가사키짬뽕',
#  '부산연제구나베',
#  '부산연제구나비파이',
#  '부산연제구나시고랭',
#  '부산연제구나폴리피자',
#  '부산연제구낙곱새',
#  '부산연제구낙엽살',
#  '부산연제구낙지',
#  '부산연제구난자완스',
#  '부산연제구날치알',
#  '부산연제구남도음식',
#  '부산연제구남방즈케',
#  '부산연제구남아공음식',
#  '부산연제구납작만두',
#  '부산연제구내장',
#  '부산연제구냄비우동',
#  '부산연제구냉국수',
#  '부산연제구냉동삼겹살',
#  '부산연제구냉라면',
#  '부산연제구냉면',
#  '부산연제구냉모밀',
#  '부산연제구냉소바',
#  '부산연제구냉우동',
#  '부산연제구냉족',
#  '부산연제구냉짬뽕',
#  '부산연제구냉채족발',
#  '부산연제구냉칼국수',
#  '부산연제구냉콩국수',
#  '부산연제구네팔식',
#  '부산연제구노가리',
#  '부산연제구녹두빈대떡',
#  '부산연제구녹두전',
#  '부산연제구뇨끼',
#  '부산연제구누들',
#  '부산연제구누룽지탕',
#  '부산연제구누룽지통닭',
#  '부산연제구누텔라',
#  '부산연제구눈꽃빙수',
#  '부산연제구능이오리',
#  '부산연제구니꾸우동',
#  '부산연제구다금바리',
#  '부산연제구다슬기',
#  '부산연제구다이닝펍',
#  '부산연제구다찌',
#  '부산연제구다코야끼',
#  '부산연제구단팥빵',
#  '부산연제구단팥죽',
#  '부산연제구단호박',
#  '부산연제구달걀말이',
#  '부산연제구닭가슴살',
#  '부산연제구닭갈비',
#  '부산연제구닭강정',
#  '부산연제구닭개장',
#  '부산연제구닭곰탕',
#  '부산연제구닭구이',
#  '부산연제구닭국수',
#  '부산연제구닭껍질',
#  '부산연제구닭꼬치',
#  '부산연제구닭내장',
#  '부산연제구닭다리',
#  '부산연제구닭도리탕',
#  '부산연제구닭똥집',
#  '부산연제구닭목살',
#  '부산연제구닭발',
#  '부산연제구닭백숙',
#  '부산연제구닭볶음탕',
#  '부산연제구닭숯불구이',
#  '부산연제구닭죽',
#  '부산연제구닭칼국수',
#  '부산연제구닭한마리',
#  '부산연제구당근주스',
#  '부산연제구당근케이크',
#  '부산연제구대게',
#  '부산연제구대구매운탕',
#  '부산연제구대구뽈찜',
#  '부산연제구대구왕뽈찜',
#  '부산연제구대구전골',
#  '부산연제구대구탕',
#  '부산연제구대나무통밥',
#  '부산연제구대만샌드위치',
#  '부산연제구대방어',
#  '부산연제구대창',
#  '부산연제구대통밥',
#  '부산연제구대패삼겹살',
#  '부산연제구대하',
#  '부산연제구대합',
#  '부산연제구더덕',
#  '부산연제구더블치즈버거',
#  '부산연제구더치커피',
#  '부산연제구덕자',
#  '부산연제구데리야끼막창',
#  '부산연제구덴뿌라',
#  '부산연제구도가니',
#  '부산연제구도넛',
#  '부산연제구도다리쑥국',
#  '부산연제구도라지정과',
#  '부산연제구도래창',
#  '부산연제구도로초밥',
#  '부산연제구도루묵',
#  '부산연제구도리뱅뱅',
#  '부산연제구도리아',
#  '부산연제구도미',
#  '부산연제구도삭면',
#  '부산연제구도치알탕',
#  '부산연제구도토리',
#  '부산연제구독일식레스토랑',
#  '부산연제구돈까스',
#  '부산연제구돈부리',
#  '부산연제구돈치맛살',
#  '부산연제구돈코츠',
#  '부산연제구돈파스',
#  '부산연제구돌게장',
#  '부산연제구돌곱창',
#  '부산연제구돌문어',
#  '부산연제구돌솥밥',
#  '부산연제구돌판',
#  '부산연제구돔베고기',
#  '부산연제구동남아음식',
#  '부산연제구동동주',
#  '부산연제구동치미막국수',
#  '부산연제구동태탕',
#  '부산연제구동파육',
#  '부산연제구돼지갈비',
#  '부산연제구돼지고기탕수육',
#  '부산연제구돼지곱창전골',
#  '부산연제구돼지국밥',
#  '부산연제구돼지김치구이',
#  '부산연제구돼지김치찜',
#  '부산연제구돼지껍데기',
#  '부산연제구돼지꼬리',
#  '부산연제구돼지머리고기',
#  '부산연제구돼지부속',
#  '부산연제구돼지불고기',
#  '부산연제구돼지불백',
#  '부산연제구돼지양념갈비',
#  '부산연제구돼지왕갈비',
#  '부산연제구돼지주물럭',
#  '부산연제구돼지짜글이',
#  '부산연제구돼지특수부위',
#  '부산연제구된장국',
#  '부산연제구두루치기',
#  '부산연제구두부',
#  '부산연제구두부버섯전골',
#  '부산연제구두부요리전문',
#  '부산연제구뒷고기',
#  '부산연제구드라이에이징',
#  '부산연제구드립커피',
#  '부산연제구들기름막국수',
#  '부산연제구들깨',
#  '부산연제구등갈비',
#  '부산연제구등뼈찜',
#  '부산연제구등심',
#  '부산연제구등심덧살',
#  '부산연제구디너코스',
#  '부산연제구디저트',
#  '부산연제구딤섬',
#  '부산연제구따개비칼국수',
#  '부산연제구따로국밥',
#  '부산연제구딱새우',
#  '부산연제구딴딴면',
#  '부산연제구딸기막걸리',
#  '부산연제구딸기',
#  '부산연제구땡초',
#  '부산연제구떠먹는피자',
#  '부산연제구떡갈비',
#  '부산연제구떡국',
#  '부산연제구떡볶이',
#  '부산연제구떡케이크',
#  '부산연제구똠얌쌀국수',
#  '부산연제구뚝배기감자탕',
#  '부산연제구뚝배기닭볶음탕',
#  '부산연제구뚝배기불고기',
#  '부산연제구뚱카롱',
#  '부산연제구라구파스타',
#  '부산연제구라따뚜이',
#  '부산연제구라멘',
#  '부산연제구라면',
#  '부산연제구라볶이',
#  '부산연제구라오스음식',
#  '부산연제구라자냐',
#  '부산연제구라코타치즈샐러드',
#  '부산연제구라클렛',
#  '부산연제구랍스타',
#  '부산연제구랩피자',
#  '부산연제구러스크',
#  '부산연제구러시아',
#  '부산연제구런치코스',
#  '부산연제구레드락',
#  '부산연제구레모네이드',
#  '부산연제구레몬마들렌',
#  '부산연제구레몬에이드',
#  '부산연제구레몬탕수육',
#  '부산연제구레몬티',
#  '부산연제구레스토랑',
#  '부산연제구레터링케이크',
#  '부산연제구로바다야키',
#  '부산연제구로스',
#  '부산연제구로스트비프',
#  '부산연제구로스팅',
#  '부산연제구로제떡볶이',
#  '부산연제구로제빠네',
#  '부산연제구로제찜닭',
#  '부산연제구로제파스타',
#  '부산연제구롤케이크',
#  '부산연제구루꼴라',
#  '부산연제구루프탑',
#  '부산연제구룽고',
#  '부산연제구류산슬',
#  '부산연제구리조또',
#  '부산연제구리코타치즈샐러드',
#  '부산연제구립아이',
#  '부산연제구링귀니',
#  '부산연제구마구로',
#  '부산연제구마늘간장',
#  '부산연제구마늘곱창',
#  '부산연제구마늘닭',
#  '부산연제구마늘떡볶이',
#  '부산연제구마늘바게트',
#  '부산연제구마늘보쌈',
#  '부산연제구마늘볶음밥',
#  '부산연제구마늘빵',
#  '부산연제구마늘족발',
#  '부산연제구마늘치킨',
#  '부산연제구마늘탕수육',
#  '부산연제구마늘통닭',
#  '부산연제구마들렌',
#  '부산연제구마라',
#  '부산연제구마라샹궈',
#  '부산연제구마르게리타',
#  '부산연제구마스카포네피자',
#  '부산연제구마약김밥',
#  '부산연제구마약옥수수',
#  '부산연제구마제',
#  '부산연제구마카롱',
#  '부산연제구마파두부',
#  '부산연제구막걸리',
#  '부산연제구막국수',
#  '부산연제구막창',
#  '부산연제구막회',
#  '부산연제구만두',
#  '부산연제구만두전골',
#  '부산연제구말차',
#  '부산연제구맑은버섯탕',
#  '부산연제구맛감자',
#  '부산연제구망고',
#  '부산연제구매생이',
#  '부산연제구매운갈비찜',
#  '부산연제구매운냉면',
#  '부산연제구매운닭발',
#  '부산연제구매운돈까스',
#  '부산연제구매운등갈비',
#  '부산연제구매운등뼈찜',
#  '부산연제구매운부타동',
#  '부산연제구매운뼈찜',
#  '부산연제구매운오뎅',
#  '부산연제구매운족발',
#  '부산연제구매운쭈꾸미',
#  '부산연제구매운탕',
#  '부산연제구매콤불닭',
#  '부산연제구매콤크림파스타',
#  '부산연제구맥주',
#  '부산연제구머릿고기',
#  '부산연제구머쉬룸버거',
#  '부산연제구머핀',
#  '부산연제구먹태',
#  '부산연제구멍게',
#  '부산연제구멍게비빔밥',
#  '부산연제구메기',
#  '부산연제구메기매운탕',
#  '부산연제구메로구이',
#  '부산연제구메론빙수',
#  '부산연제구메밀',
#  '부산연제구메밀전병',
#  '부산연제구멕시칸',
#  '부산연제구멘보샤',
#  '부산연제구멜란자네',
#  '부산연제구멜론빙수',
#  '부산연제구멜젓',
#  '부산연제구멸치',
#  '부산연제구명란',
#  '부산연제구명란파스타',
#  '부산연제구명이나물',
#  '부산연제구명태',
#  '부산연제구모나카',
#  '부산연제구모던한식',
#  '부산연제구모두부',
#  '부산연제구모둠구이',
#  '부산연제구모둠회',
#  '부산연제구모듬사시미',
#  '부산연제구모듬수육',
#  '부산연제구모듬전',
#  '부산연제구모듬조개',
#  '부산연제구모듬철판구이',
#  '부산연제구모듬초밥',
#  '부산연제구모듬튀김',
#  '부산연제구모듬해산물',
#  '부산연제구모로코',
#  '부산연제구모밀',
#  '부산연제구모소리살',
#  '부산연제구모주',
#  '부산연제구모찌리도후',
#  '부산연제구모츠나베',
#  '부산연제구모카번',
#  '부산연제구모히또',
#  '부산연제구목등심',
#  '부산연제구목살',
#  '부산연제구목살필라프',
#  '부산연제구목화솜탕수육',
#  '부산연제구몸국',
#  '부산연제구몽골음식',
#  '부산연제구몽블랑',
#  '부산연제구무가당',
#  '부산연제구무국',
#  '부산연제구무뼈닭발',
#  '부산연제구무쇠솥밥',
#  '부산연제구무지개케이크',
#  '부산연제구무침',
#  '부산연제구무한리필조개구이',
#  '부산연제구무화과',
#  '부산연제구묵밥',
#  '부산연제구묵은지',
#  '부산연제구문어',
#  '부산연제구물갈비',
#  '부산연제구물곰탕',
#  '부산연제구물국수',
#  '부산연제구물냉면',
#  '부산연제구물닭갈비',
#  '부산연제구물막국수',
#  '부산연제구물만두',
#  '부산연제구물짜장',
#  '부산연제구물쫄면',
#  '부산연제구물칡냉면',
#  '부산연제구물회',
#  '부산연제구미고랭',
#  '부산연제구미국가정식',
#  '부산연제구미국식바베큐',
#  '부산연제구미나리',
#  '부산연제구미니우동',
#  '부산연제구미니족발',
#  '부산연제구미숫가루',
#  '부산연제구미역국',
#  '부산연제구미트볼',
#  '부산연제구민물매운탕',
#  '부산연제구민물장어',
#  '부산연제구민어',
#  '부산연제구민트초코',
#  '부산연제구밀면',
#  '부산연제구밀복',
#  '부산연제구밀크빙수',
#  '부산연제구밀크티',
#  '부산연제구밀키트',
#  '부산연제구밀푀유',
#  '부산연제구바게트',
#  '부산연제구바닐라',
#  '부산연제구바다장어',
#  '부산연제구바베큐',
#  '부산연제구바싹불고기',
#  '부산연제구바오',
#  '부산연제구바지락',
#  '부산연제구박대구이',
#  '부산연제구박속',
#  '부산연제구반미',
#  '부산연제구반상',
#  '부산연제구반세오',
#  '부산연제구반찬가게',
#  '부산연제구발국수',
#  '부산연제구발리음식',
#  '부산연제구밤라떼',
#  '부산연제구밤식빵',
#  '부산연제구밥버거',
#  '부산연제구방어',
#  '부산연제구백골뱅이탕',
#  '부산연제구백반',
#  '부산연제구백숙',
#  '부산연제구백순대',
#  '부산연제구백짬뽕',
#  '부산연제구백차',
#  '부산연제구백합죽',
#  '부산연제구밴댕이회',
#  '부산연제구뱅쇼',
#  '부산연제구버거',
#  '부산연제구버블티',
#  '부산연제구버섯',
#  '부산연제구버터갈릭감자튀김',
#  '부산연제구버터난',
#  '부산연제구버터밀크',
#  '부산연제구번데기',
#  '부산연제구벌집껍데기',
#  '부산연제구벚꽃빙수',
#  '부산연제구베이글',
#  '부산연제구베이징덕',
#  '부산연제구베이커리',
#  '부산연제구베이컨',
#  '부산연제구베트남쌀국수',
#  '부산연제구베트남연유커피',
#  '부산연제구벤또',
#  '부산연제구벨기에와플',
#  '부산연제구병어',
#  '부산연제구병천순대',
#  '부산연제구보리굴비',
#  '부산연제구보리밥',
#  '부산연제구보리새우',
#  '부산연제구보말죽',
#  '부산연제구보신탕',
#  '부산연제구보쌈',
#  '부산연제구보이차',
#  '부산연제구복국',
#  '부산연제구복숭아아이스티',
#  '부산연제구복집',
#  '부산연제구볶음국수',
#  '부산연제구볶음밥',
#  '부산연제구볶음짜장',
#  '부산연제구볶음짬뽕',
#  '부산연제구봉골레',
#  '부산연제구부각',
#  '부산연제구부대볶음',
#  '부산연제구부대전골',
#  '부산연제구부대찌개',
#  '부산연제구부산오뎅',
#  '부산연제구부채살',
#  '부산연제구부추전',
#  '부산연제구부타동',
#  '부산연제구부페',
#  '부산연제구북경오리',
#  '부산연제구북어국',
#  '부산연제구북유럽',
#  '부산연제구북한음식',
#  '부산연제구분식',
#  '부산연제구분짜',
#  '부산연제구불갈비',
#  '부산연제구불고기',
#  '부산연제구불낙전골',
#  '부산연제구불닭',
#  '부산연제구불도장',
#  '부산연제구불막창',
#  '부산연제구불맛쭈꾸미',
#  '부산연제구불백',
#  '부산연제구불오징어',
#  '부산연제구불족발',
#  '부산연제구불짜장',
#  '부산연제구불짬뽕',
#  '부산연제구불쭈꾸미',
#  '부산연제구불향낙지',
#  '부산연제구붓카케우동',
#  '부산연제구붕장어',
#  '부산연제구브라우니',
#  '부산연제구브라질',
#  '부산연제구브런치',
#  '부산연제구브리또',
#  '부산연제구블랙티',
#  '부산연제구블루베리',
#  '부산연제구비건',
#  '부산연제구비빔국수',
#  '부산연제구비빔냉면',
#  '부산연제구비빔막국수',
#  '부산연제구비빔만두',
#  '부산연제구비빔메밀',
#  '부산연제구비빔면',
#  '부산연제구비빔밥',
#  '부산연제구비빔손칼국수',
#  '부산연제구비빔쫄면',
#  '부산연제구비빔칼국수',
#  '부산연제구비스마르크',
#  '부산연제구비스트로',
#  '부산연제구비엔나커피',
#  '부산연제구비지찌개',
#  '부산연제구비프',
#  '부산연제구빈대떡',
#  '부산연제구빙수',
#  '부산연제구빙어튀김',
#  '부산연제구빠가탕',
#  '부산연제구빠네',
#  '부산연제구빠에야',
#  '부산연제구빨간오뎅',
#  '부산연제구빨계떡',
#  '부산연제구빵집',
#  '부산연제구뻥튀기',
#  '부산연제구뼈감자탕',
#  '부산연제구뼈닭발',
#  '부산연제구뼈없는닭발',
#  '부산연제구뼈찜',
#  '부산연제구뼈해장국',
#  '부산연제구뽈살',
#  '부산연제구뽈찜',
#  '부산연제구사골곰탕',
#  '부산연제구사라다빵',
#  '부산연제구사시미',
#  '부산연제구사이공라떼',
#  '부산연제구사찰음식',
#  '부산연제구사천',
#  '부산연제구사철탕',
#  '부산연제구사케',
#  '부산연제구산꼼장어',
#  '부산연제구산나물',
#  '부산연제구산낙지',
#  '부산연제구산닭구이',
#  '부산연제구산미구엘',
#  '부산연제구산삼배양근삼계탕',
#  '부산연제구산야초',
#  '부산연제구산오징어',
#  '부산연제구산채백반',
#  '부산연제구산채비빔밥',
#  '부산연제구산채정식',
#  '부산연제구살얼음맥주',
#  '부산연제구살치살',
#  '부산연제구삼각갈비',
#  '부산연제구삼겹살',
#  '부산연제구삼계탕',
#  '부산연제구삼색전',
#  '부산연제구삼선고추짬뽕',
#  '부산연제구삼선짬뽕',
#  '부산연제구삼숙이탕',
#  '부산연제구삼치',
#  '부산연제구삼합',
#  '부산연제구상추튀김',
#  '부산연제구상황버섯',
#  '부산연제구새알팥죽',
#  '부산연제구새우',
#  '부산연제구새우튀김',
#  '부산연제구새우필라프',
#  '부산연제구새조개샤브샤브',
#  '부산연제구샌드위치',
#  '부산연제구샐러드',
#  '부산연제구샘플러',
#  '부산연제구생간',
#  '부산연제구생갈비',
#  '부산연제구생고기',
#  '부산연제구생과일주스',
#  '부산연제구생국수',
#  '부산연제구생굴',
#  '부산연제구생대구탕',
#  '부산연제구생도넛',
#  '부산연제구생돈까스',
#  '부산연제구생맥주',
#  '부산연제구생선구이',
#  '부산연제구생선까스',
#  '부산연제구생연어',
#  '부산연제구생오겹살',
#  '부산연제구생오리',
#  '부산연제구생크림케이크',
#  '부산연제구생태찌개',
#  '부산연제구샤브샤브',
#  '부산연제구샤오롱바오',
#  '부산연제구샤퀴테리',
#  '부산연제구샴페인',
#  '부산연제구서리태콩국수',
#  '부산연제구석갈비',
#  '부산연제구석쇠구이',
#  '부산연제구섞어찌개',
#  '부산연제구선술집',
#  '부산연제구선지국',
#  '부산연제구설기떡',
#  '부산연제구설농탕',
#  '부산연제구설렁탕',
#  '부산연제구섭죽',
#  '부산연제구섭해장국',
#  '부산연제구성게',
#  '부산연제구세꼬시',
#  '부산연제구세발낙지',
#  '부산연제구세숫대야냉면',
#  '부산연제구세이로무시',
#  '부산연제구센베',
#  '부산연제구소갈매기',
#  '부산연제구소갈비',
#  '부산연제구소고기무국',
#  '부산연제구소고기전골',
#  '부산연제구소고기짬뽕',
#  '부산연제구소고기편백찜',
#  '부산연제구소고기해장국',
#  '부산연제구소곱창',
#  '부산연제구소금구이',
#  '부산연제구소금아이스크림',
#  '부산연제구소금커피',
#  '부산연제구소꼬리찜',
#  '부산연제구소라숙회',
#  '부산연제구소룡포',
#  '부산연제구소머리국밥',
#  '부산연제구소머리수육',
#  '부산연제구소바',
#  '부산연제구소보로',
#  '부산연제구소불고기',
#  '부산연제구소불백',
#  '부산연제구소뼈해장국',
#  '부산연제구소세지',
#  '부산연제구소양념갈비',
#  '부산연제구손두부',
#  '부산연제구손만두',
#  '부산연제구손수제비',
#  '부산연제구손짜장',
#  '부산연제구손칼국수',
#  '부산연제구솔트커피',
#  '부산연제구송어',
#  '부산연제구송이버섯',
#  '부산연제구솥뚜껑삼겹살',
#  '부산연제구솥밥',
#  '부산연제구쇼가야끼',
#  '부산연제구쇼콜라',
#  '부산연제구수라상',
#  '부산연제구수박쥬스',
#  '부산연제구수산물',
#  '부산연제구수원왕갈비',
#  '부산연제구수육',
#  '부산연제구수육국밥',
#  '부산연제구수입맥주',
#  '부산연제구수정과',
#  '부산연제구수제꼬치',
#  '부산연제구수제도시락',
#  '부산연제구수제돈까스',
#  '부산연제구수제두부',
#  '부산연제구수제등심돈까스',
#  '부산연제구수제맥주',
#  '부산연제구수제버거',
#  '부산연제구수제비',
#  '부산연제구수제아이스크림',
#  '부산연제구수제양갱',
#  '부산연제구수제와플',
#  '부산연제구수제청',
#  '부산연제구수제초콜릿',
#  '부산연제구수제케이크',
#  '부산연제구수제티라미수',
#  '부산연제구수제햄버거',
#  '부산연제구수타면',
#  '부산연제구수타짜장',
#  '부산연제구수프',
#  '부산연제구수플레',
#  '부산연제구숙성돼지고기',
#  '부산연제구숙성등심',
#  '부산연제구숙성목살',
#  '부산연제구숙성삼겹살',
#  '부산연제구숙성생삼겹살',
#  '부산연제구숙성오겹살',
#  '부산연제구숙성통삼겹살',
#  '부산연제구숙성한우',
#  '부산연제구숙성한우등심',
#  '부산연제구숙성회',
#  '부산연제구순대',
#  '부산연제구순대볶음',
#  '부산연제구순대전골',
#  '부산연제구순두부',
#  '부산연제구순메밀',
#  '부산연제구순무김치',
#  '부산연제구순살강정',
#  '부산연제구술떡',
#  '부산연제구술찜',
#  '부산연제구숯불',
#  '부산연제구숯불꼼장어',
#  '부산연제구쉐이크',
#  '부산연제구쉬림프버거',
#  '부산연제구슈니첼',
#  '부산연제구슈마이',
#  '부산연제구슈크림',
#  '부산연제구슈톨렌',
#  '부산연제구슈하스코',
#  '부산연제구스끼야끼',
#  '부산연제구스몰비어',
#  '부산연제구스무디',
#  '부산연제구스시',
#  '부산연제구스시뷔페',
#  '부산연제구스위스식',
#  '부산연제구스지수육',
#  '부산연제구스지오뎅탕',
#  '부산연제구스콘',
#  '부산연제구스키야끼',
#  '부산연제구스테이크',
#  '부산연제구스테이크덮밥',
#  '부산연제구스테이크피자',
#  '부산연제구스테키동',
#  '부산연제구스텔라',
#  '부산연제구스튜',
#  '부산연제구스파게티',
#  '부산연제구스팸',
#  '부산연제구스페인식',
#  '부산연제구스프',
#  '부산연제구스프링롤',
#  '부산연제구슬로푸드',
#  '부산연제구시골밥상',
#  '부산연제구시금치',
#  '부산연제구시래기',
#  '부산연제구시저샐러드',
#  '부산연제구시카고피자',
#  '부산연제구시푸드',
#  '부산연제구식빵',
#  '부산연제구식육식당',
#  '부산연제구식혜',
#  '부산연제구신선로',
#  '부산연제구신쭈꾸미',
#  '부산연제구실내포장마차',
#  '부산연제구실비집',
#  '부산연제구심야식당',
#  '부산연제구싱가폴',
#  '부산연제구싱글몰트',
#  '부산연제구쌀국수',
#  '부산연제구쌀떡볶이',
#  '부산연제구쌀빵',
#  '부산연제구쌀케이크',
#  '부산연제구쌀통닭',
#  '부산연제구쌈밥',
#  '부산연제구쌍화차',
#  '부산연제구쏘가리매운탕',
#  '부산연제구쏘세지',
#  '부산연제구쑥라떼',
#  '부산연제구쑥인절미',
#  '부산연제구쑥차',
#  '부산연제구씨앗호떡',
#  '부산연제구씨푸드',
#  '부산연제구아강발',
#  '부산연제구아게다시도후',
#  '부산연제구아구찜',
#  '부산연제구아구탕',
#  '부산연제구아나고',
#  '부산연제구아란치니',
#  '부산연제구아롱사태',
#  '부산연제구아메리칸치즈버거',
#  '부산연제구아몬드크림라떼',
#  '부산연제구아바이순대',
#  '부산연제구아보카도',
#  '부산연제구아부라소바',
#  '부산연제구아시안푸드',
#  '부산연제구아이리쉬커피',
#  '부산연제구아이리쉬펍',
#  '부산연제구아이스모찌',
#  '부산연제구아이스크림',
#  '부산연제구아이스티',
#  '부산연제구아인슈페너',
#  '부산연제구아포카토',
#  '부산연제구안동국시',
#  '부산연제구안동찜닭',
#  '부산연제구안심돈까스',
#  '부산연제구안심스테이크',
#  '부산연제구안심탕수육',
#  '부산연제구안심파스타',
#  '부산연제구안창살',
#  '부산연제구안흥찐빵',
#  '부산연제구알곤이찜',
#  '부산연제구알곱창',
#  '부산연제구알리오올리오',
#  '부산연제구알밥',
#  '부산연제구알요리',
#  '부산연제구알탕',
#  '부산연제구앙금빵',
#  '부산연제구앙버터',
#  '부산연제구애프터눈티',
#  '부산연제구애플망고빙수',
#  '부산연제구애플파이',
#  '부산연제구애호박찌개',
#  '부산연제구야끼니꾸',
#  '부산연제구야끼도리',
#  '부산연제구야끼만두',
#  '부산연제구야끼소바',
#  '부산연제구야끼소바빵',
#  '부산연제구야끼우동',
#  '부산연제구야채곱창',
#  '부산연제구야채빵',
#  '부산연제구야채튀김',
#  '부산연제구야채호떡',
#  '부산연제구야키니쿠',
#  '부산연제구야키도리',
#  '부산연제구야키소바',
#  '부산연제구야키토리',
#  '부산연제구약과',
#  '부산연제구약초밥',
#  '부산연제구양갈비',
#  '부산연제구양고기',
#  '부산연제구양곱창',
#  '부산연제구양꼬치',
#  '부산연제구양념갈비',
#  '부산연제구양념게장',
#  '부산연제구양념곱창구이',
#  '부산연제구양념구이',
#  '부산연제구양념막창',
#  '부산연제구양념막창구이',
#  '부산연제구양념삼겹살',
#  '부산연제구양념오뎅',
#  '부산연제구양념족발',
#  '부산연제구양념치킨',
#  '부산연제구양다리',
#  '부산연제구양대창',
#  '부산연제구양밥',
#  '부산연제구양선지해장국',
#  '부산연제구양식',
#  '부산연제구양장피',
#  '부산연제구양지곰탕',
#  '부산연제구양지쌀국수',
#  '부산연제구양푼갈비',
#  '부산연제구어니언링',
#  '부산연제구어란파스타',
#  '부산연제구어리굴젓',
#  '부산연제구어만두',
#  '부산연제구어묵',
#  '부산연제구어묵고로케',
#  '부산연제구어묵탕',
#  '부산연제구어복쟁반',
#  '부산연제구어죽',
#  '부산연제구어탕국수',
#  '부산연제구어향가지',
#  '부산연제구어향동고',
#  '부산연제구언양불고기',
#  '부산연제구얼그레이',
#  '부산연제구얼큰곰탕',
#  '부산연제구얼큰라면',
#  '부산연제구얼큰설렁탕',
#  '부산연제구얼큰수제비',
#  '부산연제구얼큰순두부',
#  '부산연제구얼큰칼국수',
#  '부산연제구얼큰탕',
#  '부산연제구엄나무백숙',
#  '부산연제구에그마요',
#  '부산연제구에그베네딕트',
#  '부산연제구에그타르트',
#  '부산연제구에그토스트',
#  '부산연제구에끌레르',
#  '부산연제구에비동',
#  ...]

# %%
# 음식이름으로 검색
search_list = target

restaurant_df = pd.DataFrame()
date=str(datetime.date.today()).replace('-','')[2:]

for f_name in search_list:
    url = f'https://www.diningcode.com/list.php?query={f_name}'
    
    seed = np.random.randint(100)
    np.random.seed(seed)    
    a = np.random.randint(5)
    time.sleep(a)
    try:
        response = requests.get(url) 
    except:
        print('page error')
        break
        
    data = BeautifulSoup(response.text, 'html.parser')

    # 순위제거(상황봐서 순위 넣으려면 반복문만 주석처리)
    store = [name.text for name in data.select('span.btxt')]
    for i in range(len(store)):
        store[i] = store[i][3:]

    # 주소정보
    summary = [s_mary.text for s_mary in data.select('span.stxt')]
    sub_loca = [sub.text for sub in data.select('i.loca')]
    full_loca = [full_l.text for full_l in data.select('span.ctxt')][1::2]

    # full_loca 중복처리
    try:
        for i in range(len(full_loca)):
            if full_loca[i][0:len(sub_loca[i])] == sub_loca[i]:
                full_loca[i] = full_loca[i][len(sub_loca[i]):]
            else:
                pass
    except: pass
    
    # 카테고리 지정
    category = [f_name] * len(full_loca)
    food_cat = [f_name[3:]] * len(full_loca)
    
    # 점수
    score = [point.text for point in data.select('span.point')]

    cat_df = pd.DataFrame(columns=['category','food_cat','store','score','summary','sub_loca','full_loca'], data=list(zip(category,food_cat,store,score,summary,sub_loca,full_loca)))
    temp = cat_df
    restaurant_df = pd.concat([restaurant_df,temp])
    restaurant_df.index=range(1,len(restaurant_df)+1)
    print(f'{f_name} 크롤링 완료')

print('\n *****크롤링완료*****')

# test
restaurant_df.to_csv(f'/Users/ppangppang/Desktop/맛집리스트확인/{date}_restaurant_list4.csv',index=False)

# 데이터저장
restaurant_df.to_csv(f'/Users/ppangppang/Documents/dev/TIL/test_restaurant_data/{date}_restaurant_list4.csv',index=False)
# 백업4
restaurant_df.to_csv(f'/Users/ppangppang/Desktop/ssac/data_crwaling/restaurant_test/databackup/{date}_restaurant_list4.csv',index=False)
# Out:
# 부산연제구가라아게 크롤링 완료
# 부산연제구가리국밥 크롤링 완료
# 부산연제구가리비 크롤링 완료
# 부산연제구가릿국밥 크롤링 완료
# 부산연제구가마솥 크롤링 완료
# 부산연제구가맥 크롤링 완료
# 부산연제구가브리살 크롤링 완료
# 부산연제구가오리 크롤링 완료
# 부산연제구가자미물회 크롤링 완료
# 부산연제구가자미미역국 크롤링 완료
# 부산연제구가정식 크롤링 완료
# 부산연제구가지요리 크롤링 완료
# 부산연제구가츠나베 크롤링 완료
# 부산연제구가츠동 크롤링 완료
# 부산연제구가츠산도 크롤링 완료
# 부산연제구각재기국 크롤링 완료
# 부산연제구간장구이 크롤링 완료
# 부산연제구간장덮밥 크롤링 완료
# 부산연제구간장새우 크롤링 완료
# 부산연제구간재미 크롤링 완료
# 부산연제구간짜장 크롤링 완료
# 부산연제구갈낙찜 크롤링 완료
# 부산연제구갈낙탕 크롤링 완료
# 부산연제구갈릭난 크롤링 완료
# 부산연제구갈릭돈까스 크롤링 완료
# 부산연제구갈릭버거 크롤링 완료
# 부산연제구갈릭버터쉬림프 크롤링 완료
# 부산연제구갈릭쉬림프 크롤링 완료
# 부산연제구갈릭스테이크 크롤링 완료
# 부산연제구갈릭페뇨파스타 크롤링 완료
# 부산연제구갈매기살 크롤링 완료
# 부산연제구갈비 크롤링 완료
# 부산연제구갈추어탕 크롤링 완료
# 부산연제구갈치 크롤링 완료
# 부산연제구감바스 크롤링 완료
# 부산연제구감바스알아히요 크롤링 완료
# 부산연제구감베로니 크롤링 완료
# 부산연제구감베리크레마 크롤링 완료
# 부산연제구감성돔 크롤링 완료
# 부산연제구감자고로케 크롤링 완료
# 부산연제구감자국 크롤링 완료
# 부산연제구감자국수 크롤링 완료
# 부산연제구감자뇨끼 크롤링 완료
# 부산연제구감자떡 크롤링 완료
# 부산연제구감자빵 크롤링 완료
# 부산연제구감자수제비 크롤링 완료
# 부산연제구감자스프 크롤링 완료
# 부산연제구감자옹심이 크롤링 완료
# 부산연제구감자전 크롤링 완료
# 부산연제구감자탕 크롤링 완료
# 부산연제구감자튀김 크롤링 완료
# 부산연제구갑오징어 크롤링 완료
# 부산연제구강된장 크롤링 완료
# 부산연제구강된장비빔밥 크롤링 완료
# 부산연제구개스트로펍 크롤링 완료
# 부산연제구객주리조림 크롤링 완료
# 부산연제구갯장어 크롤링 완료
# 부산연제구건강빵 크롤링 완료
# 부산연제구건두부볶음 크롤링 완료
# 부산연제구검은콩국수 크롤링 완료
# 부산연제구게국지 크롤링 완료
# 부산연제구게살비빔밥 크롤링 완료
# 부산연제구게장 크롤링 완료
# 부산연제구간장게장 크롤링 완료
# 부산연제구게찜 크롤링 완료
# 부산연제구경양식 크롤링 완료
# 부산연제구계란김밥 크롤링 완료
# 부산연제구계란말이 크롤링 완료
# 부산연제구계란찜 크롤링 완료
# 부산연제구계란토스트 크롤링 완료
# 부산연제구고갈비 크롤링 완료
# 부산연제구고구마 크롤링 완료
# 부산연제구고기국수 크롤링 완료
# 부산연제구고기군만두 크롤링 완료
# 부산연제구고기만두 크롤링 완료
# 부산연제구고기말이 크롤링 완료
# 부산연제구고기뷔페 크롤링 완료
# 부산연제구고기짬뽕 크롤링 완료
# 부산연제구고기튀김 크롤링 완료
# 부산연제구고등어 크롤링 완료
# 부산연제구고로케 크롤링 완료
# 부산연제구고르곤졸라 크롤링 완료
# 부산연제구고사리육개장 크롤링 완료
# 부산연제구고추군만두 크롤링 완료
# 부산연제구고추닭튀김 크롤링 완료
# 부산연제구고추부각 크롤링 완료
# 부산연제구고추장 크롤링 완료
# 부산연제구고추전 크롤링 완료
# 부산연제구고추짜장 크롤링 완료
# 부산연제구고추짬뽕 크롤링 완료
# 부산연제구고추튀김 크롤링 완료
# 부산연제구곤드레 크롤링 완료
# 부산연제구곤이 크롤링 완료
# 부산연제구골뱅이 크롤링 완료
# 부산연제구곰국 크롤링 완료
# 부산연제구곰국시 크롤링 완료
# 부산연제구곰장어 크롤링 완료
# 부산연제구곰치국 크롤링 완료
# 부산연제구곰탕 크롤링 완료
# 부산연제구곱도리탕 크롤링 완료
# 부산연제구곱창 크롤링 완료
# 부산연제구곱창국수 크롤링 완료
# 부산연제구곱창떡볶이 크롤링 완료
# 부산연제구곱창모듬 크롤링 완료
# 부산연제구곱창볶음 크롤링 완료
# 부산연제구곱창순대전골 크롤링 완료
# 부산연제구곱창순두부 크롤링 완료
# 부산연제구곱창쌀국수 크롤링 완료
# 부산연제구곱창전골 크롤링 완료
# 부산연제구과메기 크롤링 완료
# 부산연제구과일디저트 크롤링 완료
# 부산연제구과일주스 크롤링 완료
# 부산연제구관자구이 크롤링 완료
# 부산연제구광동식 크롤링 완료
# 부산연제구광양불고기 크롤링 완료
# 부산연제구광어 크롤링 완료
# 부산연제구교자 크롤링 완료
# 부산연제구구운치킨 크롤링 완료
# 부산연제구국물닭발 크롤링 완료
# 부산연제구국물떡볶이 크롤링 완료
# 부산연제구국밥 크롤링 완료
# 부산연제구국수 크롤링 완료
# 부산연제구국시 크롤링 완료
# 부산연제구군만두 크롤링 완료
# 부산연제구굴림만두 크롤링 완료
# 부산연제구굴 크롤링 완료
# 부산연제구궁중음식 크롤링 완료
# 부산연제구규동 크롤링 완료
# 부산연제구규카츠 크롤링 완료
# 부산연제구그라탕 크롤링 완료
# 부산연제구그리스식 크롤링 완료
# 부산연제구그릭요거트 크롤링 완료
# 부산연제구그린티 크롤링 완료
# 부산연제구그릴드샌드위치 크롤링 완료
# 부산연제구근고기 크롤링 완료
# 부산연제구기네스 크롤링 완료
# 부산연제구기절낙지 크롤링 완료
# 부산연제구김말이 크롤링 완료
# 부산연제구김밥 크롤링 완료
# 부산연제구김치나베 크롤링 완료
# 부산연제구김치낙지죽 크롤링 완료
# 부산연제구김치덮밥 크롤링 완료
# 부산연제구김치돈까스 크롤링 완료
# 부산연제구김치돼지찌개 크롤링 완료
# 부산연제구김치두루치기 크롤링 완료
# 부산연제구김치만두 크롤링 완료
# 부산연제구김치말이국수 크롤링 완료
# 부산연제구김치보쌈 크롤링 완료
# 부산연제구김치볶음밥 크롤링 완료
# 부산연제구김치수제비 크롤링 완료
# 부산연제구김치순두부 크롤링 완료
# 부산연제구김치왕만두 크롤링 완료
# 부산연제구김치우동 크롤링 완료
# 부산연제구김치전 크롤링 완료
# 부산연제구김치전골 크롤링 완료
# 부산연제구김치제육볶음 크롤링 완료
# 부산연제구김치찌개 크롤링 완료
# 부산연제구김치치즈나베 크롤링 완료
# 부산연제구김치칼국수 크롤링 완료
# 부산연제구김치콩나물국밥 크롤링 완료
# 부산연제구까눌레 크롤링 완료
# 부산연제구까르보나라 크롤링 완료
# 부산연제구까페 크롤링 완료
# 부산연제구깍두기볶음밥 크롤링 완료
# 부산연제구깐풍기 크롤링 완료
# 부산연제구깔조네 크롤링 완료
# 부산연제구껍데기 크롤링 완료
# 부산연제구꼬들살 크롤링 완료
# 부산연제구꼬리곰탕 크롤링 완료
# 부산연제구꼬리찜 크롤링 완료
# 부산연제구꼬막 크롤링 완료
# 부산연제구꼬치 크롤링 완료
# 부산연제구꼼장어 크롤링 완료
# 부산연제구꽁보리밥 크롤링 완료
# 부산연제구꽁치찌개 크롤링 완료
# 부산연제구꽃게 크롤링 완료
# 부산연제구꽃등심 크롤링 완료
# 부산연제구꽃살 크롤링 완료
# 부산연제구꽃삼겹 크롤링 완료
# 부산연제구꽃새우 크롤링 완료
# 부산연제구꽃항정살 크롤링 완료
# 부산연제구꽈리고추 크롤링 완료
# 부산연제구꽈배기 크롤링 완료
# 부산연제구꿀막걸리 크롤링 완료
# 부산연제구꿀빵 크롤링 완료
# 부산연제구꿀호떡 크롤링 완료
# 부산연제구꿔바로우 크롤링 완료
# 부산연제구꿩 크롤링 완료
# 부산연제구나가사키짬뽕 크롤링 완료
# 부산연제구나베 크롤링 완료
# 부산연제구나비파이 크롤링 완료
# 부산연제구나시고랭 크롤링 완료
# 부산연제구나폴리피자 크롤링 완료
# 부산연제구낙곱새 크롤링 완료
# 부산연제구낙엽살 크롤링 완료
# 부산연제구낙지 크롤링 완료
# 부산연제구난자완스 크롤링 완료
# 부산연제구날치알 크롤링 완료
# 부산연제구남도음식 크롤링 완료
# 부산연제구남방즈케 크롤링 완료
# 부산연제구남아공음식 크롤링 완료
# 부산연제구납작만두 크롤링 완료
# 부산연제구내장 크롤링 완료
# 부산연제구냄비우동 크롤링 완료
# 부산연제구냉국수 크롤링 완료
# 부산연제구냉동삼겹살 크롤링 완료
# 부산연제구냉라면 크롤링 완료
# 부산연제구냉면 크롤링 완료
# 부산연제구냉모밀 크롤링 완료
# 부산연제구냉소바 크롤링 완료
# 부산연제구냉우동 크롤링 완료
# 부산연제구냉족 크롤링 완료
# 부산연제구냉짬뽕 크롤링 완료
# 부산연제구냉채족발 크롤링 완료
# 부산연제구냉칼국수 크롤링 완료
# 부산연제구냉콩국수 크롤링 완료
# 부산연제구네팔식 크롤링 완료
# 부산연제구노가리 크롤링 완료
# 부산연제구녹두빈대떡 크롤링 완료
# 부산연제구녹두전 크롤링 완료
# 부산연제구뇨끼 크롤링 완료
# 부산연제구누들 크롤링 완료
# 부산연제구누룽지탕 크롤링 완료
# 부산연제구누룽지통닭 크롤링 완료
# 부산연제구누텔라 크롤링 완료
# 부산연제구눈꽃빙수 크롤링 완료
# 부산연제구능이오리 크롤링 완료
# 부산연제구니꾸우동 크롤링 완료
# 부산연제구다금바리 크롤링 완료
# 부산연제구다슬기 크롤링 완료
# 부산연제구다이닝펍 크롤링 완료
# 부산연제구다찌 크롤링 완료
# 부산연제구다코야끼 크롤링 완료
# 부산연제구단팥빵 크롤링 완료
# 부산연제구단팥죽 크롤링 완료
# 부산연제구단호박 크롤링 완료
# 부산연제구달걀말이 크롤링 완료
# 부산연제구닭가슴살 크롤링 완료
# 부산연제구닭갈비 크롤링 완료
# 부산연제구닭강정 크롤링 완료
# 부산연제구닭개장 크롤링 완료
# 부산연제구닭곰탕 크롤링 완료
# 부산연제구닭구이 크롤링 완료
# 부산연제구닭국수 크롤링 완료
# 부산연제구닭껍질 크롤링 완료
# 부산연제구닭꼬치 크롤링 완료
# 부산연제구닭내장 크롤링 완료
# 부산연제구닭다리 크롤링 완료
# 부산연제구닭도리탕 크롤링 완료
# 부산연제구닭똥집 크롤링 완료
# 부산연제구닭목살 크롤링 완료
# 부산연제구닭발 크롤링 완료
# 부산연제구닭백숙 크롤링 완료
# 부산연제구닭볶음탕 크롤링 완료
# 부산연제구닭숯불구이 크롤링 완료
# 부산연제구닭죽 크롤링 완료
# 부산연제구닭칼국수 크롤링 완료
# 부산연제구닭한마리 크롤링 완료
# 부산연제구당근주스 크롤링 완료
# 부산연제구당근케이크 크롤링 완료
# 부산연제구대게 크롤링 완료
# 부산연제구대구매운탕 크롤링 완료
# 부산연제구대구뽈찜 크롤링 완료
# 부산연제구대구왕뽈찜 크롤링 완료
# 부산연제구대구전골 크롤링 완료
# 부산연제구대구탕 크롤링 완료
# 부산연제구대나무통밥 크롤링 완료
# 부산연제구대만샌드위치 크롤링 완료
# 부산연제구대방어 크롤링 완료
# 부산연제구대창 크롤링 완료
# 부산연제구대통밥 크롤링 완료
# 부산연제구대패삼겹살 크롤링 완료
# 부산연제구대하 크롤링 완료
# 부산연제구대합 크롤링 완료
# 부산연제구더덕 크롤링 완료
# 부산연제구더블치즈버거 크롤링 완료
# 부산연제구더치커피 크롤링 완료
# 부산연제구덕자 크롤링 완료
# 부산연제구데리야끼막창 크롤링 완료
# 부산연제구덴뿌라 크롤링 완료
# 부산연제구도가니 크롤링 완료
# 부산연제구도넛 크롤링 완료
# 부산연제구도다리쑥국 크롤링 완료
# 부산연제구도라지정과 크롤링 완료
# 부산연제구도래창 크롤링 완료
# 부산연제구도로초밥 크롤링 완료
# 부산연제구도루묵 크롤링 완료
# 부산연제구도리뱅뱅 크롤링 완료
# 부산연제구도리아 크롤링 완료
# 부산연제구도미 크롤링 완료
# 부산연제구도삭면 크롤링 완료
# 부산연제구도치알탕 크롤링 완료
# 부산연제구도토리 크롤링 완료
# 부산연제구독일식레스토랑 크롤링 완료
# 부산연제구돈까스 크롤링 완료
# 부산연제구돈부리 크롤링 완료
# 부산연제구돈치맛살 크롤링 완료
# 부산연제구돈코츠 크롤링 완료
# 부산연제구돈파스 크롤링 완료
# 부산연제구돌게장 크롤링 완료
# 부산연제구돌곱창 크롤링 완료
# 부산연제구돌문어 크롤링 완료
# 부산연제구돌솥밥 크롤링 완료
# 부산연제구돌판 크롤링 완료
# 부산연제구돔베고기 크롤링 완료
# 부산연제구동남아음식 크롤링 완료
# 부산연제구동동주 크롤링 완료
# 부산연제구동치미막국수 크롤링 완료
# 부산연제구동태탕 크롤링 완료
# 부산연제구동파육 크롤링 완료
# 부산연제구돼지갈비 크롤링 완료
# 부산연제구돼지고기탕수육 크롤링 완료
# 부산연제구돼지곱창전골 크롤링 완료
# 부산연제구돼지국밥 크롤링 완료
# 부산연제구돼지김치구이 크롤링 완료
# 부산연제구돼지김치찜 크롤링 완료
# 부산연제구돼지껍데기 크롤링 완료
# 부산연제구돼지꼬리 크롤링 완료
# 부산연제구돼지머리고기 크롤링 완료
# 부산연제구돼지부속 크롤링 완료
# 부산연제구돼지불고기 크롤링 완료
# 부산연제구돼지불백 크롤링 완료
# 부산연제구돼지양념갈비 크롤링 완료
# 부산연제구돼지왕갈비 크롤링 완료
# 부산연제구돼지주물럭 크롤링 완료
# 부산연제구돼지짜글이 크롤링 완료
# 부산연제구돼지특수부위 크롤링 완료
# 부산연제구된장국 크롤링 완료
# 부산연제구두루치기 크롤링 완료
# 부산연제구두부 크롤링 완료
# 부산연제구두부버섯전골 크롤링 완료
# 부산연제구두부요리전문 크롤링 완료
# 부산연제구뒷고기 크롤링 완료
# 부산연제구드라이에이징 크롤링 완료
# 부산연제구드립커피 크롤링 완료
# 부산연제구들기름막국수 크롤링 완료
# 부산연제구들깨 크롤링 완료
# 부산연제구등갈비 크롤링 완료
# 부산연제구등뼈찜 크롤링 완료
# 부산연제구등심 크롤링 완료
# 부산연제구등심덧살 크롤링 완료
# 부산연제구디너코스 크롤링 완료
# 부산연제구디저트 크롤링 완료
# 부산연제구딤섬 크롤링 완료
# 부산연제구따개비칼국수 크롤링 완료
# 부산연제구따로국밥 크롤링 완료
# 부산연제구딱새우 크롤링 완료
# 부산연제구딴딴면 크롤링 완료
# 부산연제구딸기막걸리 크롤링 완료
# 부산연제구딸기 크롤링 완료
# 부산연제구땡초 크롤링 완료
# 부산연제구떠먹는피자 크롤링 완료
# 부산연제구떡갈비 크롤링 완료
# 부산연제구떡국 크롤링 완료
# 부산연제구떡볶이 크롤링 완료
# 부산연제구떡케이크 크롤링 완료
# 부산연제구똠얌쌀국수 크롤링 완료
# 부산연제구뚝배기감자탕 크롤링 완료
# 부산연제구뚝배기닭볶음탕 크롤링 완료
# 부산연제구뚝배기불고기 크롤링 완료
# 부산연제구뚱카롱 크롤링 완료
# 부산연제구라구파스타 크롤링 완료
# 부산연제구라따뚜이 크롤링 완료
# 부산연제구라멘 크롤링 완료
# 부산연제구라면 크롤링 완료
# 부산연제구라볶이 크롤링 완료
# 부산연제구라오스음식 크롤링 완료
# 부산연제구라자냐 크롤링 완료
# 부산연제구라코타치즈샐러드 크롤링 완료
# 부산연제구라클렛 크롤링 완료
# 부산연제구랍스타 크롤링 완료
# 부산연제구랩피자 크롤링 완료
# 부산연제구러스크 크롤링 완료
# 부산연제구러시아 크롤링 완료
# 부산연제구런치코스 크롤링 완료
# 부산연제구레드락 크롤링 완료
# 부산연제구레모네이드 크롤링 완료
# 부산연제구레몬마들렌 크롤링 완료
# 부산연제구레몬에이드 크롤링 완료
# 부산연제구레몬탕수육 크롤링 완료
# 부산연제구레몬티 크롤링 완료
# 부산연제구레스토랑 크롤링 완료
# 부산연제구레터링케이크 크롤링 완료
# 부산연제구로바다야키 크롤링 완료
# 부산연제구로스 크롤링 완료
# 부산연제구로스트비프 크롤링 완료
# 부산연제구로스팅 크롤링 완료
# 부산연제구로제떡볶이 크롤링 완료
# 부산연제구로제빠네 크롤링 완료
# 부산연제구로제찜닭 크롤링 완료
# 부산연제구로제파스타 크롤링 완료
# 부산연제구롤케이크 크롤링 완료
# 부산연제구루꼴라 크롤링 완료
# 부산연제구루프탑 크롤링 완료
# 부산연제구룽고 크롤링 완료
# 부산연제구류산슬 크롤링 완료
# 부산연제구리조또 크롤링 완료
# 부산연제구리코타치즈샐러드 크롤링 완료
# 부산연제구립아이 크롤링 완료
# 부산연제구링귀니 크롤링 완료
# 부산연제구마구로 크롤링 완료
# 부산연제구마늘간장 크롤링 완료
# 부산연제구마늘곱창 크롤링 완료
# 부산연제구마늘닭 크롤링 완료
# 부산연제구마늘떡볶이 크롤링 완료
# 부산연제구마늘바게트 크롤링 완료
# 부산연제구마늘보쌈 크롤링 완료
# 부산연제구마늘볶음밥 크롤링 완료
# 부산연제구마늘빵 크롤링 완료
# 부산연제구마늘족발 크롤링 완료
# 부산연제구마늘치킨 크롤링 완료
# 부산연제구마늘탕수육 크롤링 완료
# 부산연제구마늘통닭 크롤링 완료
# 부산연제구마들렌 크롤링 완료
# 부산연제구마라 크롤링 완료
# 부산연제구마라샹궈 크롤링 완료
# 부산연제구마르게리타 크롤링 완료
# 부산연제구마스카포네피자 크롤링 완료
# 부산연제구마약김밥 크롤링 완료
# 부산연제구마약옥수수 크롤링 완료
# 부산연제구마제 크롤링 완료
# 부산연제구마카롱 크롤링 완료
# 부산연제구마파두부 크롤링 완료
# 부산연제구막걸리 크롤링 완료
# 부산연제구막국수 크롤링 완료
# 부산연제구막창 크롤링 완료
# 부산연제구막회 크롤링 완료
# 부산연제구만두 크롤링 완료
# 부산연제구만두전골 크롤링 완료
# 부산연제구말차 크롤링 완료
# 부산연제구맑은버섯탕 크롤링 완료
# 부산연제구맛감자 크롤링 완료
# 부산연제구망고 크롤링 완료
# 부산연제구매생이 크롤링 완료
# 부산연제구매운갈비찜 크롤링 완료
# 부산연제구매운냉면 크롤링 완료
# 부산연제구매운닭발 크롤링 완료
# 부산연제구매운돈까스 크롤링 완료
# 부산연제구매운등갈비 크롤링 완료
# 부산연제구매운등뼈찜 크롤링 완료
# 부산연제구매운부타동 크롤링 완료
# 부산연제구매운뼈찜 크롤링 완료
# 부산연제구매운오뎅 크롤링 완료
# 부산연제구매운족발 크롤링 완료
# 부산연제구매운쭈꾸미 크롤링 완료
# 부산연제구매운탕 크롤링 완료
# 부산연제구매콤불닭 크롤링 완료
# 부산연제구매콤크림파스타 크롤링 완료
# 부산연제구맥주 크롤링 완료
# 부산연제구머릿고기 크롤링 완료
# 부산연제구머쉬룸버거 크롤링 완료
# 부산연제구머핀 크롤링 완료
# 부산연제구먹태 크롤링 완료
# 부산연제구멍게 크롤링 완료
# 부산연제구멍게비빔밥 크롤링 완료
# 부산연제구메기 크롤링 완료
# 부산연제구메기매운탕 크롤링 완료
# 부산연제구메로구이 크롤링 완료
# 부산연제구메론빙수 크롤링 완료
# 부산연제구메밀 크롤링 완료
# 부산연제구메밀전병 크롤링 완료
# 부산연제구멕시칸 크롤링 완료
# 부산연제구멘보샤 크롤링 완료
# 부산연제구멜란자네 크롤링 완료
# 부산연제구멜론빙수 크롤링 완료
# 부산연제구멜젓 크롤링 완료
# 부산연제구멸치 크롤링 완료
# 부산연제구명란 크롤링 완료
# 부산연제구명란파스타 크롤링 완료
# 부산연제구명이나물 크롤링 완료
# 부산연제구명태 크롤링 완료
# 부산연제구모나카 크롤링 완료
# 부산연제구모던한식 크롤링 완료
# 부산연제구모두부 크롤링 완료
# 부산연제구모둠구이 크롤링 완료
# 부산연제구모둠회 크롤링 완료
# 부산연제구모듬사시미 크롤링 완료
# 부산연제구모듬수육 크롤링 완료
# 부산연제구모듬전 크롤링 완료
# 부산연제구모듬조개 크롤링 완료
# 부산연제구모듬철판구이 크롤링 완료
# 부산연제구모듬초밥 크롤링 완료
# 부산연제구모듬튀김 크롤링 완료
# 부산연제구모듬해산물 크롤링 완료
# 부산연제구모로코 크롤링 완료
# 부산연제구모밀 크롤링 완료
# 부산연제구모소리살 크롤링 완료
# 부산연제구모주 크롤링 완료
# 부산연제구모찌리도후 크롤링 완료
# 부산연제구모츠나베 크롤링 완료
# 부산연제구모카번 크롤링 완료
# 부산연제구모히또 크롤링 완료
# 부산연제구목등심 크롤링 완료
# 부산연제구목살 크롤링 완료
# 부산연제구목살필라프 크롤링 완료
# 부산연제구목화솜탕수육 크롤링 완료
# 부산연제구몸국 크롤링 완료
# 부산연제구몽골음식 크롤링 완료
# 부산연제구몽블랑 크롤링 완료
# 부산연제구무가당 크롤링 완료
# 부산연제구무국 크롤링 완료
# 부산연제구무뼈닭발 크롤링 완료
# 부산연제구무쇠솥밥 크롤링 완료
# 부산연제구무지개케이크 크롤링 완료
# 부산연제구무침 크롤링 완료
# 부산연제구무한리필조개구이 크롤링 완료
# 부산연제구무화과 크롤링 완료
# 부산연제구묵밥 크롤링 완료
# 부산연제구묵은지 크롤링 완료
# 부산연제구문어 크롤링 완료
# 부산연제구물갈비 크롤링 완료
# 부산연제구물곰탕 크롤링 완료
# 부산연제구물국수 크롤링 완료
# 부산연제구물냉면 크롤링 완료
# 부산연제구물닭갈비 크롤링 완료
# 부산연제구물막국수 크롤링 완료
# 부산연제구물만두 크롤링 완료
# 부산연제구물짜장 크롤링 완료
# 부산연제구물쫄면 크롤링 완료
# 부산연제구물칡냉면 크롤링 완료
# 부산연제구물회 크롤링 완료
# 부산연제구미고랭 크롤링 완료
# 부산연제구미국가정식 크롤링 완료
# 부산연제구미국식바베큐 크롤링 완료
# 부산연제구미나리 크롤링 완료
# 부산연제구미니우동 크롤링 완료
# 부산연제구미니족발 크롤링 완료
# 부산연제구미숫가루 크롤링 완료
# 부산연제구미역국 크롤링 완료
# 부산연제구미트볼 크롤링 완료
# 부산연제구민물매운탕 크롤링 완료
# 부산연제구민물장어 크롤링 완료
# 부산연제구민어 크롤링 완료
# 부산연제구민트초코 크롤링 완료
# 부산연제구밀면 크롤링 완료
# 부산연제구밀복 크롤링 완료
# 부산연제구밀크빙수 크롤링 완료
# 부산연제구밀크티 크롤링 완료
# 부산연제구밀키트 크롤링 완료
# 부산연제구밀푀유 크롤링 완료
# 부산연제구바게트 크롤링 완료
# 부산연제구바닐라 크롤링 완료
# 부산연제구바다장어 크롤링 완료
# 부산연제구바베큐 크롤링 완료
# 부산연제구바싹불고기 크롤링 완료
# 부산연제구바오 크롤링 완료
# 부산연제구바지락 크롤링 완료
# 부산연제구박대구이 크롤링 완료
# 부산연제구박속 크롤링 완료
# 부산연제구반미 크롤링 완료
# 부산연제구반상 크롤링 완료
# 부산연제구반세오 크롤링 완료
# 부산연제구반찬가게 크롤링 완료
# 부산연제구발국수 크롤링 완료
# 부산연제구발리음식 크롤링 완료
# 부산연제구밤라떼 크롤링 완료
# 부산연제구밤식빵 크롤링 완료
# 부산연제구밥버거 크롤링 완료
# 부산연제구방어 크롤링 완료
# 부산연제구백골뱅이탕 크롤링 완료
# 부산연제구백반 크롤링 완료
# 부산연제구백숙 크롤링 완료
# 부산연제구백순대 크롤링 완료
# 부산연제구백짬뽕 크롤링 완료
# 부산연제구백차 크롤링 완료
# 부산연제구백합죽 크롤링 완료
# 부산연제구밴댕이회 크롤링 완료
# 부산연제구뱅쇼 크롤링 완료
# 부산연제구버거 크롤링 완료
# 부산연제구버블티 크롤링 완료
# 부산연제구버섯 크롤링 완료
# 부산연제구버터갈릭감자튀김 크롤링 완료
# 부산연제구버터난 크롤링 완료
# 부산연제구버터밀크 크롤링 완료
# 부산연제구번데기 크롤링 완료
# 부산연제구벌집껍데기 크롤링 완료
# 부산연제구벚꽃빙수 크롤링 완료
# 부산연제구베이글 크롤링 완료
# 부산연제구베이징덕 크롤링 완료
# 부산연제구베이커리 크롤링 완료
# 부산연제구베이컨 크롤링 완료
# 부산연제구베트남쌀국수 크롤링 완료
# 부산연제구베트남연유커피 크롤링 완료
# 부산연제구벤또 크롤링 완료
# 부산연제구벨기에와플 크롤링 완료
# 부산연제구병어 크롤링 완료
# 부산연제구병천순대 크롤링 완료
# 부산연제구보리굴비 크롤링 완료
# 부산연제구보리밥 크롤링 완료
# 부산연제구보리새우 크롤링 완료
# 부산연제구보말죽 크롤링 완료
# 부산연제구보신탕 크롤링 완료
# 부산연제구보쌈 크롤링 완료
# 부산연제구보이차 크롤링 완료
# 부산연제구복국 크롤링 완료
# 부산연제구복숭아아이스티 크롤링 완료
# 부산연제구복집 크롤링 완료
# 부산연제구볶음국수 크롤링 완료
# 부산연제구볶음밥 크롤링 완료
# 부산연제구볶음짜장 크롤링 완료
# 부산연제구볶음짬뽕 크롤링 완료
# 부산연제구봉골레 크롤링 완료
# 부산연제구부각 크롤링 완료
# 부산연제구부대볶음 크롤링 완료
# 부산연제구부대전골 크롤링 완료
# 부산연제구부대찌개 크롤링 완료
# 부산연제구부산오뎅 크롤링 완료
# 부산연제구부채살 크롤링 완료
# 부산연제구부추전 크롤링 완료
# 부산연제구부타동 크롤링 완료
# 부산연제구부페 크롤링 완료
# 부산연제구북경오리 크롤링 완료
# 부산연제구북어국 크롤링 완료
# 부산연제구북유럽 크롤링 완료
# 부산연제구북한음식 크롤링 완료
# 부산연제구분식 크롤링 완료
# 부산연제구분짜 크롤링 완료
# 부산연제구불갈비 크롤링 완료
# 부산연제구불고기 크롤링 완료
# 부산연제구불낙전골 크롤링 완료
# 부산연제구불닭 크롤링 완료
# 부산연제구불도장 크롤링 완료
# 부산연제구불막창 크롤링 완료
# 부산연제구불맛쭈꾸미 크롤링 완료
# 부산연제구불백 크롤링 완료
# 부산연제구불오징어 크롤링 완료
# 부산연제구불족발 크롤링 완료
# 부산연제구불짜장 크롤링 완료
# 부산연제구불짬뽕 크롤링 완료
# 부산연제구불쭈꾸미 크롤링 완료
# 부산연제구불향낙지 크롤링 완료
# 부산연제구붓카케우동 크롤링 완료
# 부산연제구붕장어 크롤링 완료
# 부산연제구브라우니 크롤링 완료
# 부산연제구브라질 크롤링 완료
# 부산연제구브런치 크롤링 완료
# 부산연제구브리또 크롤링 완료
# 부산연제구블랙티 크롤링 완료
# 부산연제구블루베리 크롤링 완료
# 부산연제구비건 크롤링 완료
# 부산연제구비빔국수 크롤링 완료
# 부산연제구비빔냉면 크롤링 완료
# 부산연제구비빔막국수 크롤링 완료
# 부산연제구비빔만두 크롤링 완료
# 부산연제구비빔메밀 크롤링 완료
# 부산연제구비빔면 크롤링 완료
# 부산연제구비빔밥 크롤링 완료
# 부산연제구비빔손칼국수 크롤링 완료
# 부산연제구비빔쫄면 크롤링 완료
# 부산연제구비빔칼국수 크롤링 완료
# 부산연제구비스마르크 크롤링 완료
# 부산연제구비스트로 크롤링 완료
# 부산연제구비엔나커피 크롤링 완료
# 부산연제구비지찌개 크롤링 완료
# 부산연제구비프 크롤링 완료
# 부산연제구빈대떡 크롤링 완료
# 부산연제구빙수 크롤링 완료
# 부산연제구빙어튀김 크롤링 완료
# 부산연제구빠가탕 크롤링 완료
# 부산연제구빠네 크롤링 완료
# 부산연제구빠에야 크롤링 완료
# 부산연제구빨간오뎅 크롤링 완료
# 부산연제구빨계떡 크롤링 완료
# 부산연제구빵집 크롤링 완료
# 부산연제구뻥튀기 크롤링 완료
# 부산연제구뼈감자탕 크롤링 완료
# 부산연제구뼈닭발 크롤링 완료
# 부산연제구뼈없는닭발 크롤링 완료
# 부산연제구뼈찜 크롤링 완료
# 부산연제구뼈해장국 크롤링 완료
# 부산연제구뽈살 크롤링 완료
# 부산연제구뽈찜 크롤링 완료
# 부산연제구사골곰탕 크롤링 완료
# 부산연제구사라다빵 크롤링 완료
# 부산연제구사시미 크롤링 완료
# 부산연제구사이공라떼 크롤링 완료
# 부산연제구사찰음식 크롤링 완료
# 부산연제구사천 크롤링 완료
# 부산연제구사철탕 크롤링 완료
# 부산연제구사케 크롤링 완료
# 부산연제구산꼼장어 크롤링 완료
# 부산연제구산나물 크롤링 완료
# 부산연제구산낙지 크롤링 완료
# 부산연제구산닭구이 크롤링 완료
# 부산연제구산미구엘 크롤링 완료
# 부산연제구산삼배양근삼계탕 크롤링 완료
# 부산연제구산야초 크롤링 완료
# 부산연제구산오징어 크롤링 완료
# 부산연제구산채백반 크롤링 완료
# 부산연제구산채비빔밥 크롤링 완료
# 부산연제구산채정식 크롤링 완료
# 부산연제구살얼음맥주 크롤링 완료
# 부산연제구살치살 크롤링 완료
# 부산연제구삼각갈비 크롤링 완료
# 부산연제구삼겹살 크롤링 완료
# 부산연제구삼계탕 크롤링 완료
# 부산연제구삼색전 크롤링 완료
# 부산연제구삼선고추짬뽕 크롤링 완료
# 부산연제구삼선짬뽕 크롤링 완료
# 부산연제구삼숙이탕 크롤링 완료
# 부산연제구삼치 크롤링 완료
# 부산연제구삼합 크롤링 완료
# 부산연제구상추튀김 크롤링 완료
# 부산연제구상황버섯 크롤링 완료
# 부산연제구새알팥죽 크롤링 완료
# 부산연제구새우 크롤링 완료
# 부산연제구새우튀김 크롤링 완료
# 부산연제구새우필라프 크롤링 완료
# 부산연제구새조개샤브샤브 크롤링 완료
# 부산연제구샌드위치 크롤링 완료
# 부산연제구샐러드 크롤링 완료
# 부산연제구샘플러 크롤링 완료
# 부산연제구생간 크롤링 완료
# 부산연제구생갈비 크롤링 완료
# 부산연제구생고기 크롤링 완료
# 부산연제구생과일주스 크롤링 완료
# 부산연제구생국수 크롤링 완료
# 부산연제구생굴 크롤링 완료
# 부산연제구생대구탕 크롤링 완료
# 부산연제구생도넛 크롤링 완료
# 부산연제구생돈까스 크롤링 완료
# 부산연제구생맥주 크롤링 완료
# 부산연제구생선구이 크롤링 완료
# 부산연제구생선까스 크롤링 완료
# 부산연제구생연어 크롤링 완료
# 부산연제구생오겹살 크롤링 완료
# 부산연제구생오리 크롤링 완료
# 부산연제구생크림케이크 크롤링 완료
# 부산연제구생태찌개 크롤링 완료
# 부산연제구샤브샤브 크롤링 완료
# 부산연제구샤오롱바오 크롤링 완료
# 부산연제구샤퀴테리 크롤링 완료
# 부산연제구샴페인 크롤링 완료
# 부산연제구서리태콩국수 크롤링 완료
# 부산연제구석갈비 크롤링 완료
# 부산연제구석쇠구이 크롤링 완료
# 부산연제구섞어찌개 크롤링 완료
# 부산연제구선술집 크롤링 완료
# 부산연제구선지국 크롤링 완료
# 부산연제구설기떡 크롤링 완료
# 부산연제구설농탕 크롤링 완료
# 부산연제구설렁탕 크롤링 완료
# 부산연제구섭죽 크롤링 완료
# 부산연제구섭해장국 크롤링 완료
# 부산연제구성게 크롤링 완료
# 부산연제구세꼬시 크롤링 완료
# 부산연제구세발낙지 크롤링 완료
# 부산연제구세숫대야냉면 크롤링 완료
# 부산연제구세이로무시 크롤링 완료
# 부산연제구센베 크롤링 완료
# 부산연제구소갈매기 크롤링 완료
# 부산연제구소갈비 크롤링 완료
# 부산연제구소고기무국 크롤링 완료
# 부산연제구소고기전골 크롤링 완료
# 부산연제구소고기짬뽕 크롤링 완료
# 부산연제구소고기편백찜 크롤링 완료
# 부산연제구소고기해장국 크롤링 완료
# 부산연제구소곱창 크롤링 완료
# 부산연제구소금구이 크롤링 완료
# 부산연제구소금아이스크림 크롤링 완료
# 부산연제구소금커피 크롤링 완료
# 부산연제구소꼬리찜 크롤링 완료
# 부산연제구소라숙회 크롤링 완료
# 부산연제구소룡포 크롤링 완료
# 부산연제구소머리국밥 크롤링 완료
# 부산연제구소머리수육 크롤링 완료
# 부산연제구소바 크롤링 완료
# 부산연제구소보로 크롤링 완료
# 부산연제구소불고기 크롤링 완료
# 부산연제구소불백 크롤링 완료
# 부산연제구소뼈해장국 크롤링 완료
# 부산연제구소세지 크롤링 완료
# 부산연제구소양념갈비 크롤링 완료
# 부산연제구손두부 크롤링 완료
# 부산연제구손만두 크롤링 완료
# 부산연제구손수제비 크롤링 완료
# 부산연제구손짜장 크롤링 완료
# 부산연제구손칼국수 크롤링 완료
# 부산연제구솔트커피 크롤링 완료
# 부산연제구송어 크롤링 완료
# 부산연제구송이버섯 크롤링 완료
# 부산연제구솥뚜껑삼겹살 크롤링 완료
# 부산연제구솥밥 크롤링 완료
# 부산연제구쇼가야끼 크롤링 완료
# 부산연제구쇼콜라 크롤링 완료
# 부산연제구수라상 크롤링 완료
# 부산연제구수박쥬스 크롤링 완료
# 부산연제구수산물 크롤링 완료
# 부산연제구수원왕갈비 크롤링 완료
# 부산연제구수육 크롤링 완료
# 부산연제구수육국밥 크롤링 완료
# 부산연제구수입맥주 크롤링 완료
# 부산연제구수정과 크롤링 완료
# 부산연제구수제꼬치 크롤링 완료
# 부산연제구수제도시락 크롤링 완료
# 부산연제구수제돈까스 크롤링 완료
# 부산연제구수제두부 크롤링 완료
# 부산연제구수제등심돈까스 크롤링 완료
# 부산연제구수제맥주 크롤링 완료
# 부산연제구수제버거 크롤링 완료
# 부산연제구수제비 크롤링 완료
# 부산연제구수제아이스크림 크롤링 완료
# 부산연제구수제양갱 크롤링 완료
# 부산연제구수제와플 크롤링 완료
# 부산연제구수제청 크롤링 완료
# 부산연제구수제초콜릿 크롤링 완료
# 부산연제구수제케이크 크롤링 완료
# 부산연제구수제티라미수 크롤링 완료
# 부산연제구수제햄버거 크롤링 완료
# 부산연제구수타면 크롤링 완료
# 부산연제구수타짜장 크롤링 완료
# 부산연제구수프 크롤링 완료
# 부산연제구수플레 크롤링 완료
# 부산연제구숙성돼지고기 크롤링 완료
# 부산연제구숙성등심 크롤링 완료
# 부산연제구숙성목살 크롤링 완료
# 부산연제구숙성삼겹살 크롤링 완료
# 부산연제구숙성생삼겹살 크롤링 완료
# 부산연제구숙성오겹살 크롤링 완료
# 부산연제구숙성통삼겹살 크롤링 완료
# 부산연제구숙성한우 크롤링 완료
# 부산연제구숙성한우등심 크롤링 완료
# 부산연제구숙성회 크롤링 완료
# 부산연제구순대 크롤링 완료
# 부산연제구순대볶음 크롤링 완료
# 부산연제구순대전골 크롤링 완료
# 부산연제구순두부 크롤링 완료
# 부산연제구순메밀 크롤링 완료
# 부산연제구순무김치 크롤링 완료
# 부산연제구순살강정 크롤링 완료
# 부산연제구술떡 크롤링 완료
# 부산연제구술찜 크롤링 완료
# 부산연제구숯불 크롤링 완료
# 부산연제구숯불꼼장어 크롤링 완료
# 부산연제구쉐이크 크롤링 완료
# 부산연제구쉬림프버거 크롤링 완료
# 부산연제구슈니첼 크롤링 완료
# 부산연제구슈마이 크롤링 완료
# 부산연제구슈크림 크롤링 완료
# 부산연제구슈톨렌 크롤링 완료
# 부산연제구슈하스코 크롤링 완료
# 부산연제구스끼야끼 크롤링 완료
# 부산연제구스몰비어 크롤링 완료
# 부산연제구스무디 크롤링 완료
# 부산연제구스시 크롤링 완료
# 부산연제구스시뷔페 크롤링 완료
# 부산연제구스위스식 크롤링 완료
# 부산연제구스지수육 크롤링 완료
# 부산연제구스지오뎅탕 크롤링 완료
# 부산연제구스콘 크롤링 완료
# 부산연제구스키야끼 크롤링 완료
# 부산연제구스테이크 크롤링 완료
# 부산연제구스테이크덮밥 크롤링 완료
# 부산연제구스테이크피자 크롤링 완료
# 부산연제구스테키동 크롤링 완료
# 부산연제구스텔라 크롤링 완료
# 부산연제구스튜 크롤링 완료
# 부산연제구스파게티 크롤링 완료
# 부산연제구스팸 크롤링 완료
# 부산연제구스페인식 크롤링 완료
# 부산연제구스프 크롤링 완료
# 부산연제구스프링롤 크롤링 완료
# 부산연제구슬로푸드 크롤링 완료
# 부산연제구시골밥상 크롤링 완료
# 부산연제구시금치 크롤링 완료
# 부산연제구시래기 크롤링 완료
# 부산연제구시저샐러드 크롤링 완료
# 부산연제구시카고피자 크롤링 완료
# 부산연제구시푸드 크롤링 완료
# 부산연제구식빵 크롤링 완료
# 부산연제구식육식당 크롤링 완료
# 부산연제구식혜 크롤링 완료
# 부산연제구신선로 크롤링 완료
# 부산연제구신쭈꾸미 크롤링 완료
# 부산연제구실내포장마차 크롤링 완료
# 부산연제구실비집 크롤링 완료
# 부산연제구심야식당 크롤링 완료
# 부산연제구싱가폴 크롤링 완료
# 부산연제구싱글몰트 크롤링 완료
# 부산연제구쌀국수 크롤링 완료
# 부산연제구쌀떡볶이 크롤링 완료
# 부산연제구쌀빵 크롤링 완료
# 부산연제구쌀케이크 크롤링 완료
# 부산연제구쌀통닭 크롤링 완료
# 부산연제구쌈밥 크롤링 완료
# 부산연제구쌍화차 크롤링 완료
# 부산연제구쏘가리매운탕 크롤링 완료
# 부산연제구쏘세지 크롤링 완료
# 부산연제구쑥라떼 크롤링 완료
# 부산연제구쑥인절미 크롤링 완료
# 부산연제구쑥차 크롤링 완료
# 부산연제구씨앗호떡 크롤링 완료
# 부산연제구씨푸드 크롤링 완료
# 부산연제구아강발 크롤링 완료
# 부산연제구아게다시도후 크롤링 완료
# 부산연제구아구찜 크롤링 완료
# 부산연제구아구탕 크롤링 완료
# 부산연제구아나고 크롤링 완료
# 부산연제구아란치니 크롤링 완료
# 부산연제구아롱사태 크롤링 완료
# 부산연제구아메리칸치즈버거 크롤링 완료
# 부산연제구아몬드크림라떼 크롤링 완료
# 부산연제구아바이순대 크롤링 완료
# 부산연제구아보카도 크롤링 완료
# 부산연제구아부라소바 크롤링 완료
# 부산연제구아시안푸드 크롤링 완료
# 부산연제구아이리쉬커피 크롤링 완료
# 부산연제구아이리쉬펍 크롤링 완료
# 부산연제구아이스모찌 크롤링 완료
# 부산연제구아이스크림 크롤링 완료
# 부산연제구아이스티 크롤링 완료
# 부산연제구아인슈페너 크롤링 완료
# 부산연제구아포카토 크롤링 완료
# 부산연제구안동국시 크롤링 완료
# 부산연제구안동찜닭 크롤링 완료
# 부산연제구안심돈까스 크롤링 완료
# 부산연제구안심스테이크 크롤링 완료
# 부산연제구안심탕수육 크롤링 완료
# 부산연제구안심파스타 크롤링 완료
# 부산연제구안창살 크롤링 완료
# 부산연제구안흥찐빵 크롤링 완료
# 부산연제구알곤이찜 크롤링 완료
# 부산연제구알곱창 크롤링 완료
# 부산연제구알리오올리오 크롤링 완료
# 부산연제구알밥 크롤링 완료
# 부산연제구알요리 크롤링 완료
# 부산연제구알탕 크롤링 완료
# 부산연제구앙금빵 크롤링 완료
# 부산연제구앙버터 크롤링 완료
# 부산연제구애프터눈티 크롤링 완료
# 부산연제구애플망고빙수 크롤링 완료
# 부산연제구애플파이 크롤링 완료
# 부산연제구애호박찌개 크롤링 완료
# 부산연제구야끼니꾸 크롤링 완료
# 부산연제구야끼도리 크롤링 완료
# 부산연제구야끼만두 크롤링 완료
# 부산연제구야끼소바 크롤링 완료
# 부산연제구야끼소바빵 크롤링 완료
# 부산연제구야끼우동 크롤링 완료
# 부산연제구야채곱창 크롤링 완료
# 부산연제구야채빵 크롤링 완료
# 부산연제구야채튀김 크롤링 완료
# 부산연제구야채호떡 크롤링 완료
# 부산연제구야키니쿠 크롤링 완료
# 부산연제구야키도리 크롤링 완료
# 부산연제구야키소바 크롤링 완료
# 부산연제구야키토리 크롤링 완료
# 부산연제구약과 크롤링 완료
# 부산연제구약초밥 크롤링 완료
# 부산연제구양갈비 크롤링 완료
# 부산연제구양고기 크롤링 완료
# 부산연제구양곱창 크롤링 완료
# 부산연제구양꼬치 크롤링 완료
# 부산연제구양념갈비 크롤링 완료
# 부산연제구양념게장 크롤링 완료
# 부산연제구양념곱창구이 크롤링 완료
# 부산연제구양념구이 크롤링 완료
# 부산연제구양념막창 크롤링 완료
# 부산연제구양념막창구이 크롤링 완료
# 부산연제구양념삼겹살 크롤링 완료
# 부산연제구양념오뎅 크롤링 완료
# 부산연제구양념족발 크롤링 완료
# 부산연제구양념치킨 크롤링 완료
# 부산연제구양다리 크롤링 완료
# 부산연제구양대창 크롤링 완료
# 부산연제구양밥 크롤링 완료
# 부산연제구양선지해장국 크롤링 완료
# 부산연제구양식 크롤링 완료
# 부산연제구양장피 크롤링 완료
# 부산연제구양지곰탕 크롤링 완료
# 부산연제구양지쌀국수 크롤링 완료
# 부산연제구양푼갈비 크롤링 완료
# 부산연제구어니언링 크롤링 완료
# 부산연제구어란파스타 크롤링 완료
# 부산연제구어리굴젓 크롤링 완료
# 부산연제구어만두 크롤링 완료
# 부산연제구어묵 크롤링 완료
# 부산연제구어묵고로케 크롤링 완료
# 부산연제구어묵탕 크롤링 완료
# 부산연제구어복쟁반 크롤링 완료
# 부산연제구어죽 크롤링 완료
# 부산연제구어탕국수 크롤링 완료
# 부산연제구어향가지 크롤링 완료
# 부산연제구어향동고 크롤링 완료
# 부산연제구언양불고기 크롤링 완료
# 부산연제구얼그레이 크롤링 완료
# 부산연제구얼큰곰탕 크롤링 완료
# 부산연제구얼큰라면 크롤링 완료
# 부산연제구얼큰설렁탕 크롤링 완료
# 부산연제구얼큰수제비 크롤링 완료
# 부산연제구얼큰순두부 크롤링 완료
# 부산연제구얼큰칼국수 크롤링 완료
# 부산연제구얼큰탕 크롤링 완료
# 부산연제구엄나무백숙 크롤링 완료
# 부산연제구에그마요 크롤링 완료
# 부산연제구에그베네딕트 크롤링 완료
# 부산연제구에그타르트 크롤링 완료
# 부산연제구에그토스트 크롤링 완료
# 부산연제구에끌레르 크롤링 완료
# 부산연제구에비동 크롤링 완료
# 부산연제구에비텐동 크롤링 완료
# 부산연제구에클레어 크롤링 완료
# 부산연제구엔초비파스타 크롤링 완료
# 부산연제구연어 크롤링 완료
# 부산연제구연어덮밥 크롤링 완료
# 부산연제구연어롤 크롤링 완료
# 부산연제구연어무한리필 크롤링 완료
# 부산연제구연어사시미 크롤링 완료
# 부산연제구연어샌드위치 크롤링 완료
# 부산연제구연어샐러드 크롤링 완료
# 부산연제구연어전문 크롤링 완료
# 부산연제구연어초밥 크롤링 완료
# 부산연제구연어회 크롤링 완료
# 부산연제구연잎밥 크롤링 완료
# 부산연제구연탄불고기 크롤링 완료
# 부산연제구연탄불백 크롤링 완료
# 부산연제구연포탕 크롤링 완료
# 부산연제구열무 크롤링 완료
# 부산연제구염소 크롤링 완료
# 부산연제구염통꼬치 크롤링 완료
# 부산연제구영국요리 크롤링 완료
# 부산연제구영양굴밥 크롤링 완료
# 부산연제구영양돌솥 크롤링 완료
# 부산연제구영양삼계탕 크롤링 완료
# 부산연제구영양탕 크롤링 완료
# 부산연제구옛날도시락 크롤링 완료
# 부산연제구옛날떡볶이 크롤링 완료
# 부산연제구옛날순대 크롤링 완료
# 부산연제구옛날왕돈까스 크롤링 완료
# 부산연제구옛날우동 크롤링 완료
# 부산연제구옛날짜장 크롤링 완료
# 부산연제구옛날통닭 크롤링 완료
# 부산연제구오가닉 크롤링 완료
# 부산연제구오겹살 크롤링 완료
# 부산연제구오골계 크롤링 완료
# 부산연제구오꼬노미야끼 크롤링 완료
# 부산연제구오뎅 크롤링 완료
# 부산연제구오돌뼈 크롤링 완료
# 부산연제구오드레기 크롤링 완료
# 부산연제구오디 크롤링 완료
# 부산연제구오리 크롤링 완료
# 부산연제구오리로스 크롤링 완료
# 부산연제구오리백숙 크롤링 완료
# 부산연제구오리샤브샤브 크롤링 완료
# 부산연제구오리주물럭 크롤링 완료
# 부산연제구오리진흙구이 크롤링 완료
# 부산연제구오리탕 크롤링 완료
# 부산연제구오리한마리 크롤링 완료
# 부산연제구오리훈제 크롤링 완료
# 부산연제구오마카세 크롤링 완료
# 부산연제구오메기떡 크롤링 완료
# 부산연제구오므라이스 크롤링 완료
# 부산연제구오믈렛 크롤링 완료
# 부산연제구오븐스파게티 크롤링 완료
# 부산연제구오삼불고기 크롤링 완료
# 부산연제구오소리 크롤링 완료
# 부산연제구오야꼬동 크롤링 완료
# 부산연제구오이무침 크롤링 완료
# 부산연제구오징어두루치기 크롤링 완료
# 부산연제구오징어먹물빠에야 크롤링 완료
# 부산연제구오징어무침 크롤링 완료
# 부산연제구오징어물회 크롤링 완료
# 부산연제구오징어볶음 크롤링 완료
# 부산연제구오징어순대 크롤링 완료
# 부산연제구오징어입 크롤링 완료
# 부산연제구오징어짬뽕 크롤링 완료
# 부산연제구오징어초무침 크롤링 완료
# 부산연제구오징어튀김 크롤링 완료
# 부산연제구오징어회 크롤링 완료
# 부산연제구오코노미야끼 크롤링 완료
# 부산연제구오향장육 크롤링 완료
# 부산연제구오향족발 크롤링 완료
# 부산연제구옥돔 크롤링 완료
# 부산연제구옥수수빵 크롤링 완료
# 부산연제구온면 크롤링 완료
# 부산연제구온소바 크롤링 완료
# 부산연제구올갱이 크롤링 완료
# 부산연제구올챙이국수 크롤링 완료
# 부산연제구옹심이 크롤링 완료
# 부산연제구옻닭 크롤링 완료
# 부산연제구와규 크롤링 완료
# 부산연제구와인바 크롤링 완료
# 부산연제구와인삼겹살 크롤링 완료
# 부산연제구와플 크롤링 완료
# 부산연제구완당 크롤링 완료
# 부산연제구완탕면 크롤링 완료
# 부산연제구왕갈비 크롤링 완료
# 부산연제구왕돈까스 크롤링 완료
# 부산연제구왕만두 크롤링 완료
# 부산연제구왕새우튀김 크롤링 완료
# 부산연제구왕새우팟타이 크롤링 완료
# 부산연제구왕소금구이 크롤링 완료
# 부산연제구왕순대 크롤링 완료
# 부산연제구왕족발 크롤링 완료
# 부산연제구왕짬뽕 크롤링 완료
# 부산연제구요거트 크롤링 완료
# 부산연제구우거지 크롤링 완료
# 부산연제구우거지해장국 크롤링 완료
# 부산연제구우니파스타 크롤링 완료
# 부산연제구우동 크롤링 완료
# 부산연제구우럭 크롤링 완료
# 부산연제구우럭매운탕 크롤링 완료
# 부산연제구우렁된장 크롤링 완료
# 부산연제구우렁쌈밥 크롤링 완료
# 부산연제구우렁제육쌈밥 크롤링 완료
# 부산연제구우렁추어탕 크롤링 완료
# 부산연제구우삼겹 크롤링 완료
# 부산연제구우삼겹부대찌개 크롤링 완료
# 부산연제구우엉밥 크롤링 완료
# 부산연제구우유빙수 크롤링 완료
# 부산연제구우육면 크롤링 완료
# 부산연제구우족 크롤링 완료
# 부산연제구우즈베키스탄 크롤링 완료
# 부산연제구월남쌈 크롤링 완료
# 부산연제구월병 크롤링 완료
# 부산연제구웨지포테이토 크롤링 완료
# 부산연제구웰빙뷔페 크롤링 완료
# 부산연제구위스키 크롤링 완료
# 부산연제구유니짜장 크롤링 완료
# 부산연제구유린기 크롤링 완료
# 부산연제구유부초밥 크롤링 완료
# 부산연제구유케동 크롤링 완료
# 부산연제구육개장 크롤링 완료
# 부산연제구육사시미 크롤링 완료
# 부산연제구육전 크롤링 완료
# 부산연제구육칼 크롤링 완료
# 부산연제구육칼국수 크롤링 완료
# 부산연제구육회 크롤링 완료
# 부산연제구은갈치조림 크롤링 완료
# 부산연제구은복국 크롤링 완료
# 부산연제구이동갈비 크롤링 완료
# 부산연제구이베리코 크롤링 완료
# 부산연제구이북식 크롤링 완료
# 부산연제구이시가리 크롤링 완료
# 부산연제구이자카야 크롤링 완료
# 부산연제구이집트 크롤링 완료
# 부산연제구이탈리안 크롤링 완료
# 부산연제구이태리 크롤링 완료
# 부산연제구인도네시아 크롤링 완료
# 부산연제구인도요리 크롤링 완료
# 부산연제구인도카레 크롤링 완료
# 부산연제구인삼주 크롤링 완료
# 부산연제구인절미 크롤링 완료
# 부산연제구일본라면 크롤링 완료
# 부산연제구일본식 크롤링 완료
# 부산연제구일식당 크롤링 완료
# 부산연제구일식집 크롤링 완료
# 부산연제구임연수 크롤링 완료
# 부산연제구잉글리쉬머핀 크롤링 완료
# 부산연제구자루우동 크롤링 완료
# 부산연제구자연산회 크롤링 완료
# 부산연제구잔치국수 크롤링 완료
# 부산연제구잠발라야 크롤링 완료
# 부산연제구잠봉뵈르 크롤링 완료
# 부산연제구잡어 크롤링 완료
# 부산연제구잡채 크롤링 완료
# 부산연제구잣두부구이 크롤링 완료
# 부산연제구장미주 크롤링 완료
# 부산연제구장어 크롤링 완료
# 부산연제구장작구이 크롤링 완료
# 부산연제구장조림 크롤링 완료
# 부산연제구장치찜 크롤링 완료
# 부산연제구장칼국수 크롤링 완료
# 부산연제구장터국밥 크롤링 완료
# 부산연제구재첩 크롤링 완료
# 부산연제구쟁반국수 크롤링 완료
# 부산연제구쟁반짜장 크롤링 완료
# 부산연제구전골 크롤링 완료
# 부산연제구전기구이 크롤링 완료
# 부산연제구전라도음식 크롤링 완료
# 부산연제구전복 크롤링 완료
# 부산연제구전어 크롤링 완료
# 부산연제구전주가맥 크롤링 완료
# 부산연제구전주콩나물국밥 크롤링 완료
# 부산연제구전통주 크롤링 완료
# 부산연제구전통차 크롤링 완료
# 부산연제구접짝뼈국 크롤링 완료
# 부산연제구젓갈볶음밥 크롤링 완료
# 부산연제구젓국갈비 크롤링 완료
# 부산연제구정육식당 크롤링 완료
# 부산연제구제과점 크롤링 완료
# 부산연제구제비추리 크롤링 완료
# 부산연제구제육 크롤링 완료
# 부산연제구제주근고기 크롤링 완료
# 부산연제구제주돼지 크롤링 완료
# 부산연제구제주오겹살 크롤링 완료
# 부산연제구젤라또 크롤링 완료
# 부산연제구젤리 크롤링 완료
# 부산연제구조개 크롤링 완료
# 부산연제구족발 크롤링 완료
# 부산연제구존슨탕 크롤링 완료
# 부산연제구주꾸미 크롤링 완료
# 부산연제구주말브런치 크롤링 완료
# 부산연제구주먹고기 크롤링 완료
# 부산연제구주먹밥 크롤링 완료
# 부산연제구주물럭 크롤링 완료
# 부산연제구죽전문 크롤링 완료
# 부산연제구죽집 크롤링 완료
# 부산연제구중국레스토랑 크롤링 완료
# 부산연제구중식 크롤링 완료
# 부산연제구중화비빔밥 크롤링 완료
# 부산연제구중화요리 크롤링 완료
# 부산연제구쥐치조림 크롤링 완료
# 부산연제구즉석떡볶이 크롤링 완료
# 부산연제구즉석튀김 크롤링 완료
# 부산연제구지도리우동 크롤링 완료
# 부산연제구지리탕 크롤링 완료
# 부산연제구지삼선 크롤링 완료
# 부산연제구지중해식 크롤링 완료
# 부산연제구지짐만두 크롤링 완료
# 부산연제구지평막걸리 크롤링 완료
# 부산연제구직화구이 크롤링 완료
# 부산연제구진주비빔밥 크롤링 완료
# 부산연제구진흙구이 크롤링 완료
# 부산연제구짜계치 크롤링 완료
# 부산연제구짜글이 크롤링 완료
# 부산연제구짜장떡볶이 크롤링 완료
# 부산연제구짜파구리 크롤링 완료
# 부산연제구짝태 크롤링 완료
# 부산연제구짬뽕 크롤링 완료
# 부산연제구짬짜면 크롤링 완료
# 부산연제구짱뚱어 크롤링 완료
# 부산연제구쪽갈비 크롤링 완료
# 부산연제구쫀드기 크롤링 완료
# 부산연제구쫄면 크롤링 완료
# 부산연제구쫄뱅이 크롤링 완료
# 부산연제구쭈곱새 크롤링 완료
# 부산연제구쭈꾸미 크롤링 완료
# 부산연제구쭈삼 크롤링 완료
# 부산연제구찐빵 크롤링 완료
# 부산연제구찜닭 크롤링 완료
# 부산연제구차돌구이 크롤링 완료
# 부산연제구차돌된장 크롤링 완료
# 부산연제구차돌떡볶이 크롤링 완료
# 부산연제구차돌막장찌개 크롤링 완료
# 부산연제구차돌박이 크롤링 완료
# 부산연제구차돌삼합 크롤링 완료
# 부산연제구차돌쌀국수 크롤링 완료
# 부산연제구차돌양지쌀국수 크롤링 완료
# 부산연제구차돌우삼겹 크롤링 완료
# 부산연제구차돌육개장 크롤링 완료
# 부산연제구차돌짬뽕 크롤링 완료
# 부산연제구차슈덮밥 크롤링 완료
# 부산연제구착즙주스 크롤링 완료
# 부산연제구찰밥 크롤링 완료
# 부산연제구참가자미미역국 크롤링 완료
# 부산연제구참게 크롤링 완료
# 부산연제구참다랑어뱃살 크롤링 완료
# 부산연제구참복 크롤링 완료
# 부산연제구참새구이 크롤링 완료
# 부산연제구참소라 크롤링 완료
# 부산연제구참숯바베큐 크롤링 완료
# 부산연제구참치 크롤링 완료
# 부산연제구참치김치찌개 크롤링 완료
# 부산연제구참치마요컵밥 크롤링 완료
# 부산연제구참치무한리필 크롤링 완료
# 부산연제구참치찌개 크롤링 완료
# 부산연제구참치타다끼 크롤링 완료
# 부산연제구참치회 크롤링 완료
# 부산연제구찹스테이크 크롤링 완료
# 부산연제구찹쌀꽈배기 크롤링 완료
# 부산연제구찹쌀도너츠 크롤링 완료
# 부산연제구찹쌀떡 크롤링 완료
# 부산연제구찹쌀수제비 크롤링 완료
# 부산연제구찹쌀순대 크롤링 완료
# 부산연제구찹쌀탕수육 크롤링 완료
# 부산연제구찹쌀호떡 크롤링 완료
# 부산연제구채끝등심 크롤링 완료
# 부산연제구채끝스테이크 크롤링 완료
# 부산연제구채식 크롤링 완료
# 부산연제구천엽 크롤링 완료
# 부산연제구철판구이 크롤링 완료
# 부산연제구철판닭갈비 크롤링 완료
# 부산연제구철판볶음 크롤링 완료
# 부산연제구철판요리 크롤링 완료
# 부산연제구철판쭈꾸미 크롤링 완료
# 부산연제구청국장 크롤링 완료
# 부산연제구체코 크롤링 완료
# 부산연제구초계국수 크롤링 완료
# 부산연제구초당순두부 크롤링 완료
# 부산연제구초무침 크롤링 완료
# 부산연제구초밥 크롤링 완료
# 부산연제구초밥부페 크롤링 완료
# 부산연제구초콜렛 크롤링 완료
# 부산연제구초콜릿 크롤링 완료
# 부산연제구촌닭 크롤링 완료
# 부산연제구촌두부 크롤링 완료
# 부산연제구추러스 크롤링 완료
# 부산연제구추어탕 크롤링 완료
# 부산연제구추어튀김 크롤링 완료
# 부산연제구춘천막국수 크롤링 완료
# 부산연제구츄러스 크롤링 완료
# 부산연제구치떡 크롤링 완료
# 부산연제구치맛살 크롤링 완료
# 부산연제구치맥 크롤링 완료
# 부산연제구치미창가 크롤링 완료
# 부산연제구치밥 크롤링 완료
# 부산연제구치슐랭 크롤링 완료
# 부산연제구치아바타 크롤링 완료
# 부산연제구치즈 크롤링 완료
# 부산연제구치즈계란말이 크롤링 완료
# 부산연제구치즈돈까스 크롤링 완료
# 부산연제구치즈라볶이 크롤링 완료
# 부산연제구치즈롤 크롤링 완료
# 부산연제구치즈무스 크롤링 완료
# 부산연제구치즈바게트 크롤링 완료
# 부산연제구치즈버거 크롤링 완료
# 부산연제구치즈볼 크롤링 완료
# 부산연제구치즈스틱 크롤링 완료
# 부산연제구치즈오믈렛 크롤링 완료
# 부산연제구치즈찜닭 크롤링 완료
# 부산연제구치즈카츠 크롤링 완료
# 부산연제구치즈케이크 크롤링 완료
# 부산연제구치즈타르트 크롤링 완료
# 부산연제구치즈토스트 크롤링 완료
# 부산연제구치즈퐁듀 크롤링 완료
# 부산연제구치즈프라이 크롤링 완료
# 부산연제구치즈피자 크롤링 완료
# 부산연제구치즈후라이 크롤링 완료
# 부산연제구치킨 크롤링 완료
# 부산연제구치킨마요 크롤링 완료
# 부산연제구치킨스테이크 크롤링 완료
# 부산연제구칠리 크롤링 완료
# 부산연제구칠리새우볶음밥 크롤링 완료
# 부산연제구칠리크랩 크롤링 완료
# 부산연제구칠리프라이즈 크롤링 완료
# 부산연제구칡냉면 크롤링 완료
# 부산연제구칭따오 크롤링 완료
# 부산연제구카라멜 크롤링 완료
# 부산연제구카레 크롤링 완료
# 부산연제구카레우동 크롤링 완료
# 부산연제구카르파치오 크롤링 완료
# 부산연제구카스테라 크롤링 완료
# 부산연제구카야토스트 크롤링 완료
# 부산연제구카이센동 크롤링 완료
# 부산연제구카츠동 크롤링 완료
# 부산연제구카케우동 크롤링 완료
# 부산연제구카프레제 크롤링 완료
# 부산연제구카프리쵸사 크롤링 완료
# 부산연제구칵테일 크롤링 완료
# 부산연제구칼국수 크롤링 완료
# 부산연제구칼만두 크롤링 완료
# 부산연제구칼삼겹살 크롤링 완료
# 부산연제구칼제비 크롤링 완료
# 부산연제구캐주얼다이닝 크롤링 완료
# 부산연제구캘리포니아롤 크롤링 완료
# 부산연제구캠핑식당 크롤링 완료
# 부산연제구커리 크롤링 완료
# 부산연제구커피 크롤링 완료
# 부산연제구컵밥 크롤링 완료
# 부산연제구컵케이크 크롤링 완료
# 부산연제구케이크 크롤링 완료
# 부산연제구코다리 크롤링 완료
# 부산연제구코스요리 크롤링 완료
# 부산연제구코울슬로 크롤링 완료
# 부산연제구코코넛쉬림프샐러드 크롤링 완료
# 부산연제구콘브레드 크롤링 완료
# 부산연제구콘치즈 크롤링 완료
# 부산연제구콥샐러드 크롤링 완료
# 부산연제구콩국물 크롤링 완료
# 부산연제구콩국수 크롤링 완료
# 부산연제구콩나물국 크롤링 완료
# 부산연제구콩나물국밥 크롤링 완료
# 부산연제구콩나물밥 크롤링 완료
# 부산연제구콩나물해장국 크롤링 완료
# 부산연제구콩불 크롤링 완료
# 부산연제구콩비지 크롤링 완료
# 부산연제구콩요리 크롤링 완료
# 부산연제구쿠바샌드위치 크롤링 완료
# 부산연제구쿠키 크롤링 완료
# 부산연제구퀘사디아 크롤링 완료
# 부산연제구큐브라떼 크롤링 완료
# 부산연제구큐브스테이크덮밥 크롤링 완료
# 부산연제구크라상 크롤링 완료
# 부산연제구크래프트맥주 크롤링 완료
# 부산연제구크레이프 크롤링 완료
# 부산연제구크레페 크롤링 완료
# 부산연제구크로아상 크롤링 완료
# 부산연제구크로크무슈 크롤링 완료
# 부산연제구크로플 크롤링 완료
# 부산연제구크림단팥빵 크롤링 완료
# 부산연제구크림맥주 크롤링 완료
# 부산연제구크림브륄레 크롤링 완료
# 부산연제구크림빵 크롤링 완료
# 부산연제구크림새우 크롤링 완료
# 부산연제구크림생맥주 크롤링 완료
# 부산연제구크림와플 크롤링 완료
# 부산연제구크림우동 크롤링 완료
# 부산연제구크림짬뽕 크롤링 완료
# 부산연제구크림치즈 크롤링 완료
# 부산연제구크림카레 크롤링 완료
# 부산연제구크림탕수육 크롤링 완료
# 부산연제구크림파스타 크롤링 완료
# 부산연제구클라우드 크롤링 완료
# 부산연제구클램차우더 크롤링 완료
# 부산연제구키위 크롤링 완료
# 부산연제구키조개 크롤링 완료
# 부산연제구키즈까페 크롤링 완료
# 부산연제구킹크랩 크롤링 완료
# 부산연제구타다키 크롤링 완료
# 부산연제구타로버블티 크롤링 완료
# 부산연제구타르트 크롤링 완료
# 부산연제구타마고산도 크롤링 완료
# 부산연제구타이음식 크롤링 완료
# 부산연제구타코 크롤링 완료
# 부산연제구타코야끼 크롤링 완료
# 부산연제구타코와사비 크롤링 완료
# 부산연제구타파스 크롤링 완료
# 부산연제구탄두리치킨 크롤링 완료
# 부산연제구탄탄멘 크롤링 완료
# 부산연제구탕수육 크롤링 완료
# 부산연제구탕평채 크롤링 완료
# 부산연제구태국식 크롤링 완료
# 부산연제구태국요리 크롤링 완료
# 부산연제구터키 크롤링 완료
# 부산연제구털레기 크롤링 완료
# 부산연제구테린느 크롤링 완료
# 부산연제구텐동 크롤링 완료
# 부산연제구토마토 크롤링 완료
# 부산연제구토마토계란탕 크롤링 완료
# 부산연제구토마토스튜 크롤링 완료
# 부산연제구토마토짬뽕 크롤링 완료
# 부산연제구토마토파스타 크롤링 완료
# 부산연제구토스트 크롤링 완료
# 부산연제구토시살 크롤링 완료
# 부산연제구토종닭 크롤링 완료
# 부산연제구토피넛라떼 크롤링 완료
# 부산연제구톳김밥 크롤링 완료
# 부산연제구통갈치구이 크롤링 완료
# 부산연제구통갈치조림 크롤링 완료
# 부산연제구통골뱅이 크롤링 완료
# 부산연제구통닭 크롤링 완료
# 부산연제구통돼지김치찌개 크롤링 완료
# 부산연제구통목살 크롤링 완료
# 부산연제구통문어 크롤링 완료
# 부산연제구통불닭발 크롤링 완료
# 부산연제구통삼겹 크롤링 완료
# 부산연제구통오겹살 크롤링 완료
# 부산연제구통오징어 크롤링 완료
# 부산연제구통오징어튀김 크롤링 완료
# 부산연제구통장어탕 크롤링 완료
# 부산연제구통치즈스틱 크롤링 완료
# 부산연제구투움바 크롤링 완료
# 부산연제구튀김덮밥 크롤링 완료
# 부산연제구튀김만두 크롤링 완료
# 부산연제구튀김소보로 크롤링 완료
# 부산연제구튀김족발 크롤링 완료
# 부산연제구트러플 크롤링 완료
# 부산연제구특갈비탕 크롤링 완료
# 부산연제구특등심 크롤링 완료
# 부산연제구특수부위 크롤링 완료
# 부산연제구티라미수 크롤링 완료
# 부산연제구티룸 크롤링 완료
# 부산연제구티본스테이크 크롤링 완료
# 부산연제구티하우스 크롤링 완료
# 부산연제구파김치 크롤링 완료
# 부산연제구파니니 크롤링 완료
# 부산연제구파닭 크롤링 완료
# 부산연제구파르페 크롤링 완료
# 부산연제구파블로바 크롤링 완료
# 부산연제구파스타 크롤링 완료
# 부산연제구파운드케익 크롤링 완료
# 부산연제구파이 크롤링 완료
# 부산연제구파인다이닝 크롤링 완료
# 부산연제구파인애플볶음밥 크롤링 완료
# 부산연제구파전 크롤링 완료
# 부산연제구파티세리 크롤링 완료
# 부산연제구파히타 크롤링 완료
# 부산연제구판메밀 크롤링 완료
# 부산연제구팔보완자 크롤링 완료
# 부산연제구팔보채 크롤링 완료
# 부산연제구팟타이 크롤링 완료
# 부산연제구팡도르 크롤링 완료
# 부산연제구팥도너츠 크롤링 완료
# 부산연제구팥빙수 크롤링 완료
# 부산연제구팥빵 크롤링 완료
# 부산연제구팥옹심이 크롤링 완료
# 부산연제구팥죽 크롤링 완료
# 부산연제구팥집 크롤링 완료
# 부산연제구팥칼국수 크롤링 완료
# 부산연제구패밀리레스토랑 크롤링 완료
# 부산연제구팬케이크 크롤링 완료
# 부산연제구펍 크롤링 완료
# 부산연제구페퍼로니 크롤링 완료
# 부산연제구편백찜 크롤링 완료
# 부산연제구편육 크롤링 완료
# 부산연제구평양냉면 크롤링 완료
# 부산연제구포장마차 크롤링 완료
# 부산연제구포천이동갈비 크롤링 완료
# 부산연제구포테이토피자 크롤링 완료
# 부산연제구폭립 크롤링 완료
# 부산연제구폭탄피자 크롤링 완료
# 부산연제구퐁듀 크롤링 완료
# 부산연제구퐁크러쉬 크롤링 완료
# 부산연제구푸딩 크롤링 완료
# 부산연제구푸아그라 크롤링 완료
# 부산연제구풍천장어 크롤링 완료
# 부산연제구퓨전 크롤링 완료
# 부산연제구프라이즈 크롤링 완료
# 부산연제구프랑스 크롤링 완료
# 부산연제구프랑스가정식 크롤링 완료
# 부산연제구프랑스레스토랑 크롤링 완료
# 부산연제구프렌치레스토랑 크롤링 완료
# 부산연제구프렌치토스트 크롤링 완료
# 부산연제구프렌치프라이 크롤링 완료
# 부산연제구플래터 크롤링 완료
# 부산연제구플레인베이글 크롤링 완료
# 부산연제구플레인와플 크롤링 완료
# 부산연제구피낭시에 크롤링 완료
# 부산연제구피맥 크롤링 완료
# 부산연제구피문어 크롤링 완료
# 부산연제구피순대 크롤링 완료
# 부산연제구피쉬앤칩스 크롤링 완료
# 부산연제구피자 크롤링 완료
# 부산연제구피자뷔페 크롤링 완료
# 부산연제구피칸파이 크롤링 완료
# 부산연제구필라프 크롤링 완료
# 부산연제구필리치즈 크롤링 완료
# 부산연제구필스너 크롤링 완료
# 부산연제구하모 크롤링 완료
# 부산연제구하모유비끼 크롤링 완료
# 부산연제구하야시라이스 크롤링 완료
# 부산연제구하얀짜장 크롤링 완료
# 부산연제구하와이안 크롤링 완료
# 부산연제구하이볼 크롤링 완료
# 부산연제구학꽁치 크롤링 완료
# 부산연제구학센 크롤링 완료
# 부산연제구한과 크롤링 완료
# 부산연제구한돈 크롤링 완료
# 부산연제구한방구이 크롤링 완료
# 부산연제구한방능이오리백숙 크롤링 완료
# 부산연제구한방닭구이 크롤링 완료
# 부산연제구한방보쌈 크롤링 완료
# 부산연제구한방삼계탕 크롤링 완료
# 부산연제구한방오리백숙 크롤링 완료
# 부산연제구한방족발 크롤링 완료
# 부산연제구한방통닭 크롤링 완료
# 부산연제구한상차림 크롤링 완료
# 부산연제구한식 크롤링 완료
# 부산연제구한옥카페 크롤링 완료
# 부산연제구한우 크롤링 완료
# 부산연제구한우갈비 크롤링 완료
# 부산연제구한우곱창 크롤링 완료
# 부산연제구한우구이 크롤링 완료
# 부산연제구한우국밥 크롤링 완료
# 부산연제구한우국시 크롤링 완료
# 부산연제구한우내장탕 크롤링 완료
# 부산연제구한우등심 크롤링 완료
# 부산연제구한우모듬 크롤링 완료
# 부산연제구한우물회 크롤링 완료
# 부산연제구한우불고기 크롤링 완료
# 부산연제구한우생등심 크롤링 완료
# 부산연제구한우샤브샤브 크롤링 완료
# 부산연제구한우소곱창 크롤링 완료
# 부산연제구한우소머리곰탕 크롤링 완료
# 부산연제구한우양곰탕 크롤링 완료
# 부산연제구소고기오마카세 크롤링 완료
# 부산연제구한우육개장 크롤링 완료
# 부산연제구한우육회 크롤링 완료
# 부산연제구한우전골 크롤링 완료
# 부산연제구한우차돌 크롤링 완료
# 부산연제구한우초밥 크롤링 완료
# 부산연제구한우특등심 크롤링 완료
# 부산연제구한정식 크롤링 완료
# 부산연제구한치 크롤링 완료
# 부산연제구함바그 크롤링 완료
# 부산연제구함박스테이크 크롤링 완료
# 부산연제구함흥냉면 크롤링 완료
# 부산연제구핫도그 크롤링 완료
# 부산연제구항아리수제비 크롤링 완료
# 부산연제구항정살 크롤링 완료
# 부산연제구해내탕 크롤링 완료
# 부산연제구해녀의집 크롤링 완료
# 부산연제구해물 크롤링 완료
# 부산연제구해물누룽지탕 크롤링 완료
# 부산연제구해물뚝배기 크롤링 완료
# 부산연제구해물라면 크롤링 완료
# 부산연제구해물부추전 크롤링 완료
# 부산연제구해물알찜 크롤링 완료
# 부산연제구해물요리 크롤링 완료
# 부산연제구해물전 크롤링 완료
# 부산연제구해물조개찜 크롤링 완료
# 부산연제구해물죽 크롤링 완료
# 부산연제구해물짬뽕 크롤링 완료
# 부산연제구해물찜 크롤링 완료
# 부산연제구해물철판 크롤링 완료
# 부산연제구해물칼국수 크롤링 완료
# 부산연제구해물탕 크롤링 완료
# 부산연제구해물파전 크롤링 완료
# 부산연제구해물포차 크롤링 완료
# 부산연제구해산물 크롤링 완료
# 부산연제구해산물빠에야 크롤링 완료
# 부산연제구해삼 크롤링 완료
# 부산연제구해신탕 크롤링 완료
# 부산연제구해온반 크롤링 완료
# 부산연제구해장국 크롤링 완료
# 부산연제구해전물회 크롤링 완료
# 부산연제구해천탕 크롤링 완료
# 부산연제구해초쌈 크롤링 완료
# 부산연제구햄버거 크롤링 완료
# 부산연제구햄샌드위치 크롤링 완료
# 부산연제구햄치즈 크롤링 완료
# 부산연제구햄치즈순두부 크롤링 완료
# 부산연제구햄치즈토스트 크롤링 완료
# 부산연제구햄치즈파니니 크롤링 완료
# 부산연제구향어회 크롤링 완료
# 부산연제구향토음식 크롤링 완료
# 부산연제구허니브레드 크롤링 완료
# 부산연제구허파전골 크롤링 완료
# 부산연제구헛제사밥 크롤링 완료
# 부산연제구헤이즐넛아메리카노 크롤링 완료
# 부산연제구현미밥 크롤링 완료
# 부산연제구호두과자 크롤링 완료
# 부산연제구호떡 크롤링 완료
# 부산연제구호르몬동 크롤링 완료
# 부산연제구호박 크롤링 완료
# 부산연제구호지차 크롤링 완료
# 부산연제구호텔뷔페 크롤링 완료
# 부산연제구호프 크롤링 완료
# 부산연제구혼마구로 크롤링 완료
# 부산연제구홍게칼국수 크롤링 완료
# 부산연제구홍어 크롤링 완료
# 부산연제구홍어탕 크롤링 완료
# 부산연제구홍짬뽕 크롤링 완료
# 부산연제구홍차 크롤링 완료
# 부산연제구홍콩식 크롤링 완료
# 부산연제구홍탁 크롤링 완료
# 부산연제구홍합 크롤링 완료
# 부산연제구홍합짬뽕 크롤링 완료
# 부산연제구홍합탕 크롤링 완료
# 부산연제구화과자 크롤링 완료
# 부산연제구화덕피자 크롤링 완료
# 부산연제구화로구이 크롤링 완료
# 부산연제구화이타 크롤링 완료
# 부산연제구화채 크롤링 완료
# 부산연제구고등어회 크롤링 완료
# 부산연제구활어 크롤링 완료
# 부산연제구황제살 크롤링 완료
# 부산연제구황태 크롤링 완료
# 부산연제구회 크롤링 완료
# 부산연제구회전초밥 크롤링 완료
# 부산연제구회정식 크롤링 완료
# 부산연제구횟집 크롤링 완료
# 부산연제구횡성한우 크롤링 완료
# 부산연제구후라이드닭강정 크롤링 완료
# 부산연제구후라이드치킨 크롤링 완료
# 부산연제구후라이드파닭 크롤링 완료
# 부산연제구후르츠산도 크롤링 완료
# 부산연제구후토마키 크롤링 완료
# 부산연제구훈제오리 크롤링 완료
# 부산연제구훠궈 크롤링 완료
# 부산연제구휘낭시에 크롤링 완료
# 부산연제구흑당버블티 크롤링 완료
# 부산연제구흑돼지 크롤링 완료
# 부산연제구흑된장밥 크롤링 완료
# 부산연제구흑마늘치킨 크롤링 완료
# 부산연제구흑염소 크롤링 완료
# 부산연제구흑우 크롤링 완료
# 부산연제구흑임자 크롤링 완료
# 부산연제구히레카츠 크롤링 완료
# 부산연제구히쯔마부시 크롤링 완료
#
#  *****크롤링완료*****

# %%
restaurant_df
# Out:
#         category food_cat   store score              summary sub_loca  \
# 1      부산연제구가라아게   제구가라아게     코하루   43점  라멘, 매운돈코츠라멘, 토리가라아게     부산시청
# 2      부산연제구가라아게   제구가라아게    그린애플   34점    랍스타, 철판요리, 문어가라아게    부산연산동
# 3       부산연제구가리비    제구가리비    피자스쿨            피자, 포테이토피자, 가리비       연산
# 4       부산연제구가리비    제구가리비    골목그릴           요리주점, 가리비, 가리비구이     부산시청
# 5       부산연제구가마솥    제구가마솥   오복 통닭   32점        통닭, 옛날통닭, 가마솥       연산
# ...          ...      ...     ...   ...                  ...      ...
# 4668    부산연제구흑임자    제구흑임자  로타리양곱창   55점             우삼겹, 양곱창    부산연산동
# 4669    부산연제구흑임자    제구흑임자  커피필라소피   55점            커피, 아메리카노       연산
# 4670    부산연제구흑임자    제구흑임자   고등어다찌   54점               해물, 다찌       연산
# 4671    부산연제구흑임자    제구흑임자     랑돼지   53점            오겹살, 생오겹살       연산
# 4672  부산연제구히쯔마부시  제구히쯔마부시    어가초밥              일식집, 초밥, 장어덮밥       연산
#
#                   full_loca
# 1      부산광역시 연제구 연산동 1362-8
# 2      부산광역시 연제구 연산동 589-23
# 3       부산광역시 연제구 연산동 57-31
# 4     부산 연제구 연산동 1499-21 1층
# 5      부산광역시 연제구 연산동 589-37
# ...                     ...
# 4668      부산 연제구 연산동 726-11
# 4669   부산광역시 연제구 연산동 405-18
# 4670   부산광역시 연제구 연산동 621-17
# 4671   부산광역시 연제구 연산동 630-31
# 4672   부산광역시 연제구 연산동 1127-7
#
# [4672 rows x 7 columns]

# %%
df = pd.read_csv(f'/Users/ppangppang/Desktop/맛집리스트확인/{date}_restaurant_list4.csv')
df.drop_duplicates(['store'],inplace=True)
df.index = range(len(df))
df
# Out:
#          category  food_cat        store score              summary sub_loca  \
# 0       부산연제구가라아게    제구가라아게          코하루   43점  라멘, 매운돈코츠라멘, 토리가라아게     부산시청
# 1       부산연제구가라아게    제구가라아게         그린애플   34점    랍스타, 철판요리, 문어가라아게    부산연산동
# 2        부산연제구가리비     제구가리비         피자스쿨   NaN      피자, 포테이토피자, 가리비       연산
# 3        부산연제구가리비     제구가리비         골목그릴   NaN     요리주점, 가리비, 가리비구이     부산시청
# 4        부산연제구가마솥     제구가마솥        오복 통닭   32점        통닭, 옛날통닭, 가마솥       연산
# ...           ...       ...          ...   ...                  ...      ...
# 1152      부산연제구활어      제구활어        남해 횟집   33점              횟집, 생선회       연산
# 1153      부산연제구황태      제구황태          비어죤   NaN         돈까스, 칠면조, 황태       토곡
# 1154     부산연제구회정식     제구회정식         남해횟집   NaN              횟집, 회정식     부산연제
# 1155      부산연제구횟집      제구횟집           먹물   39점    요리주점, 산오징어회, 오징어회     부산시청
# 1156  부산연제구후라이드치킨  제구후라이드치킨  BBQ치킨 부산연산점   NaN           치킨, 후라이드치킨       연산
#
#                           full_loca
# 0              부산광역시 연제구 연산동 1362-8
# 1              부산광역시 연제구 연산동 589-23
# 2               부산광역시 연제구 연산동 57-31
# 3             부산 연제구 연산동 1499-21 1층
# 4              부산광역시 연제구 연산동 589-37
# ...                             ...
# 1152  부산광역시 연제구 연산동 1384-3 홍익푸르미아파트
# 1153            부산광역시 연제구 연산동 482-1
# 1154           부산광역시 연제구 연산동 636-28
# 1155           부산광역시 연제구 연산동 1507-1
# 1156           부산광역시 연제구 연산동 775-44
#
# [1157 rows x 7 columns]

# %%
# 상위점수 구분(30점 이상만)
# a = list(df['score'])
# for i in range(len(a)):
#     a[i] = int(a[i][:-1])
# df['re_score'] = a
# df = df[df['re_score']>=30]
# df.index=range(len(df))
# df.drop(['re_score'],axis=1,inplace=True)
# df=df.sort_values('score',ascending=False)

# %%
df.to_excel('/Users/ppangppang/Desktop/맛집리스트확인/select/부산연제구.xlsx',index=False)

# %%
# df.to_csv('/Users/ppangppang/Documents/dev/TIL/test_restaurant_data/211010_restaurant_list3.csv',index=False)

# %% [markdown]
# ## 현재까지 작업한 파일 concat

# %%
import glob
import pandas as pd

# get data file names
filenames = glob.glob('/Users/ppangppang/Desktop/ssac/data_crwaling/restaurant_test/databackup/*.csv')

dfs = []
for filename in filenames:
    dfs.append(pd.read_csv(filename))

# Concatenate all data into one DataFrame
df = pd.concat(dfs, ignore_index=True)
df.drop_duplicates(['store'],inplace=True)
df.index = range(len(df))

# %%
df
# Out:
#       category food_cat           store score            summary sub_loca  \
# 0         부평냉면        면            해민면옥   61점      평양냉면, 녹두전, 냉면       부평
# 1         부평냉면        면           부평막국수   56점       수육, 물막국수, 냉면    부평시장역
# 2         부평냉면        면           별미칡냉면   54점            냉면, 물냉면       부평
# 3         부평냉면        면      화미소금구이 부평점   41점        삼겹살, 목살, 냉면       부평
# 4         부평냉면        면             디델리   35점      떡볶이, 라볶이, 물냉면       부평
# ...        ...      ...             ...   ...                ...      ...
# 48631  계양찹쌀꽈배기     쌀꽈배기        노랑고래 효성점   NaN    도너츠, 꽈배기, 찹쌀꽈배기      효성동
# 48632  계양치즈핫도그     즈핫도그  소문난 마늘숙성 수제돈가스   NaN  돈까스, 수제돈까스, 치즈핫도그      효성동
# 48633    계양닭다리       다리       BHC치킨 임학점   NaN       치킨, 치즈볼, 닭다리      임학역
# 48634   계양커피콩빵      피콩빵            투씨커피   NaN       카페, 커피, 커피콩빵      계산동
# 48635     계양홍어        어          명품홍어무침   NaN           홍어무침, 홍어     계양구청
#
#                             full_loca
# 0                인천광역시 부평구 부평동 212-24
# 1               인천광역시 부평구 부평1동 529-96
# 2                   인천시 부평구 갈산동 377-8
# 3                 인천광역시 부평구 부평동 70-83
# 4                인천광역시 부평구 부평동 211-75
# ...                               ...
# 48631             인천광역시 계양구 효성동 242-7
# 48632           인천광역시 계양구 병방동 373 28호
# 48633             인천광역시 계양구 임학동 65-11
# 48634             인천광역시 계양구 작전동 905-1
# 48635  인천 계양구 용종동 209-4 계양프라자 1층 103호
#
# [48636 rows x 7 columns]

# %%
df.isna().sum()
# Out:
# category         0
# food_cat      1534
# store            0
# score        12268
# summary          2
# sub_loca         0
# full_loca        0
# dtype: int64

# %%
# 어차피 0점은 없음. 점수가 있거나 없거나임
df['score']=df['score'].fillna('0점')
df
# Out:
#       category food_cat           store score            summary sub_loca  \
# 0         부평냉면        면            해민면옥   61점      평양냉면, 녹두전, 냉면       부평
# 1         부평냉면        면           부평막국수   56점       수육, 물막국수, 냉면    부평시장역
# 2         부평냉면        면           별미칡냉면   54점            냉면, 물냉면       부평
# 3         부평냉면        면      화미소금구이 부평점   41점        삼겹살, 목살, 냉면       부평
# 4         부평냉면        면             디델리   35점      떡볶이, 라볶이, 물냉면       부평
# ...        ...      ...             ...   ...                ...      ...
# 48631  계양찹쌀꽈배기     쌀꽈배기        노랑고래 효성점    0점    도너츠, 꽈배기, 찹쌀꽈배기      효성동
# 48632  계양치즈핫도그     즈핫도그  소문난 마늘숙성 수제돈가스    0점  돈까스, 수제돈까스, 치즈핫도그      효성동
# 48633    계양닭다리       다리       BHC치킨 임학점    0점       치킨, 치즈볼, 닭다리      임학역
# 48634   계양커피콩빵      피콩빵            투씨커피    0점       카페, 커피, 커피콩빵      계산동
# 48635     계양홍어        어          명품홍어무침    0점           홍어무침, 홍어     계양구청
#
#                             full_loca
# 0                인천광역시 부평구 부평동 212-24
# 1               인천광역시 부평구 부평1동 529-96
# 2                   인천시 부평구 갈산동 377-8
# 3                 인천광역시 부평구 부평동 70-83
# 4                인천광역시 부평구 부평동 211-75
# ...                               ...
# 48631             인천광역시 계양구 효성동 242-7
# 48632           인천광역시 계양구 병방동 373 28호
# 48633             인천광역시 계양구 임학동 65-11
# 48634             인천광역시 계양구 작전동 905-1
# 48635  인천 계양구 용종동 209-4 계양프라자 1층 103호
#
# [48636 rows x 7 columns]

# %%
df[df['summary'].isna()]
# Out:
#       category food_cat        store score summary sub_loca  \
# 39192   종로구운니동      NaN    COFFEE la   21점     NaN      안국역
# 39836   강서구공항동      NaN   호호카츠 김포공항점   26점     NaN     김포공항
#
#                          full_loca
# 39192        서울시 종로구 운니동 15 노블호텔1층
# 39836  서울특별시 강서구 공항동 1373 국내선청사 4층

# %%
# df['summary'][39836:39837] = '돈까스'
# df['summary'][39192:39293] = '커피'

# %%
df.isna().sum()
# Out:
# category        0
# food_cat     1534
# store           0
# score           0
# summary         0
# sub_loca        0
# full_loca       0
# dtype: int64

# %%
# food_cat은 부가정보로 남겨둔거니까 패스
df = df[['category','store','summary','sub_loca','full_loca']]
df.index = range(len(df))
df
# Out:
#       category           store            summary sub_loca  \
# 0         부평냉면            해민면옥      평양냉면, 녹두전, 냉면       부평
# 1         부평냉면           부평막국수       수육, 물막국수, 냉면    부평시장역
# 2         부평냉면           별미칡냉면            냉면, 물냉면       부평
# 3         부평냉면      화미소금구이 부평점        삼겹살, 목살, 냉면       부평
# 4         부평냉면             디델리      떡볶이, 라볶이, 물냉면       부평
# ...        ...             ...                ...      ...
# 48631  계양찹쌀꽈배기        노랑고래 효성점    도너츠, 꽈배기, 찹쌀꽈배기      효성동
# 48632  계양치즈핫도그  소문난 마늘숙성 수제돈가스  돈까스, 수제돈까스, 치즈핫도그      효성동
# 48633    계양닭다리       BHC치킨 임학점       치킨, 치즈볼, 닭다리      임학역
# 48634   계양커피콩빵            투씨커피       카페, 커피, 커피콩빵      계산동
# 48635     계양홍어          명품홍어무침           홍어무침, 홍어     계양구청
#
#                             full_loca
# 0                인천광역시 부평구 부평동 212-24
# 1               인천광역시 부평구 부평1동 529-96
# 2                   인천시 부평구 갈산동 377-8
# 3                 인천광역시 부평구 부평동 70-83
# 4                인천광역시 부평구 부평동 211-75
# ...                               ...
# 48631             인천광역시 계양구 효성동 242-7
# 48632           인천광역시 계양구 병방동 373 28호
# 48633             인천광역시 계양구 임학동 65-11
# 48634             인천광역시 계양구 작전동 905-1
# 48635  인천 계양구 용종동 209-4 계양프라자 1층 103호
#
# [48636 rows x 5 columns]

# %%
# 일단 서울, 인천만보자
location = pd.read_csv('/Users/ppangppang/Desktop/ssac/data_crwaling/restaurant_test/adm_code.csv')
location = location[(location['시도코드'] == 23) | (location['시도코드'] == 11)]
location.index = range(len(location))
location
# Out:
#      시도코드   시도명칭  시군구코드 시군구명칭    읍면동코드 읍면동명칭            전체코드
# 0      11  서울특별시  11010   종로구  1101053   사직동  11110101101053
# 1      11  서울특별시  11010   종로구  1101054   삼청동  11110101101054
# 2      11  서울특별시  11010   종로구  1101055   부암동  11110101101055
# 3      11  서울특별시  11010   종로구  1101056   평창동  11110101101056
# 4      11  서울특별시  11010   종로구  1101057   무악동  11110101101057
# ..    ...    ...    ...   ...      ...   ...             ...
# 574    23  인천광역시  23320   옹진군  2332033   백령면  23233202332033
# 575    23  인천광역시  23320   옹진군  2332034   대청면  23233202332034
# 576    23  인천광역시  23320   옹진군  2332035   덕적면  23233202332035
# 577    23  인천광역시  23320   옹진군  2332036   자월면  23233202332036
# 578    23  인천광역시  23320   옹진군  2332037   영흥면  23233202332037
#
# [579 rows x 7 columns]

# %%
df2 = df[df['full_loca'].str.contains('임학동')]

# %%
# df['si'] = np.where(df['full_loca'].str.contains('서울'), 11, 23)

# %%
df['si'] = np.where(df['full_loca'].str.contains('서울'), '서울', '인천')
# Out:
#       category           store            summary sub_loca  \
# 0         부평냉면            해민면옥      평양냉면, 녹두전, 냉면       부평
# 1         부평냉면           부평막국수       수육, 물막국수, 냉면    부평시장역
# 2         부평냉면           별미칡냉면            냉면, 물냉면       부평
# 3         부평냉면      화미소금구이 부평점        삼겹살, 목살, 냉면       부평
# 4         부평냉면             디델리      떡볶이, 라볶이, 물냉면       부평
# ...        ...             ...                ...      ...
# 48631  계양찹쌀꽈배기        노랑고래 효성점    도너츠, 꽈배기, 찹쌀꽈배기      효성동
# 48632  계양치즈핫도그  소문난 마늘숙성 수제돈가스  돈까스, 수제돈까스, 치즈핫도그      효성동
# 48633    계양닭다리       BHC치킨 임학점       치킨, 치즈볼, 닭다리      임학역
# 48634   계양커피콩빵            투씨커피       카페, 커피, 커피콩빵      계산동
# 48635     계양홍어          명품홍어무침           홍어무침, 홍어     계양구청
#
#                             full_loca  si
# 0                인천광역시 부평구 부평동 212-24  23
# 1               인천광역시 부평구 부평1동 529-96  23
# 2                   인천시 부평구 갈산동 377-8  23
# 3                 인천광역시 부평구 부평동 70-83  23
# 4                인천광역시 부평구 부평동 211-75  23
# ...                               ...  ..
# 48631             인천광역시 계양구 효성동 242-7  23
# 48632           인천광역시 계양구 병방동 373 28호  23
# 48633             인천광역시 계양구 임학동 65-11  23
# 48634             인천광역시 계양구 작전동 905-1  23
# 48635  인천 계양구 용종동 209-4 계양프라자 1층 103호  23
#
# [48636 rows x 6 columns]

# %%
location[location['읍면동명칭'] == '연희동']
# Out:
#      시도코드   시도명칭  시군구코드 시군구명칭    읍면동코드 읍면동명칭            전체코드
# 205    11  서울특별시  11130  서대문구  1113076   연희동  11111301113076
# 517    23  인천광역시  23080    서구  2308053   연희동  23230802308053

# %%
#예제 데이터 만들기
ex = {'경도' : [127.061026,127.047883,127.899220,128.980455,127.104071,127.102490,127.088387,126.809957,127.010861,126.836078
                ,127.014217,126.886859,127.031702,126.880898,127.028726,126.897710,126.910288,127.043189,127.071184,127.076812
                ,127.045022,126.982419,126.840285,127.115873,126.885320,127.078464,127.057100,127.020945,129.068324,129.059574
                ,126.927655,127.034302,129.106330,126.980242,126.945099,129.034599,127.054649,127.019556,127.053198,127.031005
                ,127.058560,127.078519,127.056141,129.034605,126.888485,129.070117,127.057746,126.929288,127.054163,129.060972],
     '위도' : [37.493922,37.505675,37.471711,35.159774,37.500249,37.515149,37.549245,37.562013,37.552153,37.538927,37.492388
              ,37.480390,37.588485,37.504067,37.608392,37.503693,37.579029,37.580073,37.552103,37.545461,37.580196,37.562274
              ,37.535419,37.527477,37.526139,37.648247,37.512939,37.517574,35.202902,35.144776,37.499229,35.150069,35.141176
              ,37.479403,37.512569,35.123196,37.546718,37.553668,37.488742,37.493653,37.498462,37.556602,37.544180,35.111532
              ,37.508058,35.085777,37.546103,37.483899,37.489299,35.143421],
     '구분' : ['음식','음식','음식','음식','생활서비스','음식','음식','음식','음식','음식','음식','음식','음식','음식','음식'
             ,'음식','음식','소매','음식','음식','음식','음식','소매','음식','소매','음식','음식','음식','음식','음식','음식'
             ,'음식','음식','음식','음식','소매','음식','음식','의료','음식','음식','음식','소매','음식','음식','음식','음식'
             ,'음식','음식','음식']}

ex=pd.DataFrame(ex)

# %%
lat = ex.loc[0,'위도']
long = ex.loc[0,'경도']

# %%
#지도 새로 띄우기
m = folium.Map([lat,long],zoom_start=12)

for i in ex.index:
    sub_lat =  ex.loc[i,'위도']
    sub_long = ex.loc[i,'경도']
    
    title = ex.loc[i,'구분']
  
    #구분이 소매면 빨간색으로 표시, default는 녹색
    color = 'green'
    if ex.loc[i,'구분'] == '소매':
        color = "red"
        
    #지도에 동그라미로 데이터 찍기    
    folium.CircleMarker([sub_lat,sub_long],color=color,radius = 5, tooltip=title).add_to(m)

m

# %%
driver = webdriver.Chrome('/Users/ppangppang/Desktop/ssac/02.Python_/Python_Basic_Class/chromedriver')

url = 'https://www.google.com/maps/'
driver.get(url)
time.sleep(5)

# %% [markdown]
# 1. 인기 메뉴 카테고리 설정(프렌차이즈가 많으니, 적어도 50분야 정도 설정)
# 2. 구단위 뒤도 경도 뽑아보기(좀 어려우면 좀 묶어서)
# 3. 카테고리별 맛집 평균점수에따라 지도에 표시해보기
# 여기서 나올만한 인사이트? - 카테고리별 지역별 맛집 분포 / 배달과 관련해서 뭐 엮을만한게 있을까? / 시간되면 생활지수들 질병관리청에서 가져와서 상관관계 확인?
#
# 위도경도 링크1 : https://sajuplus.tistory.com/778
# 위도경도 링크2 : https://kor.timegenie.com/latitude_longitude/country/kr
# 위도경도 api : https://www.vworld.kr/dev/v4dv_2ddataguide2_s002.do?svcIde=ademd
#
# 다른 데이터셋 확인 : kosis , 질병관리청
